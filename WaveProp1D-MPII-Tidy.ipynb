# %%
from dolfin import *
import numpy as np
parameters["form_compiler"]["representation"] = 'quadrature'
import warnings
from ffc.quadrature.deprecation import QuadratureRepresentationDeprecationWarning
warnings.simplefilter("once", QuadratureRepresentationDeprecationWarning)
import matplotlib.pyplot as plt

# Form compiler options
parameters["form_compiler"]["cpp_optimize"] = True
parameters["form_compiler"]["optimize"] = True

# Define mesh
mesh = UnitIntervalMesh(50)
#mesh = RectangleMesh(Point(0., 0.), Point(1., 0.1), 50, 5)

print("Plotting a UnitIntervalMesh:")
plt.figure()
plot(mesh, title="UnitIntervalMesh")

# =========================================================
# DEFINE BOUNDARY ELEMENTS

tol = 1E-12
# Sub domain for clamp at left end
def left(x, on_boundary):
    return near(x[0], 0.,tol) and on_boundary

# Sub domain for rotation at right end
def right(x, on_boundary):
    return near(x[0], 1.,tol) and on_boundary

# Create mesh function over the cell facets
boundary_subdomains = MeshFunction("size_t", mesh, mesh.topology().dim() - 1)
boundary_subdomains.set_all(0)
force_boundary = AutoSubDomain(right)
force_boundary.mark(boundary_subdomains, 3)

# Define measure for boundary condition integral
dss = ds(subdomain_data=boundary_subdomains)
# =========================================================

# =========================================================
# DEFINE MAT. PROPERTIES

E = Constant(70e3)
nu = Constant(0.3)
lmbda = E*nu/(1+nu)/(1-2*nu)
mu = E/2./(1+nu)
sig0 = Constant((1e-6))  # yield strength
Et = E/100.  # tangent modulus
H = E*Et/(E-Et)  # hardening modulus
rho = Constant(5e4)

# Time steps
Nincr = 400
load_steps = np.linspace(0, 4, Nincr+1)[1:]

dt = Constant(load_steps[1]-load_steps[0])
dt_ = float(dt)

# Newmark-beta method
betaN = Constant(0.25)
gammaN = Constant(0.5)
# =========================================================

# =========================================================
# DEFINE ELEMENT FUNCTION SPACE AND VARIABLES

deg_u = 2
deg_stress = 2
V = FunctionSpace(mesh, "CG", deg_u)

We = VectorElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, dim=1, quad_scheme='default')
W = FunctionSpace(mesh, We)
W0e = FiniteElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, quad_scheme='default')
W0 = FunctionSpace(mesh, W0e)
# Define function space for stresses
Vsig = VectorFunctionSpace(mesh, "DG", 0)

V_LM = VectorFunctionSpace(mesh, "CG", degree=deg_stress, dim=3)

L_activation = Function(V_LM)

sig = Function(W)
sig_old = Function(W)
beta = Function(W0)
gamma0 = Function(W0)
gamma0.interpolate(Constant(1e-5))
u = Function(V, name="Total displacement")
u_pre = Function(V)
u_old = Function(V)
u_d_old = Function(V)
u_dd_old = Function(V)
du = Function(V, name="Iteration correction")
Du = Function(V, name="Current increment")
v = TrialFunction(V)
u_ = TestFunction(V)

sig_out = Function(Vsig, name="sigma")
eps_out = Function(Vsig, name="epsilon")

# Set of variables for MPII model
N_MP = 30; # Number of yielding surface
Vn = VectorFunctionSpace(mesh, "DG", degree=0, dim=N_MP)

Wne = VectorElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, dim=N_MP, quad_scheme='default')
Wn = FunctionSpace(mesh, Wne)
# Wn = VectorFunctionSpace(mesh, "CG", degree=deg_stress, dim=3)

F_MP_n = Function(Wn)
alpha_MP_n = Function(Wn)
L_MP = Function(Wn)
k_MP_n = Function(Wn)

L_MP1 = Function(Vn)

metadata = {"quadrature_degree": deg_stress, "quadrature_scheme": "default"}
dxm = dx(metadata=metadata)
# =========================================================

# =========================================================
# DEFINE MPII MODEL PARA. 

sample_MP = np.linspace(0.3,9,N_MP)
C_MP = np.zeros((N_MP,1))
k_MP = np.zeros((N_MP,))
# Generate yielding surface parameters with the bone curve
strain_ref_MP = 1e-6;
# Normalized bone curve function
def bone_MPII(strain):
    k_ = strain_ref_MP*np.log(1+strain/strain_ref_MP)
    G_ = 1/(1+strain/strain_ref_MP)
    return k_, G_

for i_sample in range(N_MP):
    k_MP[i_sample], G_n_MP = bone_MPII(sample_MP[i_sample]*strain_ref_MP)
    if i_sample > 0:
        C_MP[i_sample] = 1 / (1/2/mu/G_n_MP - 1/2/mu - np.sum(1/C_MP[0:i_sample]))
    else:
        C_MP[i_sample] = 1 / (1/2/mu/G_n_MP - 1/2/mu)
    # C_MP[i_sample] = G_n_MP

k_MP = k_MP*float(mu)
    
plt.subplot(1,2,1)
plt.plot(sample_MP*strain_ref_MP,C_MP)
plt.subplot(1,2,2)
plt.plot(sample_MP*strain_ref_MP,k_MP)
plt.show()

k_MP_n.interpolate(Constant(k_MP))
# =========================================================

# =========================================================
# DEFINE NEUMANN BCs 

n = FacetNormal(mesh)
q_lim = float(2/sqrt(3)*sig0*mu*2)
# loading = Expression("q*t", q=q_lim, t=0, degree=2)
# sin(2*pi/0.6*t)
# q*t*(1-t)*4
loading = Expression(("t <= tc ? q*sin(2*pi/0.6*t) : 0"), q=0.5*q_lim, t=0, tc=1.2, degree=2)
# p = Expression(("t <= tc ? p0*t/tc : 0", "0", "0"), t=0, tc=cutoff_Tc, p0=p0, degree=0)

def F_ext(v):
    return dot(loading,v)*dss(3)
    # return loading*dot(n, v)*dss(3)
# =========================================================

# =========================================================
# DEFINE FUNCTIONS FOR FUNCTIONAL CONSTRUCTION

def eps(v):
    e = 0.5*grad(v)
    return e

def sigma(eps_el):
    return 2*mu*eps_el

def sigma_out(r):
    return 2.0*mu*sym(grad(r))

tol_err = 1e-10
def sigma_tang(e):
    inv_modulus = 1/2/mu
    for i_n in range(N_MP):
        inv_modulus += L_MP[i_n]/C_MP[i_n]/(L_MP[i_n]+tol_err)
    modulus = 1/inv_modulus
    return modulus[0]*e
# =========================================================

# =========================================================
# DEFINE LHS MATRIX AND RHS RESIDUAL
a_Newton = rho*inner(u_,v)/(betaN*dt*dt)*dxm + inner(2*eps(u_), sigma_tang(eps(v)) )*dxm

res = (-rho)*inner(u_,u)/(betaN*dt*dt)*dxm + \
      -inner(2*eps(u_), sig)*dxm + \
      F_ext(u_) + \
      rho*inner(u_old+dt*u_d_old,u_)*1./(betaN*dt*dt)*dxm + \
      (1.-2*betaN)/(2*betaN)*rho*inner(u_dd_old,u_)*dxm
# =========================================================

# =========================================================
# DEFINE FUNCTIONS FOR FUNCTION PROJECTION
def local_project(v, V, u=None):
    dv = TrialFunction(V)
    v_ = TestFunction(V)
    a_proj = inner(dv, v_)*dxm
    b_proj = inner(v, v_)*dxm
    solver = LocalSolver(a_proj, b_proj)
    solver.factorize()
    if u is None:
        u = Function(V)
        solver.solve_local_rhs(u)
        return u
    else:
        solver.solve_local_rhs(u)
        return

def proj_sig(old_u,old_sig,old_Du,old_alpha_MP_n):
    tol_err = 1e-10
    deps_old = eps(old_Du)
    dsig = sigma_tang(deps_old)
    sig_new = dsig+old_sig
    L_MP = (abs( abs( sig_new[0]*Ones_ufl - old_alpha_MP_n) - k_MP_n ) \
               + abs( sig_new[0]*Ones_ufl - old_alpha_MP_n) - k_MP_n ) / 2
    alpha_MP_n = old_alpha_MP_n + (L_MP)*abs(deps_old[0])/(tol_err+deps_old[0])
    return dsig+old_sig, alpha_MP_n    

ppos = lambda x: (x+abs(x))/2.

Ones_ufl = Function(Wn)
Ones_ufl.interpolate(Constant( np.ones((N_MP,)) ))

def activation(Du,sig_old,alpha_MP_old):
    # L_MP_array = np.zeros((N_MP,))
    sig_new = 2*mu*eps(Du) + sig_old
    L_MP = (abs( abs( sig_new[0]*Ones_ufl - alpha_MP_old) - k_MP_n ) \
               + abs( sig_new[0]*Ones_ufl - alpha_MP_old) - k_MP_n ) / 2
        # L_MP[i_n] = conditional(gt(judge_act,0), 1, 0)
        # if judge_act > 0:
        #     L_MP[i_n] = 1
        # else:
        #     L_MP[i_n] = 0
    return L_MP
# =========================================================

# =========================================================
# DEFINE FUNCTIONS FOR U, V, A UPDATE

# Update formula for acceleration
# a = 1/(2*beta)*((u - u0 - v0*dt)/(0.5*dt*dt) - (1-2*beta)*a0)
def update_a(u, u_old, v_old, a_old, ufl=True):
    if ufl:
        dt_ = dt
        betaN_ = betaN
    else:
        dt_ = float(dt)
        betaN_ = float(betaN)
    return (u-u_old-dt_*v_old)/betaN_/dt_**2 - (1-2*betaN_)/2/betaN_*a_old

# Update formula for velocity
# v = dt * ((1-gamma)*a0 + gamma*a) + v0
def update_v(a, u_old, v_old, a_old, ufl=True):
    if ufl:
        dt_ = dt
        gamma_ = gammaN
    else:
        dt_ = float(dt)
        gamma_ = float(gammaN)
    return v_old + dt_*((1-gamma_)*a_old + gamma_*a)

def update_fields(u, u_old, v_old, a_old):
    """Update fields at the end of each time step."""

    # Get vectors (references)
    u_vec, u0_vec  = u.vector(), u_old.vector()
    v0_vec, a0_vec = v_old.vector(), a_old.vector()

    # use update functions using vector arguments
    a_vec = update_a(u_vec, u0_vec, v0_vec, a0_vec, ufl=False)
    v_vec = update_v(a_vec, u0_vec, v0_vec, a0_vec, ufl=False)

    # Update (u_old <- u)
    v_old.vector()[:], a_old.vector()[:] = v_vec, a_vec
    u_old.vector()[:] = u.vector()
# =========================================================

# =========================================================
# FILE OUTPUT
    
file_results = XDMFFile("nonlinearMPII1D__results.xdmf")
file_results.parameters["flush_output"] = True
file_results.parameters["functions_share_mesh"] = True
# =========================================================

# =========================================================
# ITERATIVE SOLVER

results = np.zeros((Nincr+1, 5))
results_1d = np.zeros((Nincr+1, 50))
results_2d = np.zeros((Nincr+1, N_MP))

Nitermax, tol = 5, 1e-9  # parameters of the Newton-Raphson procedure

# Set up Dirichlet boundary condition at left end
zero = Constant(0.0)
bc_newton = DirichletBC(V, zero, left)

bc = DirichletBC(V, zero, left)
# bc = [DirichletBC(V.sub(1), 0, facets, 1), DirichletBC(V.sub(0), 0, facets, 3)]

# Initial conditions
u_old.interpolate( Expression(("0"), degree=2) )
u_d_old.interpolate( Expression(("0"), degree=2) )

for (i, t) in enumerate(load_steps):
    loading.t = t
    
    u_pre.assign(u)
    
    # Prepare for U_n+1^0 from U_n
    bc.apply(u.vector())
    Du.assign(u-u_pre)
    
    # print("Activation: ",L_MP_(1))
    # local_project(L_MP, Vsig, sig_out)
    # print("Activation: ",sig_out(1))
    
    L_MP_ = activation(Du,sig_old,alpha_MP_n)
    local_project(L_MP_, Vn, L_MP1)
    local_project(L_MP_, Wn, L_MP)
    sig_, alpha_MP_n_ = proj_sig(u_pre,sig_old,Du,alpha_MP_n)
    local_project(sig_, W, sig)
    local_project(alpha_MP_n_, Wn, alpha_MP_n)
    
    A, Res = assemble_system(a_Newton, res, bc_newton)
    nRes0 = Res.norm("l2")
    nRes = nRes0
    
    print("Increment:", str(i+1),"   Initial Residual:", nRes0)
    niter = 0
    
    while (nRes/nRes0 > tol and nRes0>1e-10) and niter < Nitermax:
        solve(A, du.vector(), Res, "mumps")
        Du.assign(Du+du)
        u.assign(u+du) # u^{k+1}_{n+1}
        L_MP_ = activation(Du,sig_old,alpha_MP_n)
        # print("Activation: ",L_MP_(1))
        local_project(L_MP_, Vn, L_MP1)
        local_project(L_MP_, Wn, L_MP)
        sig_, alpha_MP_n_ = proj_sig(u_pre,sig_old,Du,alpha_MP_n)
        local_project(sig_, W, sig)
        local_project(alpha_MP_n_, Wn, alpha_MP_n)
        A, Res = assemble_system(a_Newton, res, bc_newton)
        nRes = Res.norm("l2")
        print("    Residual:", nRes," ",niter)
        niter += 1
    u.assign(u_pre+Du)
    
    update_fields(u, u_old, u_d_old, u_dd_old)
    
    sig_old.assign(sig)
    
    print("Activation: ",L_MP1(1)[L_MP1(1)>1e-10])
# ----------------
# Post-processing
# ----------------
#
# Inside the incremental loop, the displacement and plastic strains are exported
# at each time increment, the plastic strain must first be projected onto the
# previously defined DG FunctionSpace. We also monitor the value of the cylinder
# displacement on the inner boundary. The load-displacement curve is then plotted::

    local_project(sig, Vsig, sig_out)
    local_project(eps(u), Vsig, eps_out)
    # local_project(alpha_MP_n, V_LM, L_activation)
    # print("alpha_MP_n: ",alpha_MP_n[0](1))
    # local_project(L_MP, V_LM, L_activation)
    # print("Activation: ",L_MP(1))
    
    file_results.write(u, t)
    
    results_2d[i+1,:] = L_MP1(1)[:]
    for i_x in range(50):
        results_1d[i+1,i_x] = u(i_x/50)
    tc = 1.2;
    if t<tc:
        # results[i+1, :] = (u(1),t,4*t*(1-t))
        results[i+1, :] = (u(1), sig_out(1),t,4*t*(1-t),eps_out(1))
    else:
        results[i+1, :] = (u(1), sig_out(1),t,0,eps_out(1))
# Out:
# Plotting a UnitIntervalMesh:
# /home/aangniu/anaconda3/envs/fenicsproject/lib/python3.9/site-packages/ffc/jitcompiler.py:234: QuadratureRepresentationDeprecationWarning:
# *** ===================================================== ***
# *** FFC: quadrature representation is deprecated! It will ***
# *** likely be removed in 2018.2.0 release. Use uflacs     ***
# *** representation instead.                               ***
# *** ===================================================== ***
#   issue_deprecation_warning()
# Increment: 1    Initial Residual: 0.003249590421837719
#     Residual: 5.143285552780892e-19   0
# Activation:  []
# Increment: 2    Initial Residual: 0.013080954419446929
#     Residual: 2.529366277972212e-13   0
# Activation:  []
# Increment: 3    Initial Residual: 0.03167435059085005
#     Residual: 0.0012101184613308156   0
#     Residual: 5.221371836171689e-11   1
#     Residual: 5.905547550144555e-11   2
#     Residual: 5.3409111186158626e-14   3
# Activation:  [0.00044605]
# Increment: 4    Initial Residual: 0.05504334575808595
#     Residual: 0.0013547158992404428   0
#     Residual: 1.0948338997821096e-10   1
#     Residual: 2.617333726438415e-10   2
#     Residual: 1.2104880554486874e-10   3
#     Residual: 9.283997012534693e-11   4
# Activation:  [0.00050373]
# Increment: 5    Initial Residual: 0.0819766955072056
#     Residual: 0.001690378540932141   0
#     Residual: 1.1298676442776562e-10   1
#     Residual: 2.0339264024658312e-10   2
#     Residual: 1.5020035898935816e-10   3
#     Residual: 6.548733739517986e-11   4
# Activation:  [0.00117867 0.00081373]
# Increment: 6    Initial Residual: 0.11180708176389832
#     Residual: 0.0017449635909452122   0
#     Residual: 0.0007210092864352796   1
#     Residual: 8.662244019508077e-11   2
# Activation:  [0.00149878 0.00130241 0.00058626]
# Increment: 7    Initial Residual: 0.14408544018762737
#     Residual: 0.0016249402011199383   0
#     Residual: 3.052808875373177e-10   1
#     Residual: 1.6328089409333236e-10   2
#     Residual: 1.5416029500925003e-10   3
#     Residual: 2.3141342313887426e-10   4
# Activation:  [0.00220937 0.00220937 0.0015229  0.00021182]
# Increment: 8    Initial Residual: 0.17861157328805002
#     Residual: 0.0025596791024446266   0
#     Residual: 2.2697628779651357e-10   1
#     Residual: 4.796911745264555e-11   2
# Activation:  [0.00247854 0.00247854 0.00165032 0.001312  ]
# Increment: 9    Initial Residual: 0.21447485749963907
#     Residual: 0.0023074488091559065   0
#     Residual: 9.288920774166203e-11   1
# Activation:  [0.00288327 0.00288327 0.00288226 0.00165979 0.00090933]
# Increment: 10    Initial Residual: 0.2511104925077914
#     Residual: 0.0019138254113745118   0
#     Residual: 1.6866770385747824e-10   1
# Activation:  [0.00309353 0.00309353 0.00309353 0.00274525 0.00191585 0.00052084]
# Increment: 11    Initial Residual: 0.2883177659341369
#     Residual: 0.0024733762028833757   0
#     Residual: 0.0007724251828917947   1
#     Residual: 0.0002818774474603425   2
#     Residual: 9.687075683978914e-11   3
# Activation:  [0.00308829 0.00308829 0.00308829 0.00308829 0.00190033 0.0011994 ]
# Increment: 12    Initial Residual: 0.3251730208700415
#     Residual: 0.0029611529799821556   0
#     Residual: 0.0005224908750987466   1
#     Residual: 8.757737844088134e-11   2
# Activation:  [0.00286988 0.00286988 0.00286988 0.00286988 0.00286893 0.00161581
#  0.0005427 ]
# Increment: 13    Initial Residual: 0.3615780759348
#     Residual: 0.002930474536201349   0
#     Residual: 0.00043061261294066733   1
#     Residual: 1.2442360051969564e-10   2
# Activation:  [0.00262903 0.00262903 0.00262903 0.00262903 0.00262903 0.00171354
#  0.00076354]
# Increment: 14    Initial Residual: 0.39683479665799176
#     Residual: 0.0028129134487536096   0
#     Residual: 4.3359733220970395e-10   1
#     Residual: 7.955825783035186e-11   2
# Activation:  [0.00212607 0.00212607 0.00212607 0.00212607 0.00212607 0.00212528
#  0.00075793]
# Increment: 15    Initial Residual: 0.4303340918256388
#     Residual: 0.002526965121067495   0
#     Residual: 0.0005051558744310105   1
#     Residual: 2.2809659941029136e-10   2
# Activation:  [0.00174062 0.00174062 0.00174062 0.00174062 0.00174062 0.00174062
#  0.00084526]
# Increment: 16    Initial Residual: 0.4620276591481902
#     Residual: 0.0030550640657183653   0
#     Residual: 0.00016446808061967277   1
#     Residual: 0.0003136435027109451   2
#     Residual: 9.58436971295665e-09   3
#     Residual: 7.303568730004334e-11   4
# Activation:  [0.00119067 0.00119067 0.00119067 0.00119067 0.00119067 0.00119067
#  0.00098374]
# Increment: 17    Initial Residual: 0.4913893200896138
#     Residual: 0.0018926063552454982   0
#     Residual: 0.0005667404607657476   1
#     Residual: 2.4103840560600803e-10   2
# Activation:  [0.00084574 0.00084574 0.00084574 0.00084574 0.00084574 0.00084574
#  0.00084574]
# Increment: 18    Initial Residual: 0.5181422075147597
#     Residual: 0.0029949908303169067   0
#     Residual: 0.00022864984660802496   1
#     Residual: 1.3079087482339558e-10   2
# Activation:  [0.00019452 0.00019452 0.00019452 0.00019452 0.00019452 0.00019452
#  0.00019452]
# Increment: 19    Initial Residual: 0.5423814207294099
#     Residual: 0.0027945565051851334   0
#     Residual: 0.00047947622545705786   1
#     Residual: 4.199537638112192e-10   2
# Activation:  []
# Increment: 20    Initial Residual: 0.5633650733536417
#     Residual: 0.002649769520784009   0
#     Residual: 0.00024198093327705138   1
#     Residual: 9.338464532184496e-11   2
# Activation:  []
# Increment: 21    Initial Residual: 0.581402619656594
#     Residual: 0.0028872693057905062   0
#     Residual: 0.00037330483728528443   1
#     Residual: 1.0427919213465818e-10   2
# Activation:  []
# Increment: 22    Initial Residual: 0.5960829910062492
#     Residual: 0.003290687743810669   0
#     Residual: 0.0002780872524611499   1
#     Residual: 1.4430912999925734e-10   2
# Activation:  []
# Increment: 23    Initial Residual: 0.6076869355152733
#     Residual: 0.003312544086074089   0
#     Residual: 0.0003181439528975302   1
#     Residual: 1.6226746983578508e-10   2
# Activation:  []
# Increment: 24    Initial Residual: 0.61603547427379
#     Residual: 0.0023299746205861943   0
#     Residual: 0.00027740099477317976   1
#     Residual: 9.736930359039296e-11   2
# Activation:  []
# Increment: 25    Initial Residual: 0.6214181097711751
#     Residual: 0.00245775944350527   0
#     Residual: 0.000398094554559405   1
#     Residual: 1.8694122277495723e-10   2
# Activation:  []
# Increment: 26    Initial Residual: 0.62387802028099
#     Residual: 0.003335319175537436   0
#     Residual: 0.00042072015882103914   1
#     Residual: 0.00042367743837958395   2
#     Residual: 1.885278068648301e-10   3
# Activation:  [0.00038087]
# Increment: 27    Initial Residual: 0.6237608206490739
#     Residual: 0.003537907448128324   0
#     Residual: 0.00030825184580521303   1
#     Residual: 0.00026518005337005426   2
#     Residual: 9.871736060424784e-10   3
#     Residual: 3.74895371225328e-10   4
# Activation:  [0.00075198]
# Increment: 28    Initial Residual: 0.6215000327344189
#     Residual: 0.0034369003885200092   0
#     Residual: 0.0002894424379142926   1
#     Residual: 1.8606456955838966e-10   2
# Activation:  [0.00085759]
# Increment: 29    Initial Residual: 0.6170580150539744
#     Residual: 0.0037549262473783682   0
#     Residual: 3.683667734223771e-10   1
# Activation:  [0.00150299 0.00093234]
# Increment: 30    Initial Residual: 0.6109531587932563
#     Residual: 0.0030135513517813633   0
#     Residual: 4.5588636845997724e-10   1
# Activation:  [0.00169629 0.00144066]
# Increment: 31    Initial Residual: 0.6040426673464071
#     Residual: 0.0026739581229869983   0
#     Residual: 0.0003498658958196891   1
#     Residual: 0.00020983166095853964   2
#     Residual: 7.081074565171695e-10   3
#     Residual: 1.6139148381330738e-10   4
# Activation:  [0.00180474 0.00180474]
# Increment: 32    Initial Residual: 0.5963521878580178
#     Residual: 0.004276146476183582   0
#     Residual: 3.022322122265209e-10   1
# Activation:  [0.00244451 0.00244451 0.00138363]
# Increment: 33    Initial Residual: 0.5886882392517314
#     Residual: 0.003244875768956791   0
#     Residual: 2.51771019938146e-10   1
# Activation:  [0.00270533 0.00270533 0.00203777]
# Increment: 34    Initial Residual: 0.5816595734777508
#     Residual: 0.0034665829190129796   0
#     Residual: 8.947730322214128e-10   1
#     Residual: 2.343789396304334e-10   2
# Activation:  [0.00295475 0.00295475 0.00295598 0.00099901]
# Increment: 35    Initial Residual: 0.575949948962681
#     Residual: 0.004940197381829141   0
#     Residual: 0.0001676705044619072   1
#     Residual: 0.0008944478428252819   2
#     Residual: 3.7963706060065335e-10   3
# Activation:  [0.00303501 0.00303501 0.003035   0.00174225]
# Increment: 36    Initial Residual: 0.5721469856313627
#     Residual: 0.004257543015364535   0
#     Residual: 0.0007221068299068363   1
#     Residual: 2.553838038648693e-10   2
# Activation:  [0.00361609 0.00361609 0.00361609 0.00254094 0.00084153]
# Increment: 37    Initial Residual: 0.5704300248959946
#     Residual: 0.004185813338891565   0
#     Residual: 0.0004647121831299507   1
#     Residual: 2.991529868474997e-10   2
# Activation:  [0.00364016 0.00364016 0.00364016 0.00364103 0.00198505]
# Increment: 38    Initial Residual: 0.5717918189022682
#     Residual: 0.004178962017238379   0
#     Residual: 0.00042868076215226884   1
#     Residual: 4.275112503262042e-10   2
# Activation:  [0.0040996  0.0040996  0.0040996  0.0040996  0.00229225 0.00020188]
# Increment: 39    Initial Residual: 0.575815527514645
#     Residual: 0.004796381830790929   0
#     Residual: 6.639700042324277e-10   1
#     Residual: 3.022053934762827e-10   2
# Activation:  [0.00400451 0.00400451 0.00400451 0.00400451 0.00349025 0.00168073]
# Increment: 40    Initial Residual: 0.5830641498370452
#     Residual: 0.004613048596890577   0
#     Residual: 0.0004892418878070727   1
#     Residual: 2.5182019252631344e-10   2
# Activation:  [0.00385925 0.00385925 0.00385925 0.00385925 0.00385965 0.00185508]
# Increment: 41    Initial Residual: 0.592867830946109
#     Residual: 0.0045871429258961096   0
#     Residual: 0.00048210773410985495   1
#     Residual: 2.4745036170895464e-10   2
# Activation:  [0.00369372 0.00369372 0.00369372 0.00369372 0.00369372 0.00261092]
# Increment: 42    Initial Residual: 0.6046834809236078
#     Residual: 0.004624013631392349   0
#     Residual: 0.0006147069673683863   1
#     Residual: 3.7234132870774723e-10   2
# Activation:  [0.00330359 0.00330359 0.00330359 0.00330359 0.00330359 0.00322416
#  0.00111216]
# Increment: 43    Initial Residual: 0.6190057127256415
#     Residual: 0.004384370517423691   0
#     Residual: 0.00030829004544020956   1
#     Residual: 2.689187258926933e-10   2
# Activation:  [0.00276109 0.00276109 0.00276109 0.00276109 0.00276109 0.00276117
#  0.00102399]
# Increment: 44    Initial Residual: 0.6344984266838414
#     Residual: 0.003995440512901139   0
#     Residual: 0.00026795822374884795   1
#     Residual: 2.3204738886313935e-10   2
# Activation:  [0.00229466 0.00229466 0.00229466 0.00229466 0.00229466 0.00229466
#  0.0011642 ]
# Increment: 45    Initial Residual: 0.6504977547128892
#     Residual: 0.0038457109107101414   0
#     Residual: 0.00043839525372382505   1
#     Residual: 3.002770958710577e-10   2
# Activation:  [0.0019395  0.0019395  0.0019395  0.0019395  0.0019395  0.0019395
#  0.00143774]
# Increment: 46    Initial Residual: 0.6669135206219449
#     Residual: 0.003189631531042752   0
#     Residual: 0.0002068510056551529   1
#     Residual: 1.8933436240164794e-10   2
# Activation:  [0.00147772 0.00147772 0.00147772 0.00147772 0.00147772 0.00147772
#  0.00146368]
# Increment: 47    Initial Residual: 0.6830688219092642
#     Residual: 0.003355873883018298   0
#     Residual: 0.0005860153048694747   1
#     Residual: 2.5590303971199997e-10   2
# Activation:  [0.00085975 0.00085975 0.00085975 0.00085975 0.00085975 0.00085975
#  0.00085975]
# Increment: 48    Initial Residual: 0.6982479378151146
#     Residual: 0.0034363519130272227   0
#     Residual: 5.907297417556744e-10   1
# Activation:  [0.00030434 0.00030434 0.00030434 0.00030434 0.00030434 0.00030434
#  0.00030434]
# Increment: 49    Initial Residual: 0.7123278595442405
#     Residual: 0.002695730223207623   0
#     Residual: 0.00014829628103257   1
#     Residual: 2.342365285853187e-10   2
# Activation:  []
# Increment: 50    Initial Residual: 0.7246883727444583
#     Residual: 0.0028339946998615206   0
#     Residual: 9.559173237509725e-06   1
#     Residual: 2.0264797810117182e-10   2
# Activation:  []
# Increment: 51    Initial Residual: 0.7350265164444458
#     Residual: 0.003927917484832625   0
#     Residual: 0.00030113460878163664   1
#     Residual: 3.451270130537711e-10   2
# Activation:  []
# Increment: 52    Initial Residual: 0.7432726343308594
#     Residual: 0.0030847743974690882   0
#     Residual: 0.00018198113606981043   1
#     Residual: 1.7753231485461066e-10   2
# Activation:  []
# Increment: 53    Initial Residual: 0.749103554328828
#     Residual: 0.004100119303774294   0
#     Residual: 6.226104602910851e-05   1
#     Residual: 2.855630680721262e-10   2
# Activation:  []
# Increment: 54    Initial Residual: 0.7525353841191698
#     Residual: 0.003715269373631353   0
#     Residual: 4.8477654481450436e-05   1
#     Residual: 2.9475454219567954e-10   2
# Activation:  []
# Increment: 55    Initial Residual: 0.7534111112015339
#     Residual: 0.0035695719884788397   0
#     Residual: 0.00039238519386308154   1
#     Residual: 3.4279761885919044e-10   2
# Activation:  []
# Increment: 56    Initial Residual: 0.7522445662995451
#     Residual: 0.003625441015267604   0
#     Residual: 0.00021449569975406097   1
#     Residual: 3.782834878318841e-10   2
# Activation:  [0.00035457]
# Increment: 57    Initial Residual: 0.7489406834053731
#     Residual: 0.003448242661542722   0
#     Residual: 3.9250340599473433e-10   1
# Activation:  [0.00066107]
# Increment: 58    Initial Residual: 0.7437004685698382
#     Residual: 0.0045523399994735776   0
#     Residual: 0.00038077972131870104   1
#     Residual: 7.295642355627607e-10   2
# Activation:  [0.00090969]
# Increment: 59    Initial Residual: 0.7366415510076052
#     Residual: 0.003908952083934796   0
#     Residual: 0.00011490223132292631   1
#     Residual: 4.1809766468516345e-10   2
# Activation:  [0.00122921 0.00084218]
# Increment: 60    Initial Residual: 0.7282579063385308
#     Residual: 0.003574858145368558   0
#     Residual: 0.0005569539730170579   1
#     Residual: 0.0004579950631546582   2
#     Residual: 6.058971203696605e-09   3
#     Residual: 3.594966895049656e-10   4
# Activation:  [0.00131585 0.00082408]
# Increment: 61    Initial Residual: 0.7186850922633654
#     Residual: 0.004382791914937788   0
#     Residual: 0.00017790079735508215   1
#     Residual: 3.3531487831709513e-10   2
# Activation:  [0.0018588  0.00185716]
# Increment: 62    Initial Residual: 0.708868590186966
#     Residual: 0.00466273742985455   0
#     Residual: 4.1277670543639485e-10   1
# Activation:  [0.00239487 0.00239487 0.00140749]
# Increment: 63    Initial Residual: 0.6986097194137426
#     Residual: 0.0040151777556475055   0
#     Residual: 4.62813232891636e-05   1
#     Residual: 2.651160978141443e-10   2
# Activation:  [0.00216764 0.00216764 0.00139071]
# Increment: 64    Initial Residual: 0.6886582343251042
#     Residual: 0.0048219666875803854   0
#     Residual: 0.00038962559564088   1
#     Residual: 2.2487238085573235e-10   2
# Activation:  [0.00290052 0.00290052 0.00267154 0.00096178]
# Increment: 65    Initial Residual: 0.6798714735961968
#     Residual: 0.004282550463478142   0
#     Residual: 1.0278748364020894e-09   1
#     Residual: 2.666273772907203e-10   2
# Activation:  [0.00297462 0.00297462 0.00297443 0.00173071]
# Increment: 66    Initial Residual: 0.6724895792389672
#     Residual: 0.005247076797526307   0
#     Residual: 0.000633927331439786   1
#     Residual: 1.9664268887409572e-10   2
# Activation:  [0.00381329 0.00381329 0.00381329 0.00247835 0.00103247]
# Increment: 67    Initial Residual: 0.6668981201188626
#     Residual: 0.005983596768475545   0
#     Residual: 0.00039510175327016074   1
#     Residual: 3.1056533888202235e-10   2
# Activation:  [0.00340297 0.00340297 0.00340297 0.00340213 0.00221201]
# Increment: 68    Initial Residual: 0.6637759974053387
#     Residual: 0.0053205754429115825   0
#     Residual: 0.0008876499821503488   1
#     Residual: 0.0004316504710176743   2
#     Residual: 1.5017224646377327e-08   3
#     Residual: 2.9359734109353907e-10   4
# Activation:  [3.74881911e-03 3.74881911e-03 3.74881911e-03 3.74881911e-03
#  1.84934534e-03 9.87751414e-05]
# Increment: 69    Initial Residual: 0.6633268303324253
#     Residual: 0.006158475704133416   0
#     Residual: 0.0004056449734935027   1
#     Residual: 2.9212021725134755e-10   2
# Activation:  [0.00387027 0.00387027 0.00387027 0.00387027 0.00328474 0.00145946]
# Increment: 70    Initial Residual: 0.6649729873501488
#     Residual: 0.004834064115038672   0
#     Residual: 6.575260213801615e-10   1
# Activation:  [0.00399542 0.00399542 0.00399542 0.00399542 0.0039947  0.00233201
#  0.0001566 ]
# Increment: 71    Initial Residual: 0.6698731690982827
#     Residual: 0.0056914223729376875   0
#     Residual: 8.85141891213956e-05   1
#     Residual: 3.139668311608638e-10   2
# Activation:  [0.00314327 0.00314327 0.00314327 0.00314327 0.00314327 0.00201036]
# Increment: 72    Initial Residual: 0.6767765585859016
#     Residual: 0.0062082509673520025   0
#     Residual: 0.0005379844524883128   1
#     Residual: 2.923399775897957e-10   2
# Activation:  [0.00305527 0.00305527 0.00305527 0.00305527 0.00305527 0.00270563
#  0.0003362 ]
# Increment: 73    Initial Residual: 0.684946165535101
#     Residual: 0.006223659697632278   0
#     Residual: 0.0009456134634746523   1
#     Residual: 9.841145631955853e-10   2
#     Residual: 3.138262092107546e-10   3
# Activation:  [0.00289733 0.00289733 0.00289733 0.00289733 0.00289733 0.00289708
#  0.00184842 0.00025621]
# Increment: 74    Initial Residual: 0.6955305636165281
#     Residual: 0.005928904578288762   0
#     Residual: 0.0005762762018156874   1
#     Residual: 2.9393574415765395e-10   2
# Activation:  [0.00269686 0.00269686 0.00269686 0.00269686 0.00269686 0.00269686
#  0.00126267]
# Increment: 75    Initial Residual: 0.7070000702794417
#     Residual: 0.0056675325452329155   0
#     Residual: 0.0009051650576004398   1
#     Residual: 2.8136330173467474e-10   2
# Activation:  [0.00206763 0.00206763 0.00206763 0.00206763 0.00206763 0.00206763
#  0.00160712]
# Increment: 76    Initial Residual: 0.7186789952985772
#     Residual: 0.00688775394560098   0
#     Residual: 0.00033092644601330777   1
#     Residual: 3.005640390263054e-10   2
# Activation:  [0.0013584  0.0013584  0.0013584  0.0013584  0.0013584  0.0013584
#  0.00117627]
# Increment: 77    Initial Residual: 0.7311851567976718
#     Residual: 0.005713786671337698   0
#     Residual: 0.0008693363320861935   1
#     Residual: 3.2114068339643045e-10   2
# Activation:  [0.00074486 0.00074486 0.00074486 0.00074486 0.00074486 0.00074486
#  0.0007446 ]
# Increment: 78    Initial Residual: 0.7423775246117214
#     Residual: 0.005748867566712555   0
#     Residual: 0.0006690877024953869   1
#     Residual: 4.677990559010859e-10   2
# Activation:  [0.00012586 0.00012586 0.00012586 0.00012586 0.00012586 0.00012586
#  0.00012561]
# Increment: 79    Initial Residual: 0.753362682535267
#     Residual: 0.005921810125125122   0
#     Residual: 0.000882037456149161   1
#     Residual: 2.7323520507649076e-10   2
# Activation:  []
# Increment: 80    Initial Residual: 0.7626279927432049
#     Residual: 0.005668497306068827   0
#     Residual: 0.0005369496855427508   1
#     Residual: 3.0899371647838206e-10   2
# Activation:  []
# Increment: 81    Initial Residual: 0.7701207956354597
#     Residual: 0.005425930975836204   0
#     Residual: 0.0006143204579973338   1
#     Residual: 3.132930674852465e-10   2
# Activation:  []
# Increment: 82    Initial Residual: 0.7761778834425915
#     Residual: 0.0053656132056014395   0
#     Residual: 0.0002893714440584668   1
#     Residual: 2.998090094648422e-10   2
# Activation:  []
# Increment: 83    Initial Residual: 0.7801765711187474
#     Residual: 0.0060889556100703875   0
#     Residual: 0.0007973712653215256   1
#     Residual: 4.5154346433870896e-10   2
# Activation:  []
# Increment: 84    Initial Residual: 0.782300858273418
#     Residual: 0.005972890632156911   0
#     Residual: 0.0008168312954636299   1
#     Residual: 0.0006654458457376572   2
#     Residual: 3.5588659120639144e-09   3
#     Residual: 3.0913748237288647e-10   4
# Activation:  []
# Increment: 85    Initial Residual: 0.7821616020059993
#     Residual: 0.004867565783610698   0
#     Residual: 4.345816666050633e-06   1
#     Residual: 3.736165436768754e-10   2
# Activation:  [0.00038934]
# Increment: 86    Initial Residual: 0.7800415170633125
#     Residual: 0.004433767776791459   0
#     Residual: 0.0003945550751514978   1
#     Residual: 4.282875789632136e-10   2
# Activation:  [0.00043792]
# Increment: 87    Initial Residual: 0.7760983565354885
#     Residual: 0.004495602948842084   0
#     Residual: 0.00028929214184271175   1
#     Residual: 3.233632250502886e-10   2
# Activation:  [0.00055636]
# Increment: 88    Initial Residual: 0.7705964202339467
#     Residual: 0.004855639409048922   0
#     Residual: 0.00047688182091162136   1
#     Residual: 0.00015372760343393833   2
#     Residual: 3.0987379792831334e-10   3
# Activation:  [0.00087626]
# Increment: 89    Initial Residual: 0.7630278883337476
#     Residual: 0.00516286735247652   0
#     Residual: 0.00038732160542018495   1
#     Residual: 5.001803759136141e-10   2
# Activation:  [0.00129843 0.0010814 ]
# Increment: 90    Initial Residual: 0.7544851326994108
#     Residual: 0.0054883662850088   0
#     Residual: 0.0006347985394105398   1
#     Residual: 0.00019774920412990012   2
#     Residual: 5.048430775326328e-10   3
# Activation:  [0.00134388 0.00096935]
# Increment: 91    Initial Residual: 0.7446063837047189
#     Residual: 0.004699277169801533   0
#     Residual: 0.0004902901516550802   1
#     Residual: 4.432327020639507e-10   2
# Activation:  [0.00180584 0.00180584]
# Increment: 92    Initial Residual: 0.7345114499544064
#     Residual: 0.005202429571330572   0
#     Residual: 0.0009968945353523318   1
#     Residual: 7.22881180575111e-09   2
#     Residual: 4.345582740864562e-10   3
# Activation:  [0.00205275 0.00205275 0.00144857]
# Increment: 93    Initial Residual: 0.7241173594202422
#     Residual: 0.005216255082407813   0
#     Residual: 0.0006276167889783733   1
#     Residual: 1.8643993582816724e-09   2
#     Residual: 4.3485157149960366e-10   3
# Activation:  [0.00211171 0.00211171 0.00146318]
# Increment: 94    Initial Residual: 0.7141720653869155
#     Residual: 0.004850025002427516   0
#     Residual: 0.0003317135522820009   1
#     Residual: 4.698468529386164e-10   2
# Activation:  [0.00275154 0.00275154 0.00250952 0.0008202 ]
# Increment: 95    Initial Residual: 0.7053689298649392
#     Residual: 0.004553040206689358   0
#     Residual: 4.702813807378761e-05   1
#     Residual: 3.077238752222629e-10   2
# Activation:  [0.00307807 0.00307807 0.00307828 0.00182093]
# Increment: 96    Initial Residual: 0.6974576677118935
#     Residual: 0.005632703924376267   0
#     Residual: 0.0001567767843297642   1
#     Residual: 3.6181306137011007e-10   2
# Activation:  [0.0038563  0.0038563  0.0038563  0.00259907 0.00153578]
# Increment: 97    Initial Residual: 0.6919288395414718
#     Residual: 0.005558303223975431   0
#     Residual: 0.0002306644862703083   1
#     Residual: 4.1614593542408174e-10   2
# Activation:  [0.00394521 0.00394521 0.00394521 0.00394616 0.00205143]
# Increment: 98    Initial Residual: 0.6881967892712163
#     Residual: 0.0055463999875320445   0
#     Residual: 0.0005527847178950373   1
#     Residual: 4.08285603348255e-10   2
# Activation:  [0.00414905 0.00414905 0.00414905 0.00414905 0.00229925 0.00066146]
# Increment: 99    Initial Residual: 0.6866677665500109
#     Residual: 0.006426421264803599   0
#     Residual: 0.0005433376665096006   1
#     Residual: 9.551120205198594e-10   2
#     Residual: 3.366257586140752e-10   3
# Activation:  [0.00377608 0.00377608 0.00377608 0.00377608 0.00316366 0.00198306]
# Increment: 100    Initial Residual: 0.6881577649684978
#     Residual: 0.005937292283696245   0
#     Residual: 0.0008929965557524628   1
#     Residual: 6.85437428215502e-09   2
#     Residual: 3.4573766795899274e-10   3
# Activation:  [0.00349996 0.00349996 0.00349996 0.00349996 0.00349996 0.00157767]
# Increment: 101    Initial Residual: 0.6916257408218558
#     Residual: 0.005304045234413496   0
#     Residual: 0.00025623134154204827   1
#     Residual: 3.348527269615086e-10   2
# Activation:  [0.00349232 0.00349232 0.00349232 0.00349232 0.00349232 0.00210261
#  0.00029232]
# Increment: 102    Initial Residual: 0.6972848279947426
#     Residual: 0.00501171866506162   0
#     Residual: 0.0002779289110932529   1
#     Residual: 3.385196160102033e-10   2
# Activation:  [0.00330461 0.00330461 0.00330461 0.00330461 0.00330461 0.00289543
#  0.00108138]
# Increment: 103    Initial Residual: 0.705281249049246
#     Residual: 0.005881046498617856   0
#     Residual: 0.0007573842978910114   1
#     Residual: 3.065907848768565e-10   2
# Activation:  [0.00310464 0.00310464 0.00310464 0.00310464 0.00310464 0.00310464
#  0.00127532]
# Increment: 104    Initial Residual: 0.714134490880441
#     Residual: 0.005305261779808889   0
#     Residual: 0.0005853502449128411   1
#     Residual: 7.70970290899512e-10   2
#     Residual: 3.424866415501433e-10   3
# Activation:  [0.00275855 0.00275855 0.00275855 0.00275855 0.00275855 0.00275855
#  0.00136455]
# Increment: 105    Initial Residual: 0.724622677287493
#     Residual: 0.005155814355355137   0
#     Residual: 0.000314749101822041   1
#     Residual: 3.6040748994819785e-10   2
# Activation:  [0.00209525 0.00209525 0.00209525 0.00209525 0.00209525 0.00209525
#  0.00141569]
# Increment: 106    Initial Residual: 0.7356910508780888
#     Residual: 0.006137518204747013   0
#     Residual: 0.00027602859602460407   1
#     Residual: 3.9668734767743564e-10   2
# Activation:  [0.00127289 0.00127289 0.00127289 0.00127289 0.00127289 0.00127289
#  0.0011455 ]
# Increment: 107    Initial Residual: 0.7469589624562222
#     Residual: 0.005532488796749194   0
#     Residual: 0.00033338951361948393   1
#     Residual: 4.3423718905262595e-10   2
# Activation:  [0.00060202 0.00060202 0.00060202 0.00060202 0.00060202 0.00060202
#  0.00060235]
# Increment: 108    Initial Residual: 0.7575740108638672
#     Residual: 0.004960327212168027   0
#     Residual: 0.00012341157101056893   1
#     Residual: 3.651525331869613e-10   2
# Activation:  [0.00020633 0.00020633 0.00020633 0.00020633 0.00020633 0.00020633
#  0.00020633]
# Increment: 109    Initial Residual: 0.7675561632124999
#     Residual: 0.005229229134377977   0
#     Residual: 0.00017461455598991976   1
#     Residual: 4.134688597789338e-10   2
# Activation:  []
# Increment: 110    Initial Residual: 0.7764537842614448
#     Residual: 0.0055273637036957505   0
#     Residual: 0.0004734756804132073   1
#     Residual: 3.443805651559127e-10   2
# Activation:  []
# Increment: 111    Initial Residual: 0.7836996020323831
#     Residual: 0.00508229962679422   0
#     Residual: 0.00011919171872860886   1
#     Residual: 3.777167356295472e-10   2
# Activation:  []
# Increment: 112    Initial Residual: 0.789162756956917
#     Residual: 0.004730677978858924   0
#     Residual: 0.0005806247166715842   1
#     Residual: 4.775581213215005e-10   2
# Activation:  []
# Increment: 113    Initial Residual: 0.7931000261036063
#     Residual: 0.004818836605225421   0
#     Residual: 0.00031470667141415685   1
#     Residual: 3.204825332610642e-10   2
# Activation:  []
# Increment: 114    Initial Residual: 0.7946184651843397
#     Residual: 0.00513688146810335   0
#     Residual: 0.00021912271456024952   1
#     Residual: 3.364390314250638e-10   2
# Activation:  []
# Increment: 115    Initial Residual: 0.7942780831604347
#     Residual: 0.004927796001263856   0
#     Residual: 0.00014403695448491407   1
#     Residual: 3.088500012283585e-10   2
# Activation:  []
# Increment: 116    Initial Residual: 0.7917736882823531
#     Residual: 0.004700924130097917   0
#     Residual: 0.0004919565986805882   1
#     Residual: 4.4441086510729556e-10   2
# Activation:  [0.00049241]
# Increment: 117    Initial Residual: 0.7876849979864666
#     Residual: 0.0045301932190407205   0
#     Residual: 0.00017646142000730643   1
#     Residual: 3.552217975303538e-10   2
# Activation:  [0.00055339]
# Increment: 118    Initial Residual: 0.7815073523014693
#     Residual: 0.004840472510674734   0
#     Residual: 0.0003738795119461174   1
#     Residual: 4.1116738371501216e-10   2
# Activation:  [0.00087384]
# Increment: 119    Initial Residual: 0.7740664771095499
#     Residual: 0.005125478133967519   0
#     Residual: 0.0005559856701383909   1
#     Residual: 5.052278742474082e-10   2
# Activation:  [0.00126291 0.00109214]
# Increment: 120    Initial Residual: 0.7653223403626714
#     Residual: 0.004321351757382056   0
#     Residual: 0.00057848393369317   1
#     Residual: 3.326589593408071e-10   2
# Activation:  [0.00141076 0.00087275]
# Increment: 121    Initial Residual: 0.7553226080711966
#     Residual: 0.004553881117831958   0
#     Residual: 0.0002719941116221622   1
#     Residual: 5.794447277423804e-10   2
# Activation:  [0.00159234 0.00159115]
# Increment: 122    Initial Residual: 0.7457035861861075
#     Residual: 0.005281792164344583   0
#     Residual: 0.0001312623744381463   1
#     Residual: 3.173478830440998e-10   2
# Activation:  [0.00088695 0.00088695]
# Increment: 123    Initial Residual: 0.7357978887792846
#     Residual: 0.005530309438210035   0
#     Residual: 0.00023303165309653367   1
#     Residual: 4.2522712345127124e-10   2
# Activation:  [0.00031396 0.00031396]
# Increment: 124    Initial Residual: 0.7259480333042504
#     Residual: 0.0048689662070450545   0
#     Residual: 0.0001068051144746101   1
#     Residual: 4.1639045071417563e-10   2
# Activation:  [0.0001011 0.0001011]
# Increment: 125    Initial Residual: 0.7163568331884506
#     Residual: 0.0051410646474012636   0
#     Residual: 0.0006505268019714046   1
#     Residual: 2.7191341957065724e-09   2
#     Residual: 4.007680903970529e-10   3
# Activation:  []
# Increment: 126    Initial Residual: 0.7073758349188151
#     Residual: 0.0058298643166009995   0
#     Residual: 0.000340243475326448   1
#     Residual: 3.269254263391049e-10   2
# Activation:  [7.98514231e-05 7.98514231e-05]
# Increment: 127    Initial Residual: 0.6977417141218022
#     Residual: 0.00526225599005597   0
#     Residual: 0.0008847067198716163   1
#     Residual: 0.0004149804919508553   2
#     Residual: 4.3965291316008607e-10   3
# Activation:  [3.90594993e-06 3.90594993e-06]
# Increment: 128    Initial Residual: 0.6887098219546464
#     Residual: 0.005148662854785892   0
#     Residual: 0.0005826199702007911   1
#     Residual: 3.3634184200080492e-09   2
#     Residual: 4.13735513996156e-10   3
# Activation:  [4.35284747e-06 4.35284747e-06]
# Increment: 129    Initial Residual: 0.6800015098991854
#     Residual: 0.005711330300268637   0
#     Residual: 0.0006215606003310197   1
#     Residual: 9.927837321386542e-10   2
#     Residual: 2.680750792129688e-10   3
# Activation:  []
# Increment: 130    Initial Residual: 0.6711261337938509
#     Residual: 0.0051023335287989574   0
#     Residual: 4.0914822252670616e-05   1
#     Residual: 4.598236985201072e-10   2
# Activation:  []
# Increment: 131    Initial Residual: 0.6629342930389464
#     Residual: 0.004559770875191886   0
#     Residual: 7.767406769827262e-05   1
#     Residual: 2.5095488949229347e-05   2
#     Residual: 7.09221674931312e-10   3
#     Residual: 3.2345440442896065e-10   4
# Activation:  []
# Increment: 132    Initial Residual: 0.6545063732051687
#     Residual: 0.005435031252118615   0
#     Residual: 8.8196411770572e-05   1
#     Residual: 3.0165223222579827e-10   2
# Activation:  []
# Increment: 133    Initial Residual: 0.6464115962983761
#     Residual: 0.005088224116036211   0
#     Residual: 0.0002714485293792678   1
#     Residual: 3.2433493176654976e-10   2
# Activation:  []
# Increment: 134    Initial Residual: 0.6380738702517756
#     Residual: 0.004597269316811142   0
#     Residual: 0.00040658648035497955   1
#     Residual: 4.46985963601454e-10   2
# Activation:  [7.93200186e-05 7.93200186e-05]
# Increment: 135    Initial Residual: 0.629983207337672
#     Residual: 0.004471695917242913   0
#     Residual: 5.7287449570829534e-05   1
#     Residual: 3.1324503033011084e-10   2
# Activation:  []
# Increment: 136    Initial Residual: 0.6222778706574416
#     Residual: 0.005513644464385617   0
#     Residual: 0.0002673936051915111   1
#     Residual: 3.231710679384995e-10   2
# Activation:  []
# Increment: 137    Initial Residual: 0.61455230373773
#     Residual: 0.004443601545237385   0
#     Residual: 0.00017023990471931895   1
#     Residual: 1.0048483905270923e-09   2
#     Residual: 3.46986059333139e-10   3
# Activation:  []
# Increment: 138    Initial Residual: 0.6070098385224074
#     Residual: 0.004566378743801793   0
#     Residual: 0.0006520202495493744   1
#     Residual: 0.00012229490694796582   2
#     Residual: 7.184392444508033e-10   3
#     Residual: 3.975587353972677e-10   4
# Activation:  []
# Increment: 139    Initial Residual: 0.5992760464553194
#     Residual: 0.004804774899667949   0
#     Residual: 0.00028653961628628946   1
#     Residual: 3.897707376593827e-10   2
# Activation:  []
# Increment: 140    Initial Residual: 0.5919023268178168
#     Residual: 0.004099414878991401   0
#     Residual: 0.00023136067506657402   1
#     Residual: 8.486942414841127e-10   2
#     Residual: 3.1050049896987953e-10   3
# Activation:  [2.75171659e-05 2.75171659e-05]
# Increment: 141    Initial Residual: 0.5835119805254153
#     Residual: 0.004685998387058244   0
#     Residual: 0.0007082980600064265   1
#     Residual: 0.0002150493817473169   2
#     Residual: 3.4121034683436326e-10   3
# Activation:  []
# Increment: 142    Initial Residual: 0.5755026041621688
#     Residual: 0.003905816268933633   0
#     Residual: 0.00016717212475543823   1
#     Residual: 0.0002471575123370993   2
#     Residual: 5.235986786521526e-08   3
#     Residual: 5.50737826911704e-10   4
# Activation:  []
# Increment: 143    Initial Residual: 0.5679661655171692
#     Residual: 0.004315241848904518   0
#     Residual: 0.0001433457760417231   1
#     Residual: 3.6236046195062295e-10   2
# Activation:  []
# Increment: 144    Initial Residual: 0.5598145948560482
#     Residual: 0.00393298012722148   0
#     Residual: 0.0004330935752768224   1
#     Residual: 4.415915175494389e-10   2
# Activation:  []
# Increment: 145    Initial Residual: 0.552207903573777
#     Residual: 0.0035808384507107975   0
#     Residual: 0.00020372715119818685   1
#     Residual: 3.653849424529831e-10   2
# Activation:  []
# Increment: 146    Initial Residual: 0.5448741090605029
#     Residual: 0.003948577983582282   0
#     Residual: 0.0007429354351905946   1
#     Residual: 0.00030749127224622823   2
#     Residual: 2.5999218358705817e-10   3
# Activation:  []
# Increment: 147    Initial Residual: 0.537491676298499
#     Residual: 0.0034692808144589737   0
#     Residual: 0.00014509423293382844   1
#     Residual: 3.035775636971237e-10   2
# Activation:  []
# Increment: 148    Initial Residual: 0.529452786239636
#     Residual: 0.003837400934086352   0
#     Residual: 0.00039362931088600037   1
#     Residual: 3.4679774996674516e-10   2
# Activation:  []
# Increment: 149    Initial Residual: 0.521918527116735
#     Residual: 0.003335037266486258   0
#     Residual: 0.0002867914471287124   1
#     Residual: 4.758275833373669e-10   2
# Activation:  []
# Increment: 150    Initial Residual: 0.5131076791839138
#     Residual: 0.0035769559565347712   0
#     Residual: 0.000251659038324127   1
#     Residual: 4.4793885342899855e-10   2
# Activation:  []
# Increment: 151    Initial Residual: 0.503813381271538
#     Residual: 0.003378011819272371   0
#     Residual: 0.00024838930946373893   1
#     Residual: 3.810822943398953e-10   2
# Activation:  [0.00014241 0.00014241]
# Increment: 152    Initial Residual: 0.4947646959573732
#     Residual: 0.003476359208283665   0
#     Residual: 0.00020179635738816685   1
#     Residual: 3.2712739372059847e-10   2
# Activation:  []
# Increment: 153    Initial Residual: 0.4847840749054641
#     Residual: 0.003576633176369658   0
#     Residual: 1.4299591355246921e-07   1
#     Residual: 3.1126545004504536e-10   2
# Activation:  []
# Increment: 154    Initial Residual: 0.4751790650369232
#     Residual: 0.0031719747051330684   0
#     Residual: 0.0002862966994430942   1
#     Residual: 2.361497625700164e-10   2
# Activation:  []
# Increment: 155    Initial Residual: 0.46620834540997236
#     Residual: 0.003284832417358329   0
#     Residual: 0.00033049819091286546   1
#     Residual: 4.147897721800069e-05   2
#     Residual: 3.4440854422870395e-10   3
# Activation:  []
# Increment: 156    Initial Residual: 0.456903225019241
#     Residual: 0.0032926460099126816   0
#     Residual: 7.081402881138792e-05   1
#     Residual: 3.6730268171860184e-10   2
# Activation:  []
# Increment: 157    Initial Residual: 0.44837913461700424
#     Residual: 0.0033416260915134356   0
#     Residual: 0.0003018593677529523   1
#     Residual: 2.9175667198279555e-10   2
# Activation:  []
# Increment: 158    Initial Residual: 0.44099182364133976
#     Residual: 0.0028547827737114974   0
#     Residual: 0.00030470342526329254   1
#     Residual: 3.2651243189141585e-10   2
# Activation:  []
# Increment: 159    Initial Residual: 0.434775217023974
#     Residual: 0.0036798448723330186   0
#     Residual: 0.00015119837123690744   1
#     Residual: 3.619276205937779e-10   2
# Activation:  []
# Increment: 160    Initial Residual: 0.4287989297013872
#     Residual: 0.0031164185878501194   0
#     Residual: 2.402947332129708e-06   1
#     Residual: 3.095058441986194e-10   2
# Activation:  []
# Increment: 161    Initial Residual: 0.42337893759264655
#     Residual: 0.0027699897922697277   0
#     Residual: 8.633883607655314e-05   1
#     Residual: 2.9991145316241757e-10   2
# Activation:  []
# Increment: 162    Initial Residual: 0.4186253491289083
#     Residual: 0.0033245233831266287   0
#     Residual: 0.00025112375614741987   1
#     Residual: 3.053637013414548e-10   2
# Activation:  []
# Increment: 163    Initial Residual: 0.4138095691804441
#     Residual: 0.0028320956980238403   0
#     Residual: 0.0001087008416750275   1
#     Residual: 2.674154081164356e-10   2
# Activation:  []
# Increment: 164    Initial Residual: 0.4100413264831456
#     Residual: 0.002381759073848512   0
#     Residual: 0.0002292630136997264   1
#     Residual: 3.836901098020001e-10   2
# Activation:  []
# Increment: 165    Initial Residual: 0.40676185310440244
#     Residual: 0.0028545736904129378   0
#     Residual: 1.6497682559334812e-05   1
#     Residual: 3.03175443852429e-10   2
# Activation:  []
# Increment: 166    Initial Residual: 0.40446848423737475
#     Residual: 0.002397157014851671   0
#     Residual: 7.761248021504037e-05   1
#     Residual: 2.1063485052899415e-10   2
# Activation:  []
# Increment: 167    Initial Residual: 0.40419696093390495
#     Residual: 0.0020615727328134126   0
#     Residual: 0.0006829832181129585   1
#     Residual: 2.5989728011465864e-08   2
#     Residual: 3.452288843879179e-10   3
# Activation:  []
# Increment: 168    Initial Residual: 0.40515089008127175
#     Residual: 0.0024523961632655546   0
#     Residual: 0.0006903223790201304   1
#     Residual: 9.111485221165583e-05   2
#     Residual: 2.732317541359007e-10   3
# Activation:  []
# Increment: 169    Initial Residual: 0.40783545144116523
#     Residual: 0.002289401137620635   0
#     Residual: 4.352539287760774e-05   1
#     Residual: 3.323268229236531e-10   2
# Activation:  []
# Increment: 170    Initial Residual: 0.41180585460260793
#     Residual: 0.002160027198442863   0
#     Residual: 1.7479319419769348e-05   1
#     Residual: 2.5507016905238873e-10   2
# Activation:  []
# Increment: 171    Initial Residual: 0.4170056483458968
#     Residual: 0.002386265322399624   0
#     Residual: 2.7502537979760673e-05   1
#     Residual: 2.34292425179705e-10   2
# Activation:  []
# Increment: 172    Initial Residual: 0.4226167858797061
#     Residual: 0.0020049283192597493   0
#     Residual: 0.00011542167874724746   1
#     Residual: 3.4189537791323375e-10   2
# Activation:  []
# Increment: 173    Initial Residual: 0.42790560700981695
#     Residual: 0.0019608680206256   0
#     Residual: 5.896338837031826e-06   1
#     Residual: 2.634649117293612e-10   2
# Activation:  []
# Increment: 174    Initial Residual: 0.4327895629855862
#     Residual: 0.0021642245490109875   0
#     Residual: 0.00021139530918608233   1
#     Residual: 3.2619655192641106e-10   2
# Activation:  []
# Increment: 175    Initial Residual: 0.43600505731088635
#     Residual: 0.0016494265564131296   0
#     Residual: 6.174744731050595e-05   1
#     Residual: 2.2545670007615828e-10   2
# Activation:  []
# Increment: 176    Initial Residual: 0.439620877535204
#     Residual: 0.002119516329231674   0
#     Residual: 0.00011972311698277834   1
#     Residual: 3.94429923222659e-10   2
# Activation:  []
# Increment: 177    Initial Residual: 0.4416507797171315
#     Residual: 0.0019898702059576935   0
#     Residual: 7.432185675311873e-10   1
#     Residual: 2.8706344011475757e-10   2
# Activation:  []
# Increment: 178    Initial Residual: 0.44333338237464576
#     Residual: 0.0018141562706136764   0
#     Residual: 1.681328912720583e-05   1
#     Residual: 3.152430213849549e-10   2
# Activation:  []
# Increment: 179    Initial Residual: 0.44529549635250054
#     Residual: 0.0017056201084849492   0
#     Residual: 2.359056761518755e-09   1
#     Residual: 2.753954434901909e-10   2
# Activation:  []
# Increment: 180    Initial Residual: 0.4466852967197855
#     Residual: 0.001563126160423158   0
#     Residual: 3.557572424662847e-05   1
#     Residual: 3.259299171090614e-10   2
# Activation:  []
# Increment: 181    Initial Residual: 0.4480903634459912
#     Residual: 0.0017303336515518916   0
#     Residual: 1.5760659558397703e-05   1
#     Residual: 4.167947751755114e-10   2
# Activation:  []
# Increment: 182    Initial Residual: 0.4466142198350357
#     Residual: 0.0016791063030594435   0
#     Residual: 7.641548457082939e-05   1
#     Residual: 3.2826856969893224e-10   2
# Activation:  []
# Increment: 183    Initial Residual: 0.4434321299928674
#     Residual: 0.0017911501329541018   0
#     Residual: 0.00020251476412227985   1
#     Residual: 2.6130300597399666e-10   2
# Activation:  []
# Increment: 184    Initial Residual: 0.43783817655565
#     Residual: 0.002184258528445403   0
#     Residual: 7.414533661514686e-05   1
#     Residual: 2.607916633530402e-10   2
# Activation:  []
# Increment: 185    Initial Residual: 0.43011295306979697
#     Residual: 0.002080009554814714   0
#     Residual: 0.0007829522313507363   1
#     Residual: 0.0003128911686783779   2
#     Residual: 2.7139307522571156e-10   3
# Activation:  []
# Increment: 186    Initial Residual: 0.4202276059381217
#     Residual: 0.0022341767262487127   0
#     Residual: 0.00013770627771397316   1
#     Residual: 2.3039441357265975e-10   2
# Activation:  []
# Increment: 187    Initial Residual: 0.4087608630984515
#     Residual: 0.0024260316411002128   0
#     Residual: 6.494479941307105e-05   1
#     Residual: 3.2292832746277536e-10   2
# Activation:  []
# Increment: 188    Initial Residual: 0.39514677596793335
#     Residual: 0.0020635506938637893   0
#     Residual: 0.0001367015473574622   1
#     Residual: 2.2340752438245823e-10   2
# Activation:  []
# Increment: 189    Initial Residual: 0.3823734346784314
#     Residual: 0.001899698124113836   0
#     Residual: 0.00025836904655149025   1
#     Residual: 7.2982083444215465e-09   2
#     Residual: 1.901328618677475e-10   3
# Activation:  []
# Increment: 190    Initial Residual: 0.37060396911360155
#     Residual: 0.0021460174224915514   0
#     Residual: 0.00010433883716342111   1
#     Residual: 2.8127972855123955e-10   2
# Activation:  []
# Increment: 191    Initial Residual: 0.35819055959551277
#     Residual: 0.0018724813385424782   0
#     Residual: 0.00031611219124292824   1
#     Residual: 9.825370642683448e-08   2
#     Residual: 2.7567504067178445e-10   3
# Activation:  []
# Increment: 192    Initial Residual: 0.346793847827294
#     Residual: 0.0022134062275818212   0
#     Residual: 4.435732588552035e-05   1
#     Residual: 1.3992238368968795e-08   2
#     Residual: 2.4235631735094615e-10   3
# Activation:  []
# Increment: 193    Initial Residual: 0.3357028097310925
#     Residual: 0.002442903820921084   0
#     Residual: 4.353680557008894e-06   1
#     Residual: 3.214535827285874e-10   2
# Activation:  []
# Increment: 194    Initial Residual: 0.32453297361959904
#     Residual: 0.0024311519900069105   0
#     Residual: 0.00010787999595921072   1
#     Residual: 2.246509230629119e-10   2
# Activation:  []
# Increment: 195    Initial Residual: 0.31419298245363564
#     Residual: 0.0017499931814413873   0
#     Residual: 7.274780324301167e-05   1
#     Residual: 3.177245906762161e-10   2
#     Residual: 2.3205348734739985e-10   3
# Activation:  []
# Increment: 196    Initial Residual: 0.3045175478899031
#     Residual: 0.0023744629735396776   0
#     Residual: 0.00021733474627852746   1
#     Residual: 3.7346682727536074e-10   2
#     Residual: 2.414108014735096e-10   3
# Activation:  []
# Increment: 197    Initial Residual: 0.2959335038898175
#     Residual: 0.002441107577310945   0
#     Residual: 0.00018964784151815717   1
#     Residual: 2.327794712133208e-10   2
# Activation:  []
# Increment: 198    Initial Residual: 0.2919790070303414
#     Residual: 0.0017450788973976273   0
#     Residual: 3.1607140290377e-05   1
#     Residual: 1.7928132295150384e-10   2
# Activation:  []
# Increment: 199    Initial Residual: 0.29059262560875915
#     Residual: 0.002188307774307852   0
#     Residual: 0.00011513033644830371   1
#     Residual: 3.1683236387244257e-10   2
#     Residual: 2.817746828383649e-10   3
# Activation:  []
# Increment: 200    Initial Residual: 0.29290959251796145
#     Residual: 0.0014546437416831798   0
#     Residual: 8.253674626704684e-06   1
#     Residual: 1.632809212854691e-10   2
# Activation:  []
# Increment: 201    Initial Residual: 0.2984229887105997
#     Residual: 0.001546678888090203   0
#     Residual: 0.00015687486851195085   1
#     Residual: 2.377902244943398e-10   2
# Activation:  []
# Increment: 202    Initial Residual: 0.30738656842271844
#     Residual: 0.0009848665598003042   0
#     Residual: 5.4937489455478e-10   1
#     Residual: 2.108330896466565e-10   2
# Activation:  []
# Increment: 203    Initial Residual: 0.32009498778332957
#     Residual: 0.001242887462790903   0
#     Residual: 3.870177112629535e-10   1
#     Residual: 3.5469913698575185e-10   2
#     Residual: 2.505060656725885e-10   3
# Activation:  []
# Increment: 204    Initial Residual: 0.3330880393412814
#     Residual: 0.0008466078578510988   0
#     Residual: 2.4461018515097374e-10   1
# Activation:  []
# Increment: 205    Initial Residual: 0.34517929776638706
#     Residual: 0.0007275735132434088   0
#     Residual: 6.412599567791114e-10   1
#     Residual: 2.5923435878053614e-10   2
# Activation:  []
# Increment: 206    Initial Residual: 0.35794767292486135
#     Residual: 0.0009652392261643819   0
#     Residual: 7.528325396406462e-06   1
#     Residual: 1.7906118978882092e-10   2
# Activation:  []
# Increment: 207    Initial Residual: 0.3711256062179056
#     Residual: 0.0007636685406418362   0
#     Residual: 2.003708138314902e-06   1
#     Residual: 3.4146639757728565e-10   2
# Activation:  []
# Increment: 208    Initial Residual: 0.3837485087262651
#     Residual: 0.0009294312289249789   0
#     Residual: 3.246066811604688e-06   1
#     Residual: 2.579798549534428e-10   2
# Activation:  []
# Increment: 209    Initial Residual: 0.395482172482173
#     Residual: 0.0008414739678191256   0
#     Residual: 4.909736927509396e-10   1
#     Residual: 2.0348080171632005e-10   2
# Activation:  []
# Increment: 210    Initial Residual: 0.40778687485582904
#     Residual: 0.0006278501468915521   0
#     Residual: 8.493229614838255e-06   1
#     Residual: 2.3594833916727593e-10   2
# Activation:  []
# Increment: 211    Initial Residual: 0.4190605287164755
#     Residual: 0.0007656220971810424   0
#     Residual: 1.697540753739304e-05   1
#     Residual: 1.6985190328403237e-10   2
# Activation:  []
# Increment: 212    Initial Residual: 0.4294406344285746
#     Residual: 0.0011357765314511867   0
#     Residual: 5.148500349502264e-09   1
#     Residual: 3.4371227126465217e-10   2
# Activation:  []
# Increment: 213    Initial Residual: 0.43677155988897737
#     Residual: 0.0012926391166611195   0
#     Residual: 0.0001303264147440428   1
#     Residual: 1.6955091146384614e-10   2
# Activation:  []
# Increment: 214    Initial Residual: 0.44196180544537234
#     Residual: 0.0010998429490579555   0
#     Residual: 0.0001327343001346741   1
#     Residual: 1.6468189826330076e-10   2
# Activation:  []
# Increment: 215    Initial Residual: 0.4452276253762741
#     Residual: 0.0009047378427931024   0
#     Residual: 1.202587539940841e-05   1
#     Residual: 1.3662484961785694e-10   2
# Activation:  []
# Increment: 216    Initial Residual: 0.4447175024488599
#     Residual: 0.0013516949669609285   0
#     Residual: 3.123752042428779e-05   1
#     Residual: 2.4607172111800064e-10   2
# ...
#     Residual: 0.0005786245708683949   0
#     Residual: 1.745258349175456e-10   1
# Activation:  [0.00032492 0.00032492]
# Increment: 313    Initial Residual: 0.2418741751551297
#     Residual: 0.0008103375120023912   0
#     Residual: 1.5578377996174966e-10   1
# Activation:  []
# Increment: 314    Initial Residual: 0.23911734118787356
#     Residual: 1.4940981732791186e-10   0
# Activation:  []
# Increment: 315    Initial Residual: 0.23567736801361544
#     Residual: 1.3028010684616961e-10   0
# Activation:  []
# Increment: 316    Initial Residual: 0.23079346697383987
#     Residual: 1.3839889324300825e-10   0
# Activation:  []
# Increment: 317    Initial Residual: 0.22526807268574503
#     Residual: 1.2762603197742563e-10   0
# Activation:  []
# Increment: 318    Initial Residual: 0.2196006053915139
#     Residual: 1.1296283189917442e-10   0
# Activation:  []
# Increment: 319    Initial Residual: 0.21366755891573186
#     Residual: 0.00041136038581921077   0
#     Residual: 9.488851674220379e-10   1
#     Residual: 1.4208058745185938e-10   2
# Activation:  []
# Increment: 320    Initial Residual: 0.20782025818335803
#     Residual: 0.00022256199220832402   0
#     Residual: 1.742821178699267e-10   1
# Activation:  []
# Increment: 321    Initial Residual: 0.20258591756027203
#     Residual: 0.00029652130715924894   0
#     Residual: 1.5685401328336462e-10   1
# Activation:  []
# Increment: 322    Initial Residual: 0.19757586169948854
#     Residual: 0.0006975256159285399   0
#     Residual: 1.6287350044107029e-10   1
# Activation:  []
# Increment: 323    Initial Residual: 0.19301594186717827
#     Residual: 0.00035393307972860394   0
#     Residual: 2.042060686583863e-10   1
#     Residual: 1.2028908319747228e-10   2
# Activation:  []
# Increment: 324    Initial Residual: 0.1890924059341852
#     Residual: 0.000558268771111724   0
#     Residual: 2.1012575146991884e-10   1
#     Residual: 1.3903006377932436e-10   2
# Activation:  []
# Increment: 325    Initial Residual: 0.18629851679653503
#     Residual: 0.00044816710537763416   0
#     Residual: 2.8829032608514086e-05   1
#     Residual: 1.5018985088832038e-10   2
# Activation:  []
# Increment: 326    Initial Residual: 0.18540336155289028
#     Residual: 0.00021110188147192404   0
#     Residual: 2.0737668081957296e-10   1
#     Residual: 1.7302162913942834e-10   2
# Activation:  []
# Increment: 327    Initial Residual: 0.18579621260513332
#     Residual: 0.0011361878456764033   0
#     Residual: 1.9261125992615176e-05   1
#     Residual: 1.149095232466656e-10   2
# Activation:  [0.00040934 0.00040934]
# Increment: 328    Initial Residual: 0.18769872690099842
#     Residual: 0.000250881164382922   0
#     Residual: 1.6082428679685713e-10   1
# Activation:  [0.00012068 0.00012068]
# Increment: 329    Initial Residual: 0.1923896353460289
#     Residual: 0.000997590205821521   0
#     Residual: 1.6673529726864017e-10   1
# Activation:  []
# Increment: 330    Initial Residual: 0.1989533464457579
#     Residual: 1.1667084747047614e-10   0
# Activation:  []
# Increment: 331    Initial Residual: 0.20647172427225774
#     Residual: 1.2747017806822282e-10   0
# Activation:  []
# Increment: 332    Initial Residual: 0.21410364337760887
#     Residual: 1.8333764101188088e-10   0
# Activation:  []
# Increment: 333    Initial Residual: 0.22087624034770087
#     Residual: 1.502569079595263e-10   0
# Activation:  []
# Increment: 334    Initial Residual: 0.22788756779994673
#     Residual: 1.4603961612468215e-10   0
# Activation:  []
# Increment: 335    Initial Residual: 0.23423612856772064
#     Residual: 1.9342031059557221e-10   0
# Activation:  []
# Increment: 336    Initial Residual: 0.239146607231372
#     Residual: 1.572149787845703e-10   0
# Activation:  []
# Increment: 337    Initial Residual: 0.24384266615483807
#     Residual: 1.4692298129969214e-10   0
# Activation:  []
# Increment: 338    Initial Residual: 0.24699767476953602
#     Residual: 1.3630286600816386e-10   0
# Activation:  []
# Increment: 339    Initial Residual: 0.2508090044054115
#     Residual: 1.6775937917151113e-10   0
# Activation:  []
# Increment: 340    Initial Residual: 0.2521258327384976
#     Residual: 1.3879648637677203e-10   0
# Activation:  []
# Increment: 341    Initial Residual: 0.2500256398351411
#     Residual: 8.86693899779244e-05   0
#     Residual: 1.322803034069402e-10   1
# Activation:  []
# Increment: 342    Initial Residual: 0.24715139212069456
#     Residual: 0.0002656610755017075   0
#     Residual: 1.8075461911435222e-10   1
# Activation:  []
# Increment: 343    Initial Residual: 0.2406309610883467
#     Residual: 0.0007088249057821542   0
#     Residual: 1.6389086456275172e-10   1
# Activation:  []
# Increment: 344    Initial Residual: 0.23155988093520022
#     Residual: 0.0007315280145657717   0
#     Residual: 4.6176124383058025e-05   1
#     Residual: 2.2005278812092655e-10   2
# Activation:  []
# Increment: 345    Initial Residual: 0.22186606583219626
#     Residual: 0.0011721198606429383   0
#     Residual: 0.00037967870499245243   1
#     Residual: 2.8953717795243244e-10   2
#     Residual: 1.8349858176694766e-10   3
# Activation:  [0.00014003 0.00014003]
# Increment: 346    Initial Residual: 0.210159832874309
#     Residual: 0.0011089999326644796   0
#     Residual: 4.480484459126809e-06   1
#     Residual: 1.9056172496954085e-10   2
# Activation:  [0.00019456 0.00019456]
# Increment: 347    Initial Residual: 0.19795556912455048
#     Residual: 0.0009238079028360051   0
#     Residual: 1.0085001824143065e-05   1
#     Residual: 1.115128513046605e-10   2
# Activation:  [0.00021678 0.00021678]
# Increment: 348    Initial Residual: 0.18528067938868797
#     Residual: 0.0013307946320314276   0
#     Residual: 1.9116581284041126e-05   1
#     Residual: 1.7374845765462983e-10   2
# Activation:  [0.00010289 0.00010289]
# Increment: 349    Initial Residual: 0.17121340714127595
#     Residual: 0.0012063481782155685   0
#     Residual: 0.00023683536798474694   1
#     Residual: 1.6304843867344482e-10   2
# Activation:  []
# Increment: 350    Initial Residual: 0.1576142555667572
#     Residual: 0.0008727580667651817   0
#     Residual: 3.9885117482999086e-05   1
#     Residual: 1.1878976411961022e-10   2
# Activation:  []
# Increment: 351    Initial Residual: 0.1442782065893293
#     Residual: 0.0012803342687148444   0
#     Residual: 0.00011673963465065459   1
#     Residual: 1.1978345980846998e-10   2
# Activation:  []
# Increment: 352    Initial Residual: 0.1298319873295786
#     Residual: 0.0008953708115204293   0
#     Residual: 1.253583233977805e-05   1
#     Residual: 3.795638982054454e-08   2
#     Residual: 5.746259778860635e-08   3
#     Residual: 9.761537903560841e-07   4
# Activation:  []
# Increment: 353    Initial Residual: 0.11397392715730296
#     Residual: 0.0008916562820606813   0
#     Residual: 2.757375724544508e-10   1
#     Residual: 1.3963216329465694e-10   2
#     Residual: 1.3694093288009545e-10   3
#     Residual: 9.018058815249771e-11   4
# Activation:  []
# Increment: 354    Initial Residual: 0.09839142120522985
#     Residual: 0.0012706026939880873   0
#     Residual: 0.0001148431353867387   1
#     Residual: 1.0555709804354218e-10   2
#     Residual: 8.74409710428256e-11   3
# Activation:  []
# Increment: 355    Initial Residual: 0.08649628733829814
#     Residual: 0.0005956718230410945   0
#     Residual: 5.867468764749142e-05   1
#     Residual: 1.395183849321643e-10   2
#     Residual: 9.080820285103654e-11   3
#     Residual: 8.781163976717455e-11   4
# Activation:  []
# Increment: 356    Initial Residual: 0.0807562084604304
#     Residual: 0.0007811003020540953   0
#     Residual: 2.885623046080366e-06   1
#     Residual: 1.2764660292738174e-10   2
#     Residual: 1.5593617381858674e-10   3
#     Residual: 2.4651592636801687e-10   4
# Activation:  []
# Increment: 357    Initial Residual: 0.07832620962858079
#     Residual: 0.0006778490978499897   0
#     Residual: 7.781007347422432e-10   1
#     Residual: 1.137358775949259e-10   2
#     Residual: 1.0775774948202501e-10   3
#     Residual: 1.1787655325453157e-10   4
# Activation:  []
# Increment: 358    Initial Residual: 0.08169509603951891
#     Residual: 0.0006345944477839685   0
#     Residual: 1.6068179189121066e-10   1
#     Residual: 1.2248992498106362e-10   2
#     Residual: 1.0443360876001055e-10   3
#     Residual: 1.0308358967233637e-10   4
# Activation:  []
# Increment: 359    Initial Residual: 0.09142345103789344
#     Residual: 0.0001279383842749203   0
#     Residual: 1.593773299003706e-10   1
#     Residual: 1.221452298101821e-10   2
#     Residual: 1.3038117728412981e-10   3
#     Residual: 1.1681728095154385e-10   4
# Activation:  []
# Increment: 360    Initial Residual: 0.10172118116710409
#     Residual: 9.531292085252651e-05   0
#     Residual: 1.6157428861844865e-10   1
#     Residual: 1.0879138408923749e-10   2
#     Residual: 1.6401991642284232e-10   3
#     Residual: 1.7722651537111903e-10   4
# Activation:  []
# Increment: 361    Initial Residual: 0.11182676775926333
#     Residual: 1.2179876113987718e-10   0
#     Residual: 1.4608303378714472e-10   1
#     Residual: 1.0601498378308093e-10   2
# Activation:  []
# Increment: 362    Initial Residual: 0.12136821332803757
#     Residual: 1.7586513160788091e-10   0
#     Residual: 9.879993879104808e-11   1
# Activation:  []
# Increment: 363    Initial Residual: 0.12986371564206287
#     Residual: 0.00020956601485964615   0
#     Residual: 1.2147573597690377e-10   1
# Activation:  []
# Increment: 364    Initial Residual: 0.13990490939713304
#     Residual: 6.197409909379578e-05   0
#     Residual: 1.7958484816450714e-10   1
#     Residual: 2.053427624211179e-10   2
#     Residual: 1.942904185646801e-10   3
#     Residual: 2.024805481433673e-10   4
# Activation:  []
# Increment: 365    Initial Residual: 0.14903803149325923
#     Residual: 0.0004661716469550031   0
#     Residual: 2.9388988599889034e-10   1
#     Residual: 1.3027030284756833e-10   2
# Activation:  []
# Increment: 366    Initial Residual: 0.1566833075703413
#     Residual: 0.00015634189239292483   0
#     Residual: 1.5447599644758028e-10   1
# Activation:  []
# Increment: 367    Initial Residual: 0.16325449312095053
#     Residual: 0.00025373086833831426   0
#     Residual: 2.2632368042182e-06   1
#     Residual: 1.0921828395177694e-10   2
# Activation:  []
# Increment: 368    Initial Residual: 0.17042362902843078
#     Residual: 0.00028282054383200485   0
#     Residual: 5.228117357925295e-05   1
#     Residual: 8.407726055881564e-11   2
# Activation:  []
# Increment: 369    Initial Residual: 0.1758651699593563
#     Residual: 0.0003128542331559258   0
#     Residual: 3.296109305147037e-05   1
#     Residual: 1.186287820159358e-10   2
# Activation:  []
# Increment: 370    Initial Residual: 0.17793782456660723
#     Residual: 0.00026005441990387015   0
#     Residual: 1.023564853439371e-09   1
#     Residual: 1.2482135858810847e-10   2
# Activation:  []
# Increment: 371    Initial Residual: 0.17718021970255024
#     Residual: 0.00024308061378523684   0
#     Residual: 1.971215020518402e-05   1
#     Residual: 8.928807705117091e-11   2
# Activation:  []
# Increment: 372    Initial Residual: 0.17498750721843187
#     Residual: 0.0002652910806870717   0
#     Residual: 1.2680339462874334e-10   1
# Activation:  []
# Increment: 373    Initial Residual: 0.17236709511911294
#     Residual: 0.00030200380035196424   0
#     Residual: 7.69761074928294e-06   1
#     Residual: 1.7813968021739986e-10   2
#     Residual: 1.5955955865352809e-10   3
# Activation:  []
# Increment: 374    Initial Residual: 0.1684482797205701
#     Residual: 0.000225310289862613   0
#     Residual: 5.424197779041535e-06   1
#     Residual: 1.2976877932837254e-10   2
# Activation:  []
# Increment: 375    Initial Residual: 0.16471858590138785
#     Residual: 0.00028872789248154967   0
#     Residual: 1.5083135108674493e-10   1
# Activation:  []
# Increment: 376    Initial Residual: 0.15984332377749938
#     Residual: 0.00017605656658601425   0
#     Residual: 1.133434502994181e-06   1
#     Residual: 1.2689288720074462e-10   2
# Activation:  []
# Increment: 377    Initial Residual: 0.1554227528201111
#     Residual: 0.0005418402689151045   0
#     Residual: 6.72970808846484e-09   1
#     Residual: 1.1133013649271305e-10   2
# Activation:  []
# Increment: 378    Initial Residual: 0.1504207598179401
#     Residual: 0.0005744379649064437   0
#     Residual: 1.4815221064710124e-10   1
# Activation:  []
# Increment: 379    Initial Residual: 0.14518105750477897
#     Residual: 0.0005820748511738619   0
#     Residual: 7.230008535069756e-05   1
#     Residual: 1.4285333722144158e-10   2
# Activation:  []
# Increment: 380    Initial Residual: 0.13977150697210378
#     Residual: 0.00039997736483060034   0
#     Residual: 1.8909887545308392e-10   1
#     Residual: 1.3628167336602039e-10   2
# Activation:  []
# Increment: 381    Initial Residual: 0.13447942334093055
#     Residual: 0.0006939219342564535   0
#     Residual: 6.932859865434901e-06   1
#     Residual: 2.2682211619140296e-10   2
#     Residual: 1.638064115639821e-10   3
#     Residual: 2.0568582387744237e-10   4
# Activation:  []
# Increment: 382    Initial Residual: 0.12897555152634815
#     Residual: 0.0006124482679789215   0
#     Residual: 4.6000188532643246e-05   1
#     Residual: 1.6511977630005705e-10   2
#     Residual: 1.5783484974762767e-10   3
#     Residual: 1.0779651520953327e-10   4
# Activation:  []
# Increment: 383    Initial Residual: 0.12403030016510173
#     Residual: 0.00032873642094425964   0
#     Residual: 3.245495118939607e-05   1
#     Residual: 9.36756459652159e-11   2
# Activation:  []
# Increment: 384    Initial Residual: 0.12198015421159791
#     Residual: 0.0004127312523440255   0
#     Residual: 2.9577481929647043e-09   1
#     Residual: 1.3066148356665044e-10   2
#     Residual: 1.4347951583984324e-10   3
#     Residual: 1.618592996853332e-10   4
# Activation:  []
# Increment: 385    Initial Residual: 0.12258219337859604
#     Residual: 0.0002896307330534942   0
#     Residual: 2.0302321415046867e-10   1
#     Residual: 1.3964389665291842e-10   2
#     Residual: 1.283351643269196e-10   3
#     Residual: 1.324553684200584e-10   4
# Activation:  []
# Increment: 386    Initial Residual: 0.12495333016212264
#     Residual: 0.00023035712271232456   0
#     Residual: 1.333826895032101e-10   1
#     Residual: 1.7796782703933376e-10   2
#     Residual: 1.4071993119999195e-10   3
#     Residual: 9.863380269689027e-11   4
# Activation:  []
# Increment: 387    Initial Residual: 0.1276417959543715
#     Residual: 0.00016499432106446862   0
#     Residual: 1.4063848193878159e-10   1
#     Residual: 1.1229586205212978e-10   2
# Activation:  []
# Increment: 388    Initial Residual: 0.13127527827289967
#     Residual: 9.92604197381481e-11   0
# Activation:  []
# Increment: 389    Initial Residual: 0.13634113545858417
#     Residual: 1.0831049910641378e-10   0
# Activation:  []
# Increment: 390    Initial Residual: 0.14073783704000342
#     Residual: 1.3338264389850578e-10   0
# Activation:  []
# Increment: 391    Initial Residual: 0.14427736593926005
#     Residual: 0.00030921807155250247   0
#     Residual: 2.0047665753498197e-10   1
#     Residual: 1.1252886369010825e-10   2
# Activation:  []
# Increment: 392    Initial Residual: 0.14732245219792436
#     Residual: 7.251020209871502e-05   0
#     Residual: 1.1421702207099789e-10   1
# Activation:  []
# Increment: 393    Initial Residual: 0.15084403796841764
#     Residual: 1.177935199330753e-10   0
# Activation:  []
# Increment: 394    Initial Residual: 0.15526613727010757
#     Residual: 1.115926020947433e-10   0
# Activation:  []
# Increment: 395    Initial Residual: 0.1594184765298066
#     Residual: 0.0002796498647203785   0
#     Residual: 3.523830342866742e-10   1
#     Residual: 1.164349436170267e-10   2
# Activation:  []
# Increment: 396    Initial Residual: 0.16295452434952276
#     Residual: 0.00013237491274244848   0
#     Residual: 1.4503903660384232e-10   1
# Activation:  []
# Increment: 397    Initial Residual: 0.1660475541405671
#     Residual: 0.00016791020433255192   0
#     Residual: 1.2451976252618407e-10   1
# Activation:  []
# Increment: 398    Initial Residual: 0.16980904937743782
#     Residual: 0.000308558115652959   0
#     Residual: 1.3121643063086261e-10   1
# Activation:  []
# Increment: 399    Initial Residual: 0.17211604263610866
#     Residual: 0.00018797266603406293   0
#     Residual: 1.3482768363921085e-10   1
# Activation:  []
# Increment: 400    Initial Residual: 0.17355437681273994
#     Residual: 0.00019080186100971577   0
#     Residual: 1.411940775190934e-10   1
# Activation:  []

# %% [markdown]
# # Visualization

# %%
# %matplotlib notebook

from matplotlib.animation import FuncAnimation

# %%
# MPII
# 2*float(mu)*float(sig0)*np.log(1+abs(results[:N_pt, 4])/float(sig0))\
#           *abs(results[:N_pt, 4])/results[:N_pt, 4]

# Simple case
# 2*float(mu)*results[:N_pt, 4]*(1+ (2*results[:N_pt, 4]/float(sig0))**2 )

N_pt = 500;
stress_theo = 2*float(mu)*float(sig0)*np.log(1+abs(results[:N_pt, 4])/float(sig0))\
            *abs(results[:N_pt, 4])/results[:N_pt, 4]
stress_lin = 2*float(mu)*results[:N_pt, 4]
# Out:
# /tmp/ipykernel_65276/1685967887.py:9: RuntimeWarning: invalid value encountered in true_divide
#   stress_theo = 2*float(mu)*float(sig0)*np.log(1+abs(results[:N_pt, 4])/float(sig0))\

# %%
import matplotlib.pyplot as plt
plt.subplots()
plt.subplot(1,4,1)
plt.plot(results[:, 0], results[:, 1], "-*")
# plt.plot(results[:, 0], results[:, 3]*0.5*q_lim, ".")
plt.xlabel("Displacement")
plt.ylabel("$\sigma_{xx,yy}$ at the right end")
# plt.legend(["$\sigma_{yy}$","$\sigma_{xx}$","Loads"])
plt.subplot(1,4,2)
plt.plot(results[:, 2], results[:, 1], "-.")
# plt.plot(results[:, 2], results[:, 3]*0.5*q_lim, ".")
plt.xlabel("Loading steps")
plt.ylabel("$\sigma_{xx}$ at the right end")
# plt.legend(["$\sigma_{yy}$","Loads"])
plt.subplot(1,4,3)
plt.plot(results[:, 2], results[:, 0], "-.")
plt.xlabel("Time")
plt.ylabel("Displacement at the right end")
plt.subplot(1,4,4)
plt.plot(results[:, 4], results[:, 1], "-")
# plt.plot(results[:, 4], stress_theo, "-")
plt.xlabel("Strain and the right end")
plt.ylabel("Stress at the right end")
# plt.plot(sample_MP*strain_ref_MP,sqrt(2)*k_MP)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1556">

# %%
plt.subplots()

plt.plot(results[:, 2],results_2d[:, 0]/(1e-10+results_2d[:, 0]), ".")
plt.plot(results[:, 2],results_2d[:, 4]/(1e-10+results_2d[:, 4]), ".")


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()

line, = ax.plot([])

ax.set_xlim(0,1)
ax.set_ylim(-0.1e-5,0.1e-5)

def animate(frame_num):
    # ax.clear()
    line.set_data((np.linspace(0,1,50), results_1d[frame_num, :]))
    return line

ani = FuncAnimation(fig, animate, frames=Nincr, interval=10)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
