# %%
from dolfin import *
import numpy as np
import matplotlib.pyplot as plt
set_log_level(30)

# %%
# %matplotlib notebook

from matplotlib.animation import FuncAnimation

from matplotlib import animation

import math

import time

# %% [markdown]
# # BC 1

# %%
# parameters["ghost_mode"] = "shared_facet"

# compare upwind flux with lax-friedrichs flux
lx = 1
m_size = lx*80
mesh = IntervalMesh(m_size, 0.0, lx)

# Material properties
mu = Constant(14e9)
rho = Constant(2.2e3)
gamma = Constant(10)
tau_min = 1e-3
tau_max = 10e-3
tau = tau_min*gamma # \tau_1 in the literature


beta_E = 50
delta_E = 1e8

delta_t = 1e-6
t_total = 10e-3

t_excitation = 40e-3

fc = 5e3

A_amp = 1.5e-6

g0 = 1e-2

deg_dg = 1 # DG degree

def mu_fun(eps):
    return mu * (1 - 2*beta_E*eps - 3 * delta_E*eps*eps)

def stress_fun(eps):
    return mu * eps * (1 - beta_E*eps - delta_E*eps*eps)

def energy_fun(eps):
    return mu * eps * eps * (0.5 - beta_E/3*eps  - delta_E/4*eps*eps)

EPS_SMALL = 1e-4
def phig_fun(g_inti):
    return g_inti/(tau_max*(exp(-g_inti/g0*math.log(tau_max/tau_min)))\
                            *(g_inti/g0*math.log(tau_max/tau_min)* (1-ln(g_inti/g0+EPS_SMALL)) + 1) \
                    + tau_min*(g_inti)/g0*math.log(tau_max/tau_min) )

A_amp1 = float(stress_fun(A_amp)/rho)

def flux_fun(q_f):
    (eps,vel, g_int) = split(q_f)
    return as_vector([-vel('+'), -(1-g_int('+'))*stress_fun(eps('+'))/rho ,0]) \
           + as_vector([-vel('-'), -(1-g_int('-'))*stress_fun(eps('-'))/rho ,0])

def AStar_fun(q_f):
    (eps, vel, g_int) = split(q_f)
    a = (1 - 0.5*(g_int('+')+g_int('-')) ) * mu_fun((eps('+')+eps('-'))*0.5)/rho
    b = stress_fun((eps('+')+eps('-'))*0.5)/rho
    RStar = as_tensor([[1, 1, b], \
                       [sqrt(a), -sqrt(a), 0], \
                       [0, 0, a]])
    RStar_inv = as_tensor([[1/2, 1/2/sqrt(a), -b/a/2], \
                           [1/2, -1/2/sqrt(a), -b/a/2], \
                           [0, 0, 1/a]])
    Lamb = as_tensor([[sqrt(a), 0, 0], \
                      [0, sqrt(a), 0], \
                      [0, 0, 0]])
    return dot(dot(RStar,Lamb),RStar_inv)

# Function space
Ee = FiniteElement("DG", mesh.ufl_cell(), deg_dg)
Ve = FiniteElement("DG", mesh.ufl_cell(), deg_dg)
Ge = FiniteElement("DG", mesh.ufl_cell(), deg_dg)
V_dg = FunctionSpace(mesh, MixedElement([Ee, Ve, Ge]))

phi, v = TrialFunction(V_dg), TestFunction(V_dg)
q_new, q_old = Function(V_dg), Function(V_dg)
q_rk = Function(V_dg)

q0 = Expression(("0","0","0"), degree=1, t=0, name='q0') # 
q_old = project(q0, V_dg)

v_exact = Expression("(t<tc1 ) ? A*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ", \
                     degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp, lx = lx) # 

v_exact2 = Expression("(t<tc1 ) ? A*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ", \
                     degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp1, lx = lx) # 

v_exactr = Expression(" 0 ", \
                     degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp, lx = lx) # 

f_ext = Expression(("0", "(t<tc1 ) ? -A*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ", "0"), \
                   degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp1, lx = lx) #

DOFIN_EPS = 1e-10 # + lx/m_size/2
if deg_dg == 0: DOFIN_EPS = 1e-10 + lx/m_size/2
def left(x, on_boundary):
    return abs(x[0]-0.) < DOFIN_EPS
def right(x, on_boundary):
    return abs(x[0]-lx) < DOFIN_EPS


bc =  [DirichletBC(V_dg.sub(0), v_exact, left, method="pointwise"),\
       DirichletBC(V_dg.sub(0), v_exactr, right, method="pointwise"),\
       DirichletBC(V_dg.sub(1), v_exactr, right, method="pointwise"),\
       DirichletBC(V_dg.sub(2), v_exactr, right, method="pointwise")]

# Weak form
n = FacetNormal(mesh)

(eps1,vel1, g_int1) = split(q_old)
mu1 = mu_fun(eps1)
sig1 = stress_fun(eps1)

c_speed1 = sqrt((1-g_int1)*mu1/rho)

W_energy1 = energy_fun(eps1)

A_adv1 = as_tensor([[0, -1, 0], \
                    [-(1-g_int1)*mu1/rho, 0, sig1/rho], \
                    [0, 0, 0]])

R1 = as_tensor([[1, 1, sig1/rho], \
                [c_speed1, -c_speed1, 0], \
                [0,0,c_speed1*c_speed1]])
R_inv1 = as_tensor([[1/2, 1/c_speed1/2, -sig1/rho/c_speed1/c_speed1/2], \
                    [1/2, -1/c_speed1/2, -sig1/rho/c_speed1/c_speed1/2], \
                    [0, 0, 1/c_speed1/c_speed1] ])
Lambda_adv_abs1 = as_tensor([[c_speed1, 0, 0], \
                             [0, c_speed1, 0], \
                             [0, 0, 0] ])

A_adv_abs1 = dot( dot(R1, Lambda_adv_abs1), R_inv1)

A_adv_plus1 = (A_adv1 + A_adv_abs1)/2
A_adv_minus1 = (A_adv1 - A_adv_abs1)/2

F = dot( (phi-q_old)/delta_t, v) * dx 

flux_inner1 = as_vector([-vel1, -(1-g_int1)*sig1/rho, 0])
# F1 = F - dot(dot(A_adv1,q_old), grad(v)[:,0]) * dx
F1 = F - dot(flux_inner1, grad(v)[:,0]) * dx

r1 = as_vector([0, 0, 1/tau*W_energy1 - phig_fun(g_int1)])
F1 += - dot(r1, v) * dx

flux1 = dot(A_adv_plus1('+'), q_old('+')) + dot(A_adv_minus1('-'), q_old('-'))

# Roe solver
flux1 = 0.5*( flux_fun(q_old) \
             - dot( AStar_fun(q_old), q_old('-')-q_old('+')  ) ) 

F1 += dot( flux1*n('+')[0], jump(v)) * dS + dot(f_ext,v)*n[0] * ds

(eps2,vel2, g_int2) = split(q_rk)
mu2 = mu_fun(eps2)
sig2 = stress_fun(eps2)

c_speed2 = sqrt((1-g_int2)*mu2/rho)

W_energy2 = energy_fun(eps2)

A_adv2 = as_tensor([[0, -1, 0], \
                    [-(1-g_int2)*mu2/rho, 0, sig2/rho], \
                    [0, 0, 0]])

R2 = as_tensor([[1, 1, sig2/rho], \
                [c_speed2, -c_speed2, 0], \
                [0,0,c_speed2*c_speed2]])
R_inv2 = as_tensor([[1/2, 1/c_speed2/2, -sig2/rho/c_speed2/c_speed2/2], \
                    [1/2, -1/c_speed2/2, -sig2/rho/c_speed2/c_speed2/2], \
                    [0, 0, 1/c_speed2/c_speed2] ])
Lambda_adv_abs2 = as_tensor([[c_speed2, 0, 0], \
                             [0, c_speed2, 0], \
                             [0, 0, 0] ])

A_adv_abs2 = dot( dot(R2, Lambda_adv_abs2), R_inv2)

A_adv_plus2 = (A_adv2 + A_adv_abs2)/2
A_adv_minus2 = (A_adv2 - A_adv_abs2)/2

flux_inner2 = as_vector([-vel2, -(1-g_int2)*sig2/rho, 0])
# F2 = - dot(dot(A_adv2,q_rk), grad(v)[:,0]) * dx
F2 = - dot(flux_inner2, grad(v)[:,0]) * dx

r2 = as_vector([0, 0, 1/tau*W_energy2 - phig_fun(g_int2)])

F2 += - dot(r2, v) * dx

flux2 = dot(A_adv_plus2('+'), q_rk('+')) + dot(A_adv_minus2('-'), q_rk('-'))

# Roe solver
flux2 = 0.5*( flux_fun(q_rk) \
            - dot( AStar_fun(q_rk), q_rk('-')-q_rk('+')  ) ) 

F2 += dot( flux2*n('+')[0], jump(v)) * dS + dot(f_ext,v)*n[0] * ds

F += 0.5*((F1-F) + F2)

#===========
Sta1 = time.time()
T_sol = 0
#===========

t = 0
time_steps = int(t_total/delta_t)
uuu1 = np.zeros((time_steps,m_size,3))

a1,L1 = lhs(F1),rhs(F1)
a,L = lhs(F),rhs(F)

for n in range(time_steps):
    print('===============')
    print('Time step:',n)
    
    for i in range(m_size):
        uuu1[n,i,:] = q_old(i/(m_size-1)*lx)[:]
    
 
    T_incre1 = time.time()
    solve(a1==L1, q_new, bc)
    T_incre2 = time.time()
    T_sol += T_incre2-T_incre1
    q_rk.assign(q_new)
        
    
    T_incre1 = time.time()
    solve(a==L, q_new, bc)
    T_incre2 = time.time()
    T_sol += T_incre2-T_incre1
    q_old.assign(q_new)
    print('Strain:',q_old(0)[0])

    t += delta_t
    v_exact.t = t
    f_ext.t = t

T_total = time.time()-Sta1

plt.subplots()
plot(q_old[2])
plt.show()

print("Total time:",T_total)
print("Solving time:",T_sol)
# Out:
# ===============
# Time step: 0
# Strain: 0.0
# ===============
# Time step: 1
# Strain: 4.711613861719244e-08
# ===============
# Time step: 2
# Strain: 9.418577929397006e-08
# ===============
# Time step: 3
# Strain: 1.411624699777715e-07
# ===============
# Time step: 4
# Strain: 1.8799985034645638e-07
# ===============
# Time step: 5
# Strain: 2.346516975603463e-07
# ===============
# Time step: 6
# Strain: 2.8107197187858685e-07
# ===============
# Time step: 7
# Strain: 3.272148620948138e-07
# ===============
# Time step: 8
# Strain: 3.730348307472822e-07
# ===============
# Time step: 9
# Strain: 4.1848665905884395e-07
# ===============
# Time step: 10
# Strain: 4.635254915624211e-07
# ===============
# Time step: 11
# Strain: 5.081068803679372e-07
# ===============
# Time step: 12
# Strain: 5.52186829027017e-07
# ===============
# Time step: 13
# Strain: 5.95721835952171e-07
# ===============
# Time step: 14
# Strain: 6.386689373476092e-07
# ===============
# Time step: 15
# Strain: 6.809857496093203e-07
# ===============
# Time step: 16
# Strain: 7.22630511152573e-07
# ===============
# Time step: 17
# Strain: 7.63562123625557e-07
# ===============
# Time step: 18
# Strain: 8.03740192468495e-07
# ===============
# Time step: 19
# Strain: 8.431250667781961e-07
# ===============
# Time step: 20
# Strain: 8.816778784387099e-07
# ===============
# Time step: 21
# Strain: 9.193605804794649e-07
# ===============
# Time step: 22
# Strain: 9.561359846230348e-07
# ===============
# Time step: 23
# Strain: 9.919677979854781e-07
# ===============
# Time step: 24
# Strain: 1.0268206588930332e-06
# ===============
# Time step: 25
# Strain: 1.0606601717798216e-06
# ===============
# Time step: 26
# Strain: 1.0934529411321173e-06
# ===============
# Time step: 27
# Strain: 1.1251666044456895e-06
# ===============
# Time step: 28
# Strain: 1.155769864163684e-06
# ===============
# Time step: 29
# Strain: 1.1852325185635358e-06
# ===============
# Time step: 30
# Strain: 1.2135254915624213e-06
# ===============
# Time step: 31
# Strain: 1.240620861411843e-06
# ===============
# Time step: 32
# Strain: 1.2664918882530226e-06
# ===============
# Time step: 33
# Strain: 1.2911130405059155e-06
# ===============
# Time step: 34
# Strain: 1.3144600200657955e-06
# ===============
# Time step: 35
# Strain: 1.3365097862825517e-06
# ===============
# Time step: 36
# Strain: 1.3572405786990293e-06
# ===============
# Time step: 37
# Strain: 1.3766319385259716e-06
# ===============
# Time step: 38
# Strain: 1.3946647288323769e-06
# ===============
# Time step: 39
# Strain: 1.411321153431338e-06
# ===============
# Time step: 40
# Strain: 1.4265847744427302e-06
# ===============
# Time step: 41
# Strain: 1.4404405285154143e-06
# ===============
# Time step: 42
# Strain: 1.4528747416929463e-06
# ===============
# Time step: 43
# Strain: 1.4638751429081209e-06
# ===============
# Time step: 44
# Strain: 1.4734308760930327e-06
# ===============
# Time step: 45
# Strain: 1.4815325108927063e-06
# ===============
# Time step: 46
# Strain: 1.4881720519717166e-06
# ===============
# Time step: 47
# Strain: 1.4933429469046199e-06
# ===============
# Time step: 48
# Strain: 1.4970400926424071e-06
# ===============
# Time step: 49
# Strain: 1.4992598405485972e-06
# ===============
# Time step: 50
# Strain: 1.5e-06
# ===============
# Time step: 51
# Strain: 1.4992598405485974e-06
# ===============
# Time step: 52
# Strain: 1.4970400926424076e-06
# ===============
# Time step: 53
# Strain: 1.4933429469046203e-06
# ===============
# Time step: 54
# Strain: 1.488172051971717e-06
# ===============
# Time step: 55
# Strain: 1.4815325108927072e-06
# ===============
# Time step: 56
# Strain: 1.4734308760930336e-06
# ===============
# Time step: 57
# Strain: 1.463875142908122e-06
# ===============
# Time step: 58
# Strain: 1.4528747416929475e-06
# ===============
# Time step: 59
# Strain: 1.4404405285154156e-06
# ===============
# Time step: 60
# Strain: 1.4265847744427315e-06
# ===============
# Time step: 61
# Strain: 1.4113211534313396e-06
# ===============
# Time step: 62
# Strain: 1.3946647288323786e-06
# ===============
# Time step: 63
# Strain: 1.3766319385259733e-06
# ===============
# Time step: 64
# Strain: 1.3572405786990312e-06
# ===============
# Time step: 65
# Strain: 1.3365097862825536e-06
# ===============
# Time step: 66
# Strain: 1.3144600200657976e-06
# ===============
# Time step: 67
# Strain: 1.2911130405059178e-06
# ===============
# Time step: 68
# Strain: 1.2664918882530253e-06
# ===============
# Time step: 69
# Strain: 1.2406208614118452e-06
# ===============
# Time step: 70
# Strain: 1.213525491562424e-06
# ===============
# Time step: 71
# Strain: 1.1852325185635385e-06
# ===============
# Time step: 72
# Strain: 1.155769864163687e-06
# ===============
# Time step: 73
# Strain: 1.125166604445693e-06
# ===============
# Time step: 74
# Strain: 1.093452941132121e-06
# ===============
# Time step: 75
# Strain: 1.0606601717798252e-06
# ===============
# Time step: 76
# Strain: 1.0268206588930372e-06
# ===============
# Time step: 77
# Strain: 9.919677979854823e-07
# ===============
# Time step: 78
# Strain: 9.56135984623039e-07
# ===============
# Time step: 79
# Strain: 9.193605804794699e-07
# ===============
# Time step: 80
# Strain: 8.816778784387148e-07
# ===============
# Time step: 81
# Strain: 8.431250667782013e-07
# ===============
# Time step: 82
# Strain: 8.037401924685006e-07
# ===============
# Time step: 83
# Strain: 7.63562123625563e-07
# ===============
# Time step: 84
# Strain: 7.226305111525787e-07
# ===============
# Time step: 85
# Strain: 6.809857496093263e-07
# ===============
# Time step: 86
# Strain: 6.386689373476154e-07
# ===============
# Time step: 87
# Strain: 5.957218359521771e-07
# ===============
# Time step: 88
# Strain: 5.52186829027024e-07
# ===============
# Time step: 89
# Strain: 5.081068803679439e-07
# ===============
# Time step: 90
# Strain: 4.6352549156242826e-07
# ===============
# Time step: 91
# Strain: 4.1848665905885136e-07
# ===============
# Time step: 92
# Strain: 3.7303483074729e-07
# ===============
# Time step: 93
# Strain: 3.2721486209482125e-07
# ===============
# Time step: 94
# Strain: 2.8107197187859537e-07
# ===============
# Time step: 95
# Strain: 2.346516975603544e-07
# ===============
# Time step: 96
# Strain: 1.8799985034646477e-07
# ===============
# Time step: 97
# Strain: 1.4116246997778014e-07
# ===============
# Time step: 98
# Strain: 9.418577929397835e-08
# ===============
# Time step: 99
# Strain: 4.7116138617201013e-08
# ===============
# Time step: 100
# Strain: 8.843436611948324e-21
# ===============
# Time step: 101
# Strain: -4.7116138617184e-08
# ===============
# Time step: 102
# Strain: -9.418577929396069e-08
# ===============
# Time step: 103
# Strain: -1.4116246997776188e-07
# ===============
# Time step: 104
# Strain: -1.879998503464472e-07
# ===============
# Time step: 105
# Strain: -2.3465169756033693e-07
# ===============
# Time step: 106
# Strain: -2.81071971878578e-07
# ===============
# Time step: 107
# Strain: -3.272148620948047e-07
# ===============
# Time step: 108
# Strain: -3.730348307472722e-07
# ===============
# Time step: 109
# Strain: -4.184866590588337e-07
# ===============
# Time step: 110
# Strain: -4.635254915624114e-07
# ===============
# Time step: 111
# Strain: -5.081068803679272e-07
# ===============
# Time step: 112
# Strain: -5.521868290270076e-07
# ===============
# Time step: 113
# Strain: -5.957218359521615e-07
# ===============
# Time step: 114
# Strain: -6.386689373475988e-07
# ===============
# Time step: 115
# Strain: -6.809857496093105e-07
# ===============
# Time step: 116
# Strain: -7.226305111525631e-07
# ===============
# Time step: 117
# Strain: -7.635621236255477e-07
# ===============
# Time step: 118
# Strain: -8.037401924684857e-07
# ===============
# Time step: 119
# Strain: -8.431250667781871e-07
# ===============
# Time step: 120
# Strain: -8.816778784386999e-07
# ===============
# Time step: 121
# Strain: -9.193605804794555e-07
# ===============
# Time step: 122
# Strain: -9.561359846230253e-07
# ===============
# Time step: 123
# Strain: -9.91967797985469e-07
# ===============
# Time step: 124
# Strain: -1.0268206588930243e-06
# ===============
# Time step: 125
# Strain: -1.0606601717798132e-06
# ===============
# Time step: 126
# Strain: -1.0934529411321093e-06
# ===============
# Time step: 127
# Strain: -1.1251666044456817e-06
# ===============
# Time step: 128
# Strain: -1.1557698641636764e-06
# ===============
# Time step: 129
# Strain: -1.1852325185635284e-06
# ===============
# Time step: 130
# Strain: -1.2135254915624141e-06
# ===============
# Time step: 131
# Strain: -1.2406208614118357e-06
# ===============
# Time step: 132
# Strain: -1.2664918882530158e-06
# ===============
# Time step: 133
# Strain: -1.2911130405059087e-06
# ===============
# Time step: 134
# Strain: -1.3144600200657896e-06
# ===============
# Time step: 135
# Strain: -1.3365097862825458e-06
# ===============
# Time step: 136
# Strain: -1.3572405786990234e-06
# ===============
# Time step: 137
# Strain: -1.3766319385259667e-06
# ===============
# Time step: 138
# Strain: -1.3946647288323724e-06
# ===============
# Time step: 139
# Strain: -1.4113211534313336e-06
# ===============
# Time step: 140
# Strain: -1.4265847744427262e-06
# ===============
# Time step: 141
# Strain: -1.4404405285154107e-06
# ===============
# Time step: 142
# Strain: -1.452874741692943e-06
# ===============
# Time step: 143
# Strain: -1.4638751429081181e-06
# ===============
# Time step: 144
# Strain: -1.4734308760930302e-06
# ===============
# Time step: 145
# Strain: -1.4815325108927044e-06
# ===============
# Time step: 146
# Strain: -1.488172051971715e-06
# ===============
# Time step: 147
# Strain: -1.4933429469046186e-06
# ===============
# Time step: 148
# Strain: -1.4970400926424065e-06
# ===============
# Time step: 149
# Strain: -1.499259840548597e-06
# ===============
# Time step: 150
# Strain: -1.5e-06
# ===============
# Time step: 151
# Strain: -1.4992598405485978e-06
# ===============
# Time step: 152
# Strain: -1.4970400926424084e-06
# ===============
# Time step: 153
# Strain: -1.4933429469046215e-06
# ===============
# Time step: 154
# Strain: -1.4881720519717189e-06
# ===============
# Time step: 155
# Strain: -1.481532510892709e-06
# ===============
# Time step: 156
# Strain: -1.473430876093036e-06
# ===============
# Time step: 157
# Strain: -1.4638751429081245e-06
# ===============
# Time step: 158
# Strain: -1.4528747416929507e-06
# ===============
# Time step: 159
# Strain: -1.4404405285154192e-06
# ===============
# Time step: 160
# Strain: -1.4265847744427355e-06
# ===============
# Time step: 161
# Strain: -1.4113211534313438e-06
# ===============
# Time step: 162
# Strain: -1.3946647288323834e-06
# ===============
# Time step: 163
# Strain: -1.3766319385259786e-06
# ===============
# Time step: 164
# Strain: -1.3572405786990363e-06
# ===============
# Time step: 165
# Strain: -1.3365097862825598e-06
# ===============
# Time step: 166
# Strain: -1.314460020065804e-06
# ===============
# Time step: 167
# Strain: -1.291113040505924e-06
# ===============
# Time step: 168
# Strain: -1.266491888253032e-06
# ===============
# Time step: 169
# Strain: -1.2406208614118526e-06
# ===============
# Time step: 170
# Strain: -1.2135254915624315e-06
# ===============
# Time step: 171
# Strain: -1.1852325185635464e-06
# ===============
# Time step: 172
# Strain: -1.1557698641636954e-06
# ===============
# Time step: 173
# Strain: -1.1251666044457016e-06
# ===============
# Time step: 174
# Strain: -1.0934529411321302e-06
# ===============
# Time step: 175
# Strain: -1.0606601717798337e-06
# ===============
# Time step: 176
# Strain: -1.0268206588930461e-06
# ===============
# Time step: 177
# Strain: -9.919677979854925e-07
# ===============
# Time step: 178
# Strain: -9.561359846230488e-07
# ===============
# Time step: 179
# Strain: -9.193605804794796e-07
# ===============
# Time step: 180
# Strain: -8.81677878438725e-07
# ===============
# Time step: 181
# Strain: -8.431250667782118e-07
# ===============
# Time step: 182
# Strain: -8.037401924685115e-07
# ===============
# Time step: 183
# Strain: -7.635621236255728e-07
# ===============
# Time step: 184
# Strain: -7.226305111525905e-07
# ===============
# Time step: 185
# Strain: -6.809857496093382e-07
# ===============
# Time step: 186
# Strain: -6.386689373476264e-07
# ===============
# Time step: 187
# Strain: -5.957218359521889e-07
# ===============
# Time step: 188
# Strain: -5.521868290270353e-07
# ===============
# Time step: 189
# Strain: -5.08106880367956e-07
# ===============
# Time step: 190
# Strain: -4.635254915624405e-07
# ===============
# Time step: 191
# Strain: -4.1848665905886364e-07
# ===============
# Time step: 192
# Strain: -3.730348307473024e-07
# ===============
# Time step: 193
# Strain: -3.272148620948345e-07
# ===============
# Time step: 194
# Strain: -2.810719718786067e-07
# ===============
# Time step: 195
# Strain: -2.3465169756036641e-07
# ===============
# Time step: 196
# Strain: -1.8799985034647811e-07
# ===============
# Time step: 197
# Strain: -1.4116246997779227e-07
# ===============
# Time step: 198
# Strain: -9.418577929399117e-08
# ===============
# Time step: 199
# Strain: -4.711613861721385e-08
# ===============
# Time step: 200
# Strain: -2.168367611254721e-20
# ===============
# Time step: 201
# Strain: 4.71161386171705e-08
# ===============
# Time step: 202
# Strain: 9.418577929394923e-08
# ===============
# Time step: 203
# Strain: 1.411624699777491e-07
# ===============
# Time step: 204
# Strain: 1.8799985034643513e-07
# ===============
# Time step: 205
# Strain: 2.3465169756032486e-07
# ===============
# Time step: 206
# Strain: 2.8107197187856403e-07
# ===============
# Time step: 207
# Strain: 3.2721486209479213e-07
# ===============
# Time step: 208
# Strain: 3.730348307472604e-07
# ===============
# Time step: 209
# Strain: 4.1848665905882325e-07
# ===============
# Time step: 210
# Strain: 4.635254915623992e-07
# ===============
# Time step: 211
# Strain: 5.081068803679139e-07
# ===============
# Time step: 212
# Strain: 5.521868290269951e-07
# ===============
# Time step: 213
# Strain: 5.957218359521491e-07
# ===============
# Time step: 214
# Strain: 6.386689373475883e-07
# ===============
# Time step: 215
# Strain: 6.809857496092985e-07
# ===============
# Time step: 216
# Strain: 7.226305111525525e-07
# ===============
# Time step: 217
# Strain: 7.635621236255367e-07
# ===============
# Time step: 218
# Strain: 8.037401924684737e-07
# ===============
# Time step: 219
# Strain: 8.431250667781759e-07
# ===============
# Time step: 220
# Strain: 8.816778784386899e-07
# ===============
# Time step: 221
# Strain: 9.193605804794463e-07
# ===============
# Time step: 222
# Strain: 9.561359846230153e-07
# ===============
# Time step: 223
# Strain: 9.919677979854588e-07
# ===============
# Time step: 224
# Strain: 1.0268206588930154e-06
# ===============
# Time step: 225
# Strain: 1.060660171779803e-06
# ===============
# Time step: 226
# Strain: 1.0934529411321004e-06
# ===============
# Time step: 227
# Strain: 1.125166604445673e-06
# ===============
# Time step: 228
# Strain: 1.1557698641636685e-06
# ===============
# Time step: 229
# Strain: 1.18523251856352e-06
# ===============
# Time step: 230
# Strain: 1.213525491562406e-06
# ===============
# Time step: 231
# Strain: 1.240620861411829e-06
# ===============
# Time step: 232
# Strain: 1.2664918882530084e-06
# ===============
# Time step: 233
# Strain: 1.2911130405059026e-06
# ===============
# Time step: 234
# Strain: 1.3144600200657824e-06
# ===============
# Time step: 235
# Strain: 1.3365097862825397e-06
# ===============
# Time step: 236
# Strain: 1.3572405786990183e-06
# ===============
# Time step: 237
# Strain: 1.3766319385259608e-06
# ===============
# Time step: 238
# Strain: 1.3946647288323673e-06
# ===============
# Time step: 239
# Strain: 1.4113211534313292e-06
# ===============
# Time step: 240
# Strain: 1.4265847744427226e-06
# ===============
# Time step: 241
# Strain: 1.440440528515407e-06
# ===============
# Time step: 242
# Strain: 1.45287474169294e-06
# ===============
# Time step: 243
# Strain: 1.4638751429081154e-06
# ===============
# Time step: 244
# Strain: 1.4734308760930279e-06
# ===============
# Time step: 245
# Strain: 1.4815325108927023e-06
# ===============
# Time step: 246
# Strain: 1.4881720519717136e-06
# ===============
# Time step: 247
# Strain: 1.4933429469046177e-06
# ===============
# Time step: 248
# Strain: 1.4970400926424059e-06
# ===============
# Time step: 249
# Strain: 1.4992598405485966e-06
# ===============
# Time step: 250
# Strain: 1.5e-06
# ===============
# Time step: 251
# Strain: 1.499259840548598e-06
# ===============
# Time step: 252
# Strain: 1.4970400926424086e-06
# ===============
# Time step: 253
# Strain: 1.4933429469046218e-06
# ===============
# Time step: 254
# Strain: 1.488172051971719e-06
# ===============
# Time step: 255
# Strain: 1.481532510892709e-06
# ===============
# Time step: 256
# Strain: 1.4734308760930355e-06
# ===============
# Time step: 257
# Strain: 1.463875142908124e-06
# ===============
# Time step: 258
# Strain: 1.4528747416929492e-06
# ===============
# Time step: 259
# Strain: 1.440440528515417e-06
# ===============
# Time step: 260
# Strain: 1.426584774442733e-06
# ===============
# Time step: 261
# Strain: 1.4113211534313404e-06
# ===============
# Time step: 262
# Strain: 1.3946647288323796e-06
# ===============
# Time step: 263
# Strain: 1.3766319385259733e-06
# ===============
# Time step: 264
# Strain: 1.357240578699031e-06
# ===============
# Time step: 265
# Strain: 1.3365097862825528e-06
# ===============
# Time step: 266
# Strain: 1.3144600200657964e-06
# ===============
# Time step: 267
# Strain: 1.2911130405059153e-06
# ===============
# Time step: 268
# Strain: 1.2664918882530226e-06
# ===============
# Time step: 269
# Strain: 1.2406208614118414e-06
# ===============
# Time step: 270
# Strain: 1.2135254915624199e-06
# ===============
# Time step: 271
# Strain: 1.1852325185635328e-06
# ===============
# Time step: 272
# Strain: 1.155769864163681e-06
# ===============
# Time step: 273
# Strain: 1.1251666044456848e-06
# ===============
# Time step: 274
# Strain: 1.0934529411321129e-06
# ===============
# Time step: 275
# Strain: 1.060660171779815e-06
# ===============
# Time step: 276
# Strain: 1.0268206588930269e-06
# ===============
# Time step: 277
# Strain: 9.919677979854696e-07
# ===============
# Time step: 278
# Strain: 9.561359846230263e-07
# ===============
# Time step: 279
# Strain: 9.193605804794544e-07
# ===============
# Time step: 280
# Strain: 8.816778784386994e-07
# ===============
# Time step: 281
# Strain: 8.431250667781834e-07
# ===============
# Time step: 282
# Strain: 8.037401924684823e-07
# ===============
# Time step: 283
# Strain: 7.63562123625542e-07
# ===============
# Time step: 284
# Strain: 7.22630511152558e-07
# ===============
# Time step: 285
# Strain: 6.809857496093029e-07
# ===============
# Time step: 286
# Strain: 6.386689373475916e-07
# ===============
# Time step: 287
# Strain: 5.957218359521511e-07
# ===============
# Time step: 288
# Strain: 5.521868290269971e-07
# ===============
# Time step: 289
# Strain: 5.081068803679147e-07
# ===============
# Time step: 290
# Strain: 4.635254915623989e-07
# ===============
# Time step: 291
# Strain: 4.184866590588191e-07
# ===============
# Time step: 292
# Strain: 3.7303483074725485e-07
# ===============
# Time step: 293
# Strain: 3.272148620947839e-07
# ===============
# Time step: 294
# Strain: 2.8107197187855715e-07
# ===============
# Time step: 295
# Strain: 2.3465169756031392e-07
# ===============
# Time step: 296
# Strain: 1.8799985034642412e-07
# ===============
# Time step: 297
# Strain: 1.4116246997773676e-07
# ===============
# Time step: 298
# Strain: 9.418577929393551e-08
# ===============
# Time step: 299
# Strain: 4.711613861715544e-08
# ===============
# Time step: 300
# Strain: -3.675240256778895e-20
# ===============
# Time step: 301
# Strain: -4.711613861723157e-08
# ===============
# Time step: 302
# Strain: -9.418577929400887e-08
# ===============
# Time step: 303
# Strain: -1.411624699778126e-07
# ===============
# Time step: 304
# Strain: -1.8799985034649707e-07
# ===============
# Time step: 305
# Strain: -2.346516975603892e-07
# ===============
# Time step: 306
# Strain: -2.8107197187862936e-07
# ===============
# Time step: 307
# Strain: -3.2721486209485825e-07
# ===============
# Time step: 308
# Strain: -3.7303483074732605e-07
# ===============
# Time step: 309
# Strain: -4.1848665905888964e-07
# ===============
# Time step: 310
# Strain: -4.635254915624662e-07
# ===============
# Time step: 311
# Strain: -5.08106880367984e-07
# ===============
# Time step: 312
# Strain: -5.52186829027063e-07
# ===============
# Time step: 313
# Strain: -5.957218359522185e-07
# ===============
# Time step: 314
# Strain: -6.386689373476557e-07
# ===============
# Time step: 315
# Strain: -6.809857496093683e-07
# ===============
# Time step: 316
# Strain: -7.226305111526201e-07
# ===============
# Time step: 317
# Strain: -7.635621236256053e-07
# ===============
# Time step: 318
# Strain: -8.037401924685421e-07
# ===============
# Time step: 319
# Strain: -8.431250667782442e-07
# ===============
# Time step: 320
# Strain: -8.816778784387567e-07
# ===============
# Time step: 321
# Strain: -9.193605804795125e-07
# ===============
# Time step: 322
# Strain: -9.56135984623081e-07
# ===============
# Time step: 323
# Strain: -9.919677979855247e-07
# ===============
# Time step: 324
# Strain: -1.0268206588930783e-06
# ===============
# Time step: 325
# Strain: -1.060660171779867e-06
# ===============
# Time step: 326
# Strain: -1.0934529411321616e-06
# ===============
# Time step: 327
# Strain: -1.1251666044457335e-06
# ===============
# Time step: 328
# Strain: -1.1557698641637263e-06
# ===============
# Time step: 329
# Strain: -1.1852325185635794e-06
# ===============
# Time step: 330
# Strain: -1.2135254915624633e-06
# ===============
# Time step: 331
# Strain: -1.2406208614118842e-06
# ===============
# Time step: 332
# Strain: -1.266491888253062e-06
# ===============
# Time step: 333
# Strain: -1.291113040505954e-06
# ===============
# Time step: 334
# Strain: -1.314460020065832e-06
# ===============
# Time step: 335
# Strain: -1.336509786282587e-06
# ===============
# Time step: 336
# Strain: -1.3572405786990624e-06
# ===============
# Time step: 337
# Strain: -1.3766319385260035e-06
# ===============
# Time step: 338
# Strain: -1.3946647288324065e-06
# ===============
# Time step: 339
# Strain: -1.411321153431366e-06
# ===============
# Time step: 340
# Strain: -1.4265847744427556e-06
# ===============
# Time step: 341
# Strain: -1.440440528515438e-06
# ===============
# Time step: 342
# Strain: -1.4528747416929677e-06
# ===============
# Time step: 343
# Strain: -1.46387514290814e-06
# ===============
# Time step: 344
# Strain: -1.4734308760930492e-06
# ===============
# Time step: 345
# Strain: -1.4815325108927205e-06
# ===============
# Time step: 346
# Strain: -1.4881720519717278e-06
# ===============
# Time step: 347
# Strain: -1.4933429469046285e-06
# ===============
# Time step: 348
# Strain: -1.497040092642413e-06
# ===============
# Time step: 349
# Strain: -1.4992598405486004e-06
# ===============
# Time step: 350
# Strain: -1.5e-06
# ===============
# Time step: 351
# Strain: -1.4992598405485944e-06
# ===============
# Time step: 352
# Strain: -1.4970400926424014e-06
# ===============
# Time step: 353
# Strain: -1.493342946904611e-06
# ===============
# Time step: 354
# Strain: -1.4881720519717047e-06
# ===============
# Time step: 355
# Strain: -1.481532510892691e-06
# ===============
# Time step: 356
# Strain: -1.4734308760930145e-06
# ===============
# Time step: 357
# Strain: -1.463875142908099e-06
# ===============
# Time step: 358
# Strain: -1.4528747416929215e-06
# ===============
# Time step: 359
# Strain: -1.4404405285153857e-06
# ===============
# Time step: 360
# Strain: -1.4265847744426984e-06
# ===============
# Time step: 361
# Strain: -1.4113211534313023e-06
# ===============
# Time step: 362
# Strain: -1.3946647288323383e-06
# ===============
# Time step: 363
# Strain: -1.376631938525929e-06
# ===============
# Time step: 364
# Strain: -1.3572405786989836e-06
# ===============
# Time step: 365
# Strain: -1.336509786282502e-06
# ===============
# Time step: 366
# Strain: -1.3144600200657413e-06
# ===============
# Time step: 367
# Strain: -1.291113040505857e-06
# ===============
# Time step: 368
# Strain: -1.2664918882529614e-06
# ===============
# Time step: 369
# Strain: -1.2406208614117772e-06
# ===============
# Time step: 370
# Strain: -1.2135254915623525e-06
# ===============
# Time step: 371
# Strain: -1.1852325185634627e-06
# ===============
# Time step: 372
# Strain: -1.1557698641636084e-06
# ===============
# Time step: 373
# Strain: -1.1251666044456092e-06
# ===============
# Time step: 374
# Strain: -1.0934529411320345e-06
# ===============
# Time step: 375
# Strain: -1.0606601717797342e-06
# ===============
# Time step: 376
# Strain: -1.0268206588929434e-06
# ===============
# Time step: 377
# Strain: -9.919677979853839e-07
# ===============
# Time step: 378
# Strain: -9.561359846229382e-07
# ===============
# Time step: 379
# Strain: -9.19360580479364e-07
# ===============
# Time step: 380
# Strain: -8.816778784386068e-07
# ===============
# Time step: 381
# Strain: -8.431250667780888e-07
# ===============
# Time step: 382
# Strain: -8.037401924683857e-07
# ===============
# Time step: 383
# Strain: -7.635621236254436e-07
# ===============
# Time step: 384
# Strain: -7.226305111524578e-07
# ===============
# Time step: 385
# Strain: -6.809857496092009e-07
# ===============
# Time step: 386
# Strain: -6.386689373474881e-07
# ===============
# Time step: 387
# Strain: -5.957218359520462e-07
# ===============
# Time step: 388
# Strain: -5.521868290268907e-07
# ===============
# Time step: 389
# Strain: -5.081068803678071e-07
# ===============
# Time step: 390
# Strain: -4.6352549156229003e-07
# ===============
# Time step: 391
# Strain: -4.184866590587092e-07
# ===============
# Time step: 392
# Strain: -3.730348307471466e-07
# ===============
# Time step: 393
# Strain: -3.2721486209467487e-07
# ===============
# Time step: 394
# Strain: -2.810719718784474e-07
# ===============
# Time step: 395
# Strain: -2.346516975602036e-07
# ===============
# Time step: 396
# Strain: -1.8799985034631064e-07
# ===============
# Time step: 397
# Strain: -1.411624699776255e-07
# ===============
# Time step: 398
# Strain: -9.418577929382134e-08
# ===============
# Time step: 399
# Strain: -4.711613861704376e-08
# ===============
# Time step: 400
# Strain: 1.5114372168923302e-19
# ===============
# Time step: 401
# Strain: 4.711613861734591e-08
# ===============
# Time step: 402
# Strain: 9.418577929412305e-08
# ===============
# Time step: 403
# Strain: 1.4116246997792644e-07
# ===============
# Time step: 404
# Strain: 1.8799985034661057e-07
# ===============
# Time step: 405
# Strain: 2.3465169756050212e-07
# ===============
# Time step: 406
# Strain: 2.810719718787417e-07
# ===============
# Time step: 407
# Strain: 3.272148620949699e-07
# ===============
# Time step: 408
# Strain: 3.7303483074743685e-07
# ===============
# Time step: 409
# Strain: 4.184866590589995e-07
# ===============
# Time step: 410
# Strain: 4.63525491562575e-07
# ===============
# Time step: 411
# Strain: 5.081068803680915e-07
# ===============
# Time step: 412
# Strain: 5.521868290271694e-07
# ===============
# Time step: 413
# Strain: 5.957218359523236e-07
# ===============
# Time step: 414
# Strain: 6.386689373477592e-07
# ===============
# Time step: 415
# Strain: 6.809857496094703e-07
# ===============
# Time step: 416
# Strain: 7.226305111527203e-07
# ===============
# Time step: 417
# Strain: 7.635621236257037e-07
# ===============
# Time step: 418
# Strain: 8.037401924686387e-07
# ===============
# Time step: 419
# Strain: 8.431250667783388e-07
# ===============
# Time step: 420
# Strain: 8.816778784388493e-07
# ===============
# Time step: 421
# Strain: 9.19360580479603e-07
# ===============
# Time step: 422
# Strain: 9.561359846231712e-07
# ===============
# Time step: 423
# Strain: 9.919677979856105e-07
# ===============
# Time step: 424
# Strain: 1.0268206588931639e-06
# ===============
# Time step: 425
# Strain: 1.060660171779948e-06
# ===============
# Time step: 426
# Strain: 1.0934529411322416e-06
# ===============
# Time step: 427
# Strain: 1.1251666044458091e-06
# ===============
# Time step: 428
# Strain: 1.1557698641638009e-06
# ===============
# Time step: 429
# Strain: 1.1852325185636478e-06
# ===============
# Time step: 430
# Strain: 1.2135254915625302e-06
# ===============
# Time step: 431
# Strain: 1.240620861411947e-06
# ===============
# Time step: 432
# Strain: 1.2664918882531232e-06
# ===============
# Time step: 433
# Strain: 1.291113040506011e-06
# ===============
# Time step: 434
# Strain: 1.314460020065887e-06
# ===============
# Time step: 435
# Strain: 1.336509786282638e-06
# ===============
# Time step: 436
# Strain: 1.3572405786991113e-06
# ===============
# Time step: 437
# Strain: 1.376631938526048e-06
# ===============
# Time step: 438
# Strain: 1.3946647288324486e-06
# ===============
# Time step: 439
# Strain: 1.411321153431404e-06
# ===============
# Time step: 440
# Strain: 1.4265847744427912e-06
# ===============
# Time step: 441
# Strain: 1.4404405285154694e-06
# ===============
# Time step: 442
# Strain: 1.452874741692996e-06
# ===============
# Time step: 443
# Strain: 1.4638751429081643e-06
# ===============
# Time step: 444
# Strain: 1.4734308760930706e-06
# ===============
# Time step: 445
# Strain: 1.481532510892738e-06
# ===============
# Time step: 446
# Strain: 1.4881720519717424e-06
# ===============
# Time step: 447
# Strain: 1.4933429469046391e-06
# ===============
# Time step: 448
# Strain: 1.4970400926424203e-06
# ===============
# Time step: 449
# Strain: 1.4992598405486038e-06
# ===============
# Time step: 450
# Strain: 1.5e-06
# ===============
# Time step: 451
# Strain: 1.499259840548591e-06
# ===============
# Time step: 452
# Strain: 1.497040092642394e-06
# ===============
# Time step: 453
# Strain: 1.4933429469046004e-06
# ===============
# Time step: 454
# Strain: 1.48817205197169e-06
# ===============
# Time step: 455
# Strain: 1.4815325108926735e-06
# ===============
# Time step: 456
# Strain: 1.4734308760929927e-06
# ===============
# Time step: 457
# Strain: 1.4638751429080736e-06
# ===============
# Time step: 458
# Strain: 1.4528747416928925e-06
# ===============
# Time step: 459
# Strain: 1.4404405285153531e-06
# ===============
# Time step: 460
# Strain: 1.4265847744426624e-06
# ===============
# Time step: 461
# Strain: 1.4113211534312627e-06
# ===============
# Time step: 462
# Strain: 1.3946647288322953e-06
# ===============
# Time step: 463
# Strain: 1.3766319385258824e-06
# ===============
# Time step: 464
# Strain: 1.3572405786989336e-06
# ===============
# Time step: 465
# Strain: 1.3365097862824488e-06
# ===============
# Time step: 466
# Strain: 1.3144600200656862e-06
# ===============
# Time step: 467
# Strain: 1.2911130405057988e-06
# ===============
# Time step: 468
# Strain: 1.2664918882529e-06
# ===============
# Time step: 469
# Strain: 1.2406208614117129e-06
# ===============
# Time step: 470
# Strain: 1.2135254915622854e-06
# ===============
# Time step: 471
# Strain: 1.1852325185633926e-06
# ===============
# Time step: 472
# Strain: 1.1557698641635353e-06
# ===============
# Time step: 473
# Strain: 1.1251666044455336e-06
# ===============
# Time step: 474
# Strain: 1.0934529411319564e-06
# ===============
# Time step: 475
# Strain: 1.0606601717796533e-06
# ===============
# Time step: 476
# Strain: 1.02682065889286e-06
# ===============
# Time step: 477
# Strain: 9.919677979852981e-07
# ===============
# Time step: 478
# Strain: 9.561359846228501e-07
# ===============
# Time step: 479
# Strain: 9.193605804792738e-07
# ===============
# Time step: 480
# Strain: 8.816778784385142e-07
# ===============
# Time step: 481
# Strain: 8.43125066777994e-07
# ===============
# Time step: 482
# Strain: 8.037401924682892e-07
# ===============
# Time step: 483
# Strain: 7.635621236253452e-07
# ===============
# Time step: 484
# Strain: 7.226305111523575e-07
# ===============
# Time step: 485
# Strain: 6.80985749609099e-07
# ===============
# Time step: 486
# Strain: 6.386689373473846e-07
# ===============
# Time step: 487
# Strain: 5.957218359519411e-07
# ===============
# Time step: 488
# Strain: 5.521868290267844e-07
# ===============
# Time step: 489
# Strain: 5.081068803676995e-07
# ===============
# Time step: 490
# Strain: 4.635254915621813e-07
# ===============
# Time step: 491
# Strain: 4.1848665905859937e-07
# ===============
# Time step: 492
# Strain: 3.7303483074703583e-07
# ===============
# Time step: 493
# Strain: 3.2721486209456327e-07
# ===============
# Time step: 494
# Strain: 2.810719718783324e-07
# ===============
# Time step: 495
# Strain: 2.3465169756009063e-07
# ===============
# Time step: 496
# Strain: 1.8799985034619714e-07
# ===============
# Time step: 497
# Strain: 1.4116246997751163e-07
# ===============
# Time step: 498
# Strain: 9.418577929370453e-08
# ===============
# Time step: 499
# Strain: 4.7116138616929433e-08
# ===============
# Time step: 500
# Strain: -2.6819957606977745e-19
# ===============
# Time step: 501
# Strain: -4.711613861745758e-08
# ===============
# Time step: 502
# Strain: -9.418577929423987e-08
# ===============
# Time step: 503
# Strain: -1.411624699780377e-07
# ===============
# Time step: 504
# Strain: -1.8799985034672666e-07
# ===============
# Time step: 505
# Strain: -2.346516975606125e-07
# ===============
# Time step: 506
# Strain: -2.810719718788567e-07
# ===============
# Time step: 507
# Strain: -3.2721486209507896e-07
# ===============
# Time step: 508
# Strain: -3.730348307475502e-07
# ===============
# Time step: 509
# Strain: -4.184866590591068e-07
# ===============
# Time step: 510
# Strain: -4.635254915626863e-07
# ===============
# Time step: 511
# Strain: -5.081068803681967e-07
# ===============
# Time step: 512
# Strain: -5.521868290272757e-07
# ===============
# Time step: 513
# Strain: -5.957218359524286e-07
# ===============
# Time step: 514
# Strain: -6.386689373478651e-07
# ===============
# Time step: 515
# Strain: -6.809857496095699e-07
# ===============
# Time step: 516
# Strain: -7.226305111528205e-07
# ===============
# Time step: 517
# Strain: -7.635621236258022e-07
# ===============
# Time step: 518
# Strain: -8.037401924687377e-07
# ===============
# Time step: 519
# Strain: -8.431250667784312e-07
# ===============
# Time step: 520
# Strain: -8.816778784389418e-07
# ===============
# Time step: 521
# Strain: -9.193605804796933e-07
# ===============
# Time step: 522
# Strain: -9.561359846232593e-07
# ===============
# Time step: 523
# Strain: -9.919677979856945e-07
# ===============
# Time step: 524
# Strain: -1.0268206588932452e-06
# ===============
# Time step: 525
# Strain: -1.060660171780029e-06
# ===============
# Time step: 526
# Strain: -1.09345294113232e-06
# ===============
# Time step: 527
# Strain: -1.125166604445883e-06
# ===============
# Time step: 528
# Strain: -1.155769864163872e-06
# ===============
# Time step: 529
# Strain: -1.185232518563718e-06
# ===============
# Time step: 530
# Strain: -1.2135254915625975e-06
# ===============
# Time step: 531
# Strain: -1.2406208614120127e-06
# ===============
# Time step: 532
# Strain: -1.266491888253183e-06
# ===============
# Time step: 533
# Strain: -1.2911130405060718e-06
# ===============
# Time step: 534
# Strain: -1.314460020065942e-06
# ===============
# Time step: 535
# Strain: -1.336509786282691e-06
# ===============
# Time step: 536
# Strain: -1.3572405786991587e-06
# ===============
# Time step: 537
# Strain: -1.3766319385260954e-06
# ===============
# Time step: 538
# Strain: -1.3946647288324908e-06
# ===============
# Time step: 539
# Strain: -1.4113211534314436e-06
# ===============
# Time step: 540
# Strain: -1.4265847744428255e-06
# ===============
# Time step: 541
# Strain: -1.4404405285155028e-06
# ===============
# Time step: 542
# Strain: -1.4528747416930246e-06
# ===============
# Time step: 543
# Strain: -1.46387514290819e-06
# ===============
# Time step: 544
# Strain: -1.4734308760930916e-06
# ===============
# Time step: 545
# Strain: -1.4815325108927567e-06
# ===============
# Time step: 546
# Strain: -1.4881720519717566e-06
# ===============
# Time step: 547
# Strain: -1.4933429469046501e-06
# ===============
# Time step: 548
# Strain: -1.4970400926424272e-06
# ===============
# Time step: 549
# Strain: -1.4992598405486076e-06
# ===============
# Time step: 550
# Strain: -1.5e-06
# ===============
# Time step: 551
# Strain: -1.4992598405485872e-06
# ===============
# Time step: 552
# Strain: -1.4970400926423872e-06
# ===============
# Time step: 553
# Strain: -1.4933429469045891e-06
# ===============
# Time step: 554
# Strain: -1.4881720519716761e-06
# ===============
# Time step: 555
# Strain: -1.4815325108926553e-06
# ===============
# Time step: 556
# Strain: -1.4734308760929711e-06
# ===============
# Time step: 557
# Strain: -1.4638751429080487e-06
# ===============
# Time step: 558
# Strain: -1.4528747416928648e-06
# ===============
# Time step: 559
# Strain: -1.4404405285153218e-06
# ===============
# Time step: 560
# Strain: -1.4265847744426269e-06
# ===============
# Time step: 561
# Strain: -1.411321153431224e-06
# ===============
# Time step: 562
# Strain: -1.3946647288322543e-06
# ===============
# Time step: 563
# Strain: -1.376631938525838e-06
# ===============
# Time step: 564
# Strain: -1.3572405786988851e-06
# ===============
# Time step: 565
# Strain: -1.336509786282397e-06
# ===============
# Time step: 566
# Strain: -1.3144600200656325e-06
# ===============
# Time step: 567
# Strain: -1.2911130405057419e-06
# ===============
# Time step: 568
# Strain: -1.2664918882528388e-06
# ===============
# Time step: 569
# Strain: -1.2406208614116485e-06
# ===============
# Time step: 570
# Strain: -1.2135254915622166e-06
# ===============
# Time step: 571
# Strain: -1.1852325185633242e-06
# ===============
# Time step: 572
# Strain: -1.1557698641634625e-06
# ===============
# Time step: 573
# Strain: -1.125166604445458e-06
# ===============
# Time step: 574
# Strain: -1.0934529411318763e-06
# ===============
# Time step: 575
# Strain: -1.0606601717795743e-06
# ===============
# Time step: 576
# Strain: -1.0268206588927766e-06
# ===============
# Time step: 577
# Strain: -9.919677979852121e-07
# ===============
# Time step: 578
# Strain: -9.5613598462276e-07
# ===============
# Time step: 579
# Strain: -9.193605804791853e-07
# ===============
# Time step: 580
# Strain: -8.816778784384218e-07
# ===============
# Time step: 581
# Strain: -8.431250667778995e-07
# ===============
# Time step: 582
# Strain: -8.037401924681904e-07
# ===============
# Time step: 583
# Strain: -7.635621236252489e-07
# ===============
# Time step: 584
# Strain: -7.226305111522572e-07
# ===============
# Time step: 585
# Strain: -6.809857496089971e-07
# ===============
# Time step: 586
# Strain: -6.386689373472786e-07
# ===============
# Time step: 587
# Strain: -5.957218359518386e-07
# ===============
# Time step: 588
# Strain: -5.521868290266781e-07
# ===============
# Time step: 589
# Strain: -5.081068803675919e-07
# ===============
# Time step: 590
# Strain: -4.6352549156206996e-07
# ===============
# Time step: 591
# Strain: -4.184866590584921e-07
# ===============
# Time step: 592
# Strain: -3.7303483074692503e-07
# ===============
# Time step: 593
# Strain: -3.272148620944516e-07
# ===============
# Time step: 594
# Strain: -2.8107197187822003e-07
# ===============
# Time step: 595
# Strain: -2.346516975599803e-07
# ===============
# Time step: 596
# Strain: -1.879998503460863e-07
# ===============
# Time step: 597
# Strain: -1.4116246997739776e-07
# ===============
# Time step: 598
# Strain: -9.418577929359301e-08
# ===============
# Time step: 599
# Strain: -4.711613861681776e-08
# ===============
# Time step: 600
# Strain: 3.7726182467302074e-19
# ===============
# Time step: 601
# Strain: 4.7116138617571915e-08
# ===============
# Time step: 602
# Strain: 9.418577929435136e-08
# ===============
# Time step: 603
# Strain: 1.4116246997815421e-07
# ===============
# Time step: 604
# Strain: 1.8799985034683487e-07
# ===============
# Time step: 605
# Strain: 2.3465169756073074e-07
# ===============
# Time step: 606
# Strain: 2.810719718789664e-07
# ===============
# Time step: 607
# Strain: 3.272148620951932e-07
# ===============
# Time step: 608
# Strain: 3.73034830747661e-07
# ===============
# Time step: 609
# Strain: 4.184866590592218e-07
# ===============
# Time step: 610
# Strain: 4.6352549156279254e-07
# ===============
# Time step: 611
# Strain: 5.081068803683069e-07
# ===============
# Time step: 612
# Strain: 5.521868290273845e-07
# ===============
# Time step: 613
# Strain: 5.95721835952536e-07
# ===============
# Time step: 614
# Strain: 6.386689373479662e-07
# ===============
# Time step: 615
# Strain: 6.809857496096741e-07
# ===============
# Time step: 616
# Strain: 7.226305111529231e-07
# ===============
# Time step: 617
# Strain: 7.63562123625903e-07
# ===============
# Time step: 618
# Strain: 8.037401924688319e-07
# ===============
# Time step: 619
# Strain: 8.43125066778528e-07
# ===============
# Time step: 620
# Strain: 8.816778784390364e-07
# ===============
# Time step: 621
# Strain: 9.193605804797858e-07
# ===============
# Time step: 622
# Strain: 9.561359846233454e-07
# ===============
# Time step: 623
# Strain: 9.919677979857822e-07
# ===============
# Time step: 624
# Strain: 1.0268206588933305e-06
# ===============
# Time step: 625
# Strain: 1.0606601717801117e-06
# ===============
# Time step: 626
# Strain: 1.0934529411323964e-06
# ===============
# Time step: 627
# Strain: 1.1251666044459605e-06
# ===============
# Time step: 628
# Strain: 1.1557698641639468e-06
# ===============
# Time step: 629
# Strain: 1.1852325185637897e-06
# ===============
# Time step: 630
# Strain: 1.2135254915626632e-06
# ===============
# Time step: 631
# Strain: 1.2406208614120756e-06
# ===============
# Time step: 632
# Strain: 1.266491888253246e-06
# ===============
# Time step: 633
# Strain: 1.2911130405061287e-06
# ===============
# Time step: 634
# Strain: 1.3144600200659958e-06
# ===============
# Time step: 635
# Strain: 1.3365097862827419e-06
# ===============
# Time step: 636
# Strain: 1.3572405786992087e-06
# ===============
# Time step: 637
# Strain: 1.3766319385261397e-06
# ===============
# Time step: 638
# Strain: 1.3946647288325319e-06
# ===============
# Time step: 639
# Strain: 1.4113211534314815e-06
# ===============
# Time step: 640
# Strain: 1.4265847744428617e-06
# ===============
# Time step: 641
# Strain: 1.440440528515534e-06
# ===============
# Time step: 642
# Strain: 1.4528747416930536e-06
# ===============
# Time step: 643
# Strain: 1.4638751429082143e-06
# ===============
# Time step: 644
# Strain: 1.4734308760931136e-06
# ===============
# Time step: 645
# Strain: 1.4815325108927741e-06
# ===============
# Time step: 646
# Strain: 1.4881720519717712e-06
# ===============
# Time step: 647
# Strain: 1.4933429469046607e-06
# ===============
# Time step: 648
# Strain: 1.4970400926424347e-06
# ===============
# Time step: 649
# Strain: 1.4992598405486112e-06
# ===============
# Time step: 650
# Strain: 1.5e-06
# ===============
# Time step: 651
# Strain: 1.4992598405485836e-06
# ===============
# Time step: 652
# Strain: 1.4970400926423798e-06
# ===============
# Time step: 653
# Strain: 1.4933429469045786e-06
# ===============
# Time step: 654
# Strain: 1.4881720519716613e-06
# ===============
# Time step: 655
# Strain: 1.4815325108926377e-06
# ===============
# Time step: 656
# Strain: 1.4734308760929501e-06
# ===============
# Time step: 657
# Strain: 1.463875142908024e-06
# ===============
# Time step: 658
# Strain: 1.4528747416928355e-06
# ===============
# Time step: 659
# Strain: 1.4404405285152906e-06
# ===============
# Time step: 660
# Strain: 1.4265847744425909e-06
# ===============
# Time step: 661
# Strain: 1.4113211534311863e-06
# ===============
# Time step: 662
# Strain: 1.394664728832211e-06
# ===============
# Time step: 663
# Strain: 1.3766319385257937e-06
# ===============
# Time step: 664
# Strain: 1.3572405786988351e-06
# ===============
# Time step: 665
# Strain: 1.3365097862823461e-06
# ===============
# Time step: 666
# Strain: 1.314460020065576e-06
# ===============
# Time step: 667
# Strain: 1.2911130405056851e-06
# ===============
# Time step: 668
# Strain: 1.266491888252776e-06
# ===============
# Time step: 669
# Strain: 1.2406208614115856e-06
# ===============
# Time step: 670
# Strain: 1.213525491562151e-06
# ===============
# Time step: 671
# Strain: 1.1852325185632556e-06
# ===============
# Time step: 672
# Strain: 1.1557698641633877e-06
# ===============
# Time step: 673
# Strain: 1.1251666044453841e-06
# ===============
# Time step: 674
# Strain: 1.0934529411317997e-06
# ===============
# Time step: 675
# Strain: 1.0606601717794953e-06
# ===============
# Time step: 676
# Strain: 1.0268206588926914e-06
# ===============
# Time step: 677
# Strain: 9.919677979851245e-07
# ===============
# Time step: 678
# Strain: 9.561359846226737e-07
# ===============
# Time step: 679
# Strain: 9.193605804790929e-07
# ===============
# Time step: 680
# Strain: 8.81677878438327e-07
# ===============
# Time step: 681
# Strain: 8.431250667778027e-07
# ===============
# Time step: 682
# Strain: 8.03740192468096e-07
# ===============
# Time step: 683
# Strain: 7.635621236251481e-07
# ===============
# Time step: 684
# Strain: 7.226305111521547e-07
# ===============
# Time step: 685
# Strain: 6.809857496088928e-07
# ===============
# Time step: 686
# Strain: 6.386689373471776e-07
# ===============
# Time step: 687
# Strain: 5.957218359517312e-07
# ===============
# Time step: 688
# Strain: 5.521868290265693e-07
# ===============
# Time step: 689
# Strain: 5.081068803674818e-07
# ===============
# Time step: 690
# Strain: 4.6352549156196366e-07
# ===============
# Time step: 691
# Strain: 4.184866590583797e-07
# ===============
# Time step: 692
# Strain: 3.7303483074681164e-07
# ===============
# Time step: 693
# Strain: 3.272148620943374e-07
# ===============
# Time step: 694
# Strain: 2.810719718781103e-07
# ===============
# Time step: 695
# Strain: 2.3465169755986465e-07
# ===============
# Time step: 696
# Strain: 1.8799985034597016e-07
# ===============
# Time step: 697
# Strain: 1.4116246997728121e-07
# ===============
# Time step: 698
# Strain: 9.418577929348151e-08
# ===============
# Time step: 699
# Strain: 4.711613861670076e-08
# ===============
# Time step: 700
# Strain: -4.9431767905356515e-19
# ===============
# Time step: 701
# Strain: -4.7116138617688904e-08
# ===============
# Time step: 702
# Strain: -9.418577929446288e-08
# ===============
# Time step: 703
# Strain: -1.4116246997826544e-07
# ===============
# Time step: 704
# Strain: -1.87999850346951e-07
# ===============
# Time step: 705
# Strain: -2.3465169756084112e-07
# ===============
# Time step: 706
# Strain: -2.8107197187907617e-07
# ===============
# Time step: 707
# Strain: -3.272148620953022e-07
# ===============
# Time step: 708
# Strain: -3.730348307477692e-07
# ===============
# Time step: 709
# Strain: -4.1848665905932903e-07
# ===============
# Time step: 710
# Strain: -4.635254915628989e-07
# ===============
# Time step: 711
# Strain: -5.081068803684119e-07
# ===============
# Time step: 712
# Strain: -5.521868290274884e-07
# ===============
# Time step: 713
# Strain: -5.957218359526385e-07
# ===============
# Time step: 714
# Strain: -6.386689373480721e-07
# ===============
# Time step: 715
# Strain: -6.809857496097737e-07
# ===============
# Time step: 716
# Strain: -7.226305111530257e-07
# ===============
# Time step: 717
# Strain: -7.635621236259992e-07
# ===============
# Time step: 718
# Strain: -8.037401924689307e-07
# ===============
# Time step: 719
# Strain: -8.431250667786204e-07
# ===============
# Time step: 720
# Strain: -8.816778784391312e-07
# ===============
# Time step: 721
# Strain: -9.193605804798741e-07
# ===============
# Time step: 722
# Strain: -9.561359846234354e-07
# ===============
# Time step: 723
# Strain: -9.91967797985866e-07
# ===============
# Time step: 724
# Strain: -1.0268206588934159e-06
# ===============
# Time step: 725
# Strain: -1.0606601717801905e-06
# ===============
# Time step: 726
# Strain: -1.0934529411324764e-06
# ===============
# Time step: 727
# Strain: -1.1251666044460342e-06
# ===============
# Time step: 728
# Strain: -1.1557698641640213e-06
# ===============
# Time step: 729
# Strain: -1.1852325185638583e-06
# ===============
# Time step: 730
# Strain: -1.2135254915627322e-06
# ===============
# Time step: 731
# Strain: -1.2406208614121383e-06
# ===============
# Time step: 732
# Strain: -1.2664918882533087e-06
# ===============
# Time step: 733
# Strain: -1.2911130405061857e-06
# ===============
# Time step: 734
# Strain: -1.3144600200660522e-06
# ===============
# Time step: 735
# Strain: -1.3365097862827925e-06
# ===============
# Time step: 736
# Strain: -1.3572405786992584e-06
# ===============
# Time step: 737
# Strain: -1.3766319385261842e-06
# ===============
# Time step: 738
# Strain: -1.3946647288325749e-06
# ===============
# Time step: 739
# Strain: -1.4113211534315191e-06
# ===============
# Time step: 740
# Strain: -1.426584774442898e-06
# ===============
# Time step: 741
# Strain: -1.440440528515565e-06
# ===============
# Time step: 742
# Strain: -1.4528747416930814e-06
# ===============
# Time step: 743
# Strain: -1.4638751429082397e-06
# ===============
# Time step: 744
# Strain: -1.4734308760931354e-06
# ===============
# Time step: 745
# Strain: -1.4815325108927917e-06
# ===============
# Time step: 746
# Strain: -1.4881720519717852e-06
# ===============
# Time step: 747
# Strain: -1.4933429469046717e-06
# ===============
# Time step: 748
# Strain: -1.497040092642442e-06
# ===============
# Time step: 749
# Strain: -1.4992598405486146e-06
# ===============
# Time step: 750
# Strain: -1.5e-06
# ===============
# Time step: 751
# Strain: -1.49925984054858e-06
# ===============
# Time step: 752
# Strain: -1.4970400926423726e-06
# ===============
# Time step: 753
# Strain: -1.4933429469045676e-06
# ===============
# Time step: 754
# Strain: -1.4881720519716473e-06
# ===============
# Time step: 755
# Strain: -1.4815325108926195e-06
# ===============
# Time step: 756
# Strain: -1.4734308760929281e-06
# ===============
# Time step: 757
# Strain: -1.4638751429079987e-06
# ===============
# Time step: 758
# Strain: -1.4528747416928078e-06
# ===============
# Time step: 759
# Strain: -1.440440528515258e-06
# ===============
# Time step: 760
# Strain: -1.4265847744425564e-06
# ===============
# Time step: 761
# Strain: -1.4113211534311465e-06
# ===============
# Time step: 762
# Strain: -1.39466472883217e-06
# ===============
# Time step: 763
# Strain: -1.3766319385257473e-06
# ===============
# Time step: 764
# Strain: -1.3572405786987875e-06
# ===============
# Time step: 765
# Strain: -1.336509786282293e-06
# ===============
# Time step: 766
# Strain: -1.3144600200655221e-06
# ===============
# Time step: 767
# Strain: -1.2911130405056256e-06
# ===============
# Time step: 768
# Strain: -1.2664918882527162e-06
# ===============
# Time step: 769
# Strain: -1.24062086141152e-06
# ===============
# Time step: 770
# Strain: -1.2135254915620853e-06
# ===============
# Time step: 771
# Strain: -1.1852325185631839e-06
# ===============
# Time step: 772
# Strain: -1.1557698641633166e-06
# ===============
# Time step: 773
# Strain: -1.1251666044453066e-06
# ===============
# Time step: 774
# Strain: -1.0934529411317232e-06
# ===============
# Time step: 775
# Strain: -1.0606601717794125e-06
# ===============
# Time step: 776
# Strain: -1.0268206588926097e-06
# ===============
# Time step: 777
# Strain: -9.919677979850406e-07
# ===============
# Time step: 778
# ...
# Strain: -1.493342946901476e-06
# ===============
# Time step: 9748
# Strain: -1.497040092640303e-06
# ===============
# Time step: 9749
# Strain: -1.4992598405475441e-06
# ===============
# Time step: 9750
# Strain: -1.5e-06
# ===============
# Time step: 9751
# Strain: -1.4992598405496517e-06
# ===============
# Time step: 9752
# Strain: -1.4970400926445165e-06
# ===============
# Time step: 9753
# Strain: -1.4933429469077829e-06
# ===============
# Time step: 9754
# Strain: -1.488172051975942e-06
# ===============
# Time step: 9755
# Strain: -1.4815325108979834e-06
# ===============
# Time step: 9756
# Strain: -1.4734308760993573e-06
# ===============
# Time step: 9757
# Strain: -1.4638751429154877e-06
# ===============
# Time step: 9758
# Strain: -1.4528747417013707e-06
# ===============
# Time step: 9759
# Strain: -1.4404405285248465e-06
# ===============
# Time step: 9760
# Strain: -1.4265847744531832e-06
# ===============
# Time step: 9761
# Strain: -1.4113211534428315e-06
# ===============
# Time step: 9762
# Strain: -1.3946647288448744e-06
# ===============
# Time step: 9763
# Strain: -1.376631938539462e-06
# ===============
# Time step: 9764
# Strain: -1.3572405787135362e-06
# ===============
# Time step: 9765
# Strain: -1.3365097862980287e-06
# ===============
# Time step: 9766
# Strain: -1.3144600200822277e-06
# ===============
# Time step: 9767
# Strain: -1.2911130405232884e-06
# ===============
# Time step: 9768
# Strain: -1.2664918882713198e-06
# ===============
# Time step: 9769
# Strain: -1.240620861431047e-06
# ===============
# Time step: 9770
# Strain: -1.2135254915825149e-06
# ===============
# Time step: 9771
# Strain: -1.1852325185845517e-06
# ===============
# Time step: 9772
# Strain: -1.155769864185553e-06
# ===============
# Time step: 9773
# Strain: -1.1251666044683904e-06
# ===============
# Time step: 9774
# Strain: -1.0934529411556873e-06
# ===============
# Time step: 9775
# Strain: -1.060660171804121e-06
# ===============
# Time step: 9776
# Strain: -1.026820658918098e-06
# ===============
# Time step: 9777
# Strain: -9.91967798011348e-07
# ===============
# Time step: 9778
# Strain: -9.56135984649623e-07
# ===============
# Time step: 9779
# Strain: -9.193605805067458e-07
# ===============
# Time step: 9780
# Strain: -8.816778784666572e-07
# ===============
# Time step: 9781
# Strain: -8.431250668068536e-07
# ===============
# Time step: 9782
# Strain: -8.037401924977662e-07
# ===============
# Time step: 9783
# Strain: -7.635621236554136e-07
# ===============
# Time step: 9784
# Strain: -7.22630511182986e-07
# ===============
# Time step: 9785
# Strain: -6.809857496402603e-07
# ===============
# Time step: 9786
# Strain: -6.386689373790461e-07
# ===============
# Time step: 9787
# Strain: -5.957218359841528e-07
# ===============
# Time step: 9788
# Strain: -5.521868290594354e-07
# ===============
# Time step: 9789
# Strain: -5.081068804007604e-07
# ===============
# Time step: 9790
# Strain: -4.6352549159569866e-07
# ===============
# Time step: 9791
# Strain: -4.1848665909238084e-07
# ===============
# Time step: 9792
# Strain: -3.73034830781127e-07
# ===============
# Time step: 9793
# Strain: -3.272148621290166e-07
# ===============
# Time step: 9794
# Strain: -2.8107197191303155e-07
# ===============
# Time step: 9795
# Strain: -2.3465169759499894e-07
# ===============
# Time step: 9796
# Strain: -1.8799985038128312e-07
# ===============
# Time step: 9797
# Strain: -1.4116247001282296e-07
# ===============
# Time step: 9798
# Strain: -9.418577932912718e-08
# ===============
# Time step: 9799
# Strain: -4.711613865233538e-08
# ===============
# Time step: 9800
# Strain: -3.526447471532724e-17
# ===============
# Time step: 9801
# Strain: 4.711613858192646e-08
# ===============
# Time step: 9802
# Strain: 9.418577925873741e-08
# ===============
# Time step: 9803
# Strain: 1.4116246994252213e-07
# ===============
# Time step: 9804
# Strain: 1.8799985031131028e-07
# ===============
# Time step: 9805
# Strain: 2.3465169752533835e-07
# ===============
# Time step: 9806
# Strain: 2.810719718437519e-07
# ===============
# Time step: 9807
# Strain: 3.272148620601862e-07
# ===============
# Time step: 9808
# Strain: 3.7303483071289644e-07
# ===============
# Time step: 9809
# Strain: 4.184866590247342e-07
# ===============
# Time step: 9810
# Strain: 4.6352549152854054e-07
# ===============
# Time step: 9811
# Strain: 5.081068803344011e-07
# ===============
# Time step: 9812
# Strain: 5.521868289938593e-07
# ===============
# Time step: 9813
# Strain: 5.957218359193462e-07
# ===============
# Time step: 9814
# Strain: 6.386689373152297e-07
# ===============
# Time step: 9815
# Strain: 6.809857495774946e-07
# ===============
# Time step: 9816
# Strain: 7.22630511121181e-07
# ===============
# Time step: 9817
# Strain: 7.635621235947063e-07
# ===============
# Time step: 9818
# Strain: 8.037401924382168e-07
# ===============
# Time step: 9819
# Strain: 8.431250667484501e-07
# ===============
# Time step: 9820
# Strain: 8.816778784095982e-07
# ===============
# Time step: 9821
# Strain: 9.19360580451017e-07
# ===============
# Time step: 9822
# Strain: 9.561359845952794e-07
# ===============
# Time step: 9823
# Strain: 9.919677979583792e-07
# ===============
# Time step: 9824
# Strain: 1.0268206588667466e-06
# ===============
# Time step: 9825
# Strain: 1.06066017175431e-06
# ===============
# Time step: 9826
# Strain: 1.0934529411073486e-06
# ===============
# Time step: 9827
# Strain: 1.1251666044217487e-06
# ===============
# Time step: 9828
# Strain: 1.155769864140596e-06
# ===============
# Time step: 9829
# Strain: 1.185232518541272e-06
# ===============
# Time step: 9830
# Strain: 1.213525491541059e-06
# ===============
# Time step: 9831
# Strain: 1.240620861391404e-06
# ===============
# Time step: 9832
# Strain: 1.2664918882335283e-06
# ===============
# Time step: 9833
# Strain: 1.2911130404873862e-06
# ===============
# Time step: 9834
# Strain: 1.3144600200482503e-06
# ===============
# Time step: 9835
# Strain: 1.3365097862660094e-06
# ===============
# Time step: 9836
# Strain: 1.3572405786834704e-06
# ===============
# Time step: 9837
# Strain: 1.3766319385114515e-06
# ===============
# Time step: 9838
# Strain: 1.394664728818911e-06
# ===============
# Time step: 9839
# Strain: 1.411321153418912e-06
# ===============
# Time step: 9840
# Strain: 1.4265847744314147e-06
# ===============
# Time step: 9841
# Strain: 1.4404405285051934e-06
# ===============
# Time step: 9842
# Strain: 1.4528747416838095e-06
# ===============
# Time step: 9843
# Strain: 1.463875142900102e-06
# ===============
# Time step: 9844
# Strain: 1.4734308760861413e-06
# ===============
# Time step: 9845
# Strain: 1.4815325108869501e-06
# ===============
# Time step: 9846
# Strain: 1.4881720519670918e-06
# ===============
# Time step: 9847
# Strain: 1.4933429469011455e-06
# ===============
# Time step: 9848
# Strain: 1.497040092640088e-06
# ===============
# Time step: 9849
# Strain: 1.4992598405474365e-06
# ===============
# Time step: 9850
# Strain: 1.5e-06
# ===============
# Time step: 9851
# Strain: 1.4992598405497595e-06
# ===============
# Time step: 9852
# Strain: 1.4970400926447371e-06
# ===============
# Time step: 9853
# Strain: 1.4933429469081134e-06
# ===============
# Time step: 9854
# Strain: 1.4881720519763714e-06
# ===============
# Time step: 9855
# Strain: 1.4815325108985193e-06
# ===============
# Time step: 9856
# Strain: 1.4734308760999992e-06
# ===============
# Time step: 9857
# Strain: 1.463875142916235e-06
# ===============
# Time step: 9858
# Strain: 1.4528747417022228e-06
# ===============
# Time step: 9859
# Strain: 1.440440528525826e-06
# ===============
# Time step: 9860
# Strain: 1.4265847744542683e-06
# ===============
# Time step: 9861
# Strain: 1.4113211534439923e-06
# ===============
# Time step: 9862
# Strain: 1.3946647288461674e-06
# ===============
# Time step: 9863
# Strain: 1.3766319385408567e-06
# ===============
# Time step: 9864
# Strain: 1.3572405787149593e-06
# ===============
# Time step: 9865
# Strain: 1.3365097862995845e-06
# ===============
# Time step: 9866
# Strain: 1.3144600200838788e-06
# ===============
# Time step: 9867
# Strain: 1.2911130405250326e-06
# ===============
# Time step: 9868
# Strain: 1.2664918882732017e-06
# ===============
# Time step: 9869
# Strain: 1.2406208614330212e-06
# ===============
# Time step: 9870
# Strain: 1.213525491584579e-06
# ===============
# Time step: 9871
# Strain: 1.1852325185866522e-06
# ===============
# Time step: 9872
# Strain: 1.1557698641877372e-06
# ===============
# Time step: 9873
# Strain: 1.1251666044706566e-06
# ===============
# Time step: 9874
# Strain: 1.0934529411579747e-06
# ===============
# Time step: 9875
# Strain: 1.0606601718066044e-06
# ===============
# Time step: 9876
# Strain: 1.0268206589206581e-06
# ===============
# Time step: 9877
# Strain: 9.919677980139183e-07
# ===============
# Time step: 9878
# Strain: 9.561359846523288e-07
# ===============
# Time step: 9879
# Strain: 9.193605805095207e-07
# ===============
# Time step: 9880
# Strain: 8.816778784694986e-07
# ===============
# Time step: 9881
# Strain: 8.431250668096879e-07
# ===============
# Time step: 9882
# Strain: 8.037401925006596e-07
# ===============
# Time step: 9883
# Strain: 7.63562123658363e-07
# ===============
# Time step: 9884
# Strain: 7.22630511185989e-07
# ===============
# Time step: 9885
# Strain: 6.809857496433896e-07
# ===============
# Time step: 9886
# Strain: 6.386689373822239e-07
# ===============
# Time step: 9887
# Strain: 5.957218359872978e-07
# ===============
# Time step: 9888
# Strain: 5.521868290627007e-07
# ===============
# Time step: 9889
# Strain: 5.081068804039847e-07
# ===============
# Time step: 9890
# Strain: 4.635254915988766e-07
# ===============
# Time step: 9891
# Strain: 4.1848665909575346e-07
# ===============
# Time step: 9892
# Strain: 3.730348307845287e-07
# ===============
# Time step: 9893
# Strain: 3.272148621323608e-07
# ===============
# Time step: 9894
# Strain: 2.810719719163976e-07
# ===============
# Time step: 9895
# Strain: 2.3465169759846778e-07
# ===============
# Time step: 9896
# Strain: 1.8799985038476744e-07
# ===============
# Time step: 9897
# Strain: 1.411624700162345e-07
# ===============
# Time step: 9898
# Strain: 9.41857793325472e-08
# ===============
# Time step: 9899
# Strain: 4.711613865584569e-08
# ===============
# Time step: 9900
# Strain: 3.869125075555019e-17
# ===============
# Time step: 9901
# Strain: -4.711613857841614e-08
# ===============
# Time step: 9902
# Strain: -9.41857792552323e-08
# ===============
# Time step: 9903
# Strain: -1.4116246993911055e-07
# ===============
# Time step: 9904
# Strain: -1.8799985030782596e-07
# ===============
# Time step: 9905
# Strain: -2.346516975219538e-07
# ===============
# Time step: 9906
# Strain: -2.8107197184038577e-07
# ===============
# Time step: 9907
# Strain: -3.272148620567587e-07
# ===============
# Time step: 9908
# Strain: -3.730348307094947e-07
# ===============
# Time step: 9909
# Strain: -4.184866590213617e-07
# ===============
# Time step: 9910
# Strain: -4.6352549152528147e-07
# ===============
# Time step: 9911
# Strain: -5.081068803310967e-07
# ===============
# Time step: 9912
# Strain: -5.521868289905938e-07
# ===============
# Time step: 9913
# Strain: -5.957218359162797e-07
# ===============
# Time step: 9914
# Strain: -6.38668937312129e-07
# ===============
# Time step: 9915
# Strain: -6.809857495743653e-07
# ===============
# Time step: 9916
# Strain: -7.226305111181781e-07
# ===============
# Time step: 9917
# Strain: -7.635621235916834e-07
# ===============
# Time step: 9918
# Strain: -8.037401924352513e-07
# ===============
# Time step: 9919
# Strain: -8.431250667456158e-07
# ===============
# Time step: 9920
# Strain: -8.816778784068258e-07
# ===============
# Time step: 9921
# Strain: -9.193605804483092e-07
# ===============
# Time step: 9922
# Strain: -9.56135984592639e-07
# ===============
# Time step: 9923
# Strain: -9.919677979558728e-07
# ===============
# Time step: 9924
# Strain: -1.0268206588641865e-06
# ===============
# Time step: 9925
# Strain: -1.0606601717518266e-06
# ===============
# Time step: 9926
# Strain: -1.0934529411050027e-06
# ===============
# Time step: 9927
# Strain: -1.1251666044194262e-06
# ===============
# Time step: 9928
# Strain: -1.1557698641383573e-06
# ===============
# Time step: 9929
# Strain: -1.1852325185392238e-06
# ===============
# Time step: 9930
# Strain: -1.2135254915390447e-06
# ===============
# Time step: 9931
# Strain: -1.2406208613894778e-06
# ===============
# Time step: 9932
# Strain: -1.2664918882316924e-06
# ===============
# Time step: 9933
# Strain: -1.2911130404855984e-06
# ===============
# Time step: 9934
# Strain: -1.3144600200465583e-06
# ===============
# Time step: 9935
# Strain: -1.3365097862644146e-06
# ===============
# Time step: 9936
# Strain: -1.3572405786820112e-06
# ===============
# Time step: 9937
# Strain: -1.3766319385100905e-06
# ===============
# Time step: 9938
# Strain: -1.3946647288176495e-06
# ===============
# Time step: 9939
# Strain: -1.4113211534177799e-06
# ===============
# Time step: 9940
# Strain: -1.4265847744303294e-06
# ===============
# Time step: 9941
# Strain: -1.4404405285042134e-06
# ===============
# Time step: 9942
# Strain: -1.4528747416829572e-06
# ===============
# Time step: 9943
# Strain: -1.463875142899336e-06
# ===============
# Time step: 9944
# Strain: -1.4734308760854833e-06
# ===============
# Time step: 9945
# Strain: -1.4815325108864008e-06
# ===============
# Time step: 9946
# Strain: -1.4881720519666623e-06
# ===============
# Time step: 9947
# Strain: -1.493342946900823e-06
# ===============
# Time step: 9948
# Strain: -1.4970400926398728e-06
# ===============
# Time step: 9949
# Strain: -1.4992598405473288e-06
# ===============
# Time step: 9950
# Strain: -1.5e-06
# ===============
# Time step: 9951
# Strain: -1.4992598405498699e-06
# ===============
# Time step: 9952
# Strain: -1.4970400926449523e-06
# ===============
# Time step: 9953
# Strain: -1.4933429469084438e-06
# ===============
# Time step: 9954
# Strain: -1.4881720519768009e-06
# ===============
# Time step: 9955
# Strain: -1.4815325108990555e-06
# ===============
# Time step: 9956
# Strain: -1.4734308761006573e-06
# ===============
# Time step: 9957
# Strain: -1.4638751429170012e-06
# ===============
# Time step: 9958
# Strain: -1.452874741703075e-06
# ===============
# Time step: 9959
# Strain: -1.4404405285267821e-06
# ===============
# Time step: 9960
# Strain: -1.4265847744553535e-06
# ===============
# Time step: 9961
# Strain: -1.411321153445182e-06
# ===============
# Time step: 9962
# Strain: -1.3946647288474289e-06
# ===============
# Time step: 9963
# Strain: -1.3766319385422177e-06
# ===============
# Time step: 9964
# Strain: -1.3572405787164545e-06
# ===============
# Time step: 9965
# Strain: -1.33650978630114e-06
# ===============
# Time step: 9966
# Strain: -1.3144600200855705e-06
# ===============
# Time step: 9967
# Strain: -1.2911130405268205e-06
# ===============
# Time step: 9968
# Strain: -1.2664918882750376e-06
# ===============
# Time step: 9969
# Strain: -1.2406208614349474e-06
# ===============
# Time step: 9970
# Strain: -1.2135254915865933e-06
# ===============
# Time step: 9971
# Strain: -1.1852325185887524e-06
# ===============
# Time step: 9972
# Strain: -1.155769864189976e-06
# ===============
# Time step: 9973
# Strain: -1.125166604472979e-06
# ===============
# Time step: 9974
# Strain: -1.093452941160379e-06
# ===============
# Time step: 9975
# Strain: -1.0606601718090278e-06
# ===============
# Time step: 9976
# Strain: -1.0268206589232183e-06
# ===============
# Time step: 9977
# Strain: -9.919677980165528e-07
# ===============
# Time step: 9978
# Strain: -9.561359846549036e-07
# ===============
# Time step: 9979
# Strain: -9.193605805122285e-07
# ===============
# Time step: 9980
# Strain: -8.816778784722709e-07
# ===============
# Time step: 9981
# Strain: -8.431250668125221e-07
# ===============
# Time step: 9982
# Strain: -8.037401925036249e-07
# ===============
# Time step: 9983
# Strain: -7.635621236613862e-07
# ===============
# Time step: 9984
# Strain: -7.226305111890665e-07
# ===============
# Time step: 9985
# Strain: -6.809857496464428e-07
# ===============
# Time step: 9986
# Strain: -6.386689373853246e-07
# ===============
# Time step: 9987
# Strain: -5.957218359904427e-07
# ===============
# Time step: 9988
# Strain: -5.521868290658076e-07
# ===============
# Time step: 9989
# Strain: -5.08106880407289e-07
# ===============
# Time step: 9990
# Strain: -4.635254916022168e-07
# ===============
# Time step: 9991
# Strain: -4.184866590990442e-07
# ===============
# Time step: 9992
# Strain: -3.7303483078793037e-07
# ===============
# Time step: 9993
# Strain: -3.272148621357883e-07
# ===============
# Time step: 9994
# Strain: -2.8107197191976366e-07
# ===============
# Time step: 9995
# Strain: -2.3465169760185237e-07
# ===============
# Time step: 9996
# Strain: -1.879998503881672e-07
# ===============
# Time step: 9997
# Strain: -1.4116247001964607e-07
# ===============
# Time step: 9998
# Strain: -9.418577933596721e-08
# ===============
# Time step: 9999
# Strain: -4.7116138659356004e-08
# <img src="data:image/png;base64,..." width="572.85">
# Total time: 54.38919949531555
# Solving time: 34.610677003860474

# %% [markdown]
# # BC2

# %%
# parameters["ghost_mode"] = "shared_facet"

# compare upwind flux with lax-friedrichs flux
lx = 1
m_size = lx*80
mesh = IntervalMesh(m_size, 0.0, lx)

# Material properties
mu = Constant(14e9)
rho = Constant(2.2e3)
gamma = Constant(10)
tau_min = 1e-3
tau_max = 10e-3
tau = tau_min*gamma # \tau_1 in the literature


beta_E = 50
delta_E = 1e8

delta_t = 1e-6
t_total = 10e-3

t_excitation = 40e-3

fc = 5e3

A_amp = 1.5e-6

g0 = 1e-2

deg_dg = 1 # DG degree

def mu_fun(eps):
    return mu * (1 - 2*beta_E*eps - 3 * delta_E*eps*eps)

def stress_fun(eps):
    return mu * eps * (1 - beta_E*eps - delta_E*eps*eps)

def energy_fun(eps):
    return mu * eps * eps * (0.5 - beta_E/3*eps  - delta_E/4*eps*eps)

EPS_SMALL = 1e-4
def phig_fun(g_inti):
    return g_inti/(tau_max*(exp(-g_inti/g0*math.log(tau_max/tau_min)))\
                            *(g_inti/g0*math.log(tau_max/tau_min)* (1-ln(g_inti/g0+EPS_SMALL)) + 1) \
                    + tau_min*(g_inti)/g0*math.log(tau_max/tau_min) )

A_amp1 = float(stress_fun(A_amp)/rho)

A_amp2 = -float(sqrt(mu_fun(A_amp)/rho)*A_amp)

def flux_fun(q_f):
    (eps,vel, g_int) = split(q_f)
    return as_vector([-vel('+'), -(1-g_int('+'))*stress_fun(eps('+'))/rho ,0]) \
           + as_vector([-vel('-'), -(1-g_int('-'))*stress_fun(eps('-'))/rho ,0])

def AStar_fun(q_f):
    (eps, vel, g_int) = split(q_f)
    a = (1 - 0.5*(g_int('+')+g_int('-')) ) * mu_fun((eps('+')+eps('-'))*0.5)/rho
    b = stress_fun((eps('+')+eps('-'))*0.5)/rho
    RStar = as_tensor([[1, 1, b], \
                       [sqrt(a), -sqrt(a), 0], \
                       [0, 0, a]])
    RStar_inv = as_tensor([[1/2, 1/2/sqrt(a), -b/a/2], \
                           [1/2, -1/2/sqrt(a), -b/a/2], \
                           [0, 0, 1/a]])
    Lamb = as_tensor([[sqrt(a), 0, 0], \
                      [0, sqrt(a), 0], \
                      [0, 0, 0]])
    return dot(dot(RStar,Lamb),RStar_inv)

# Function space
Ee = FiniteElement("DG", mesh.ufl_cell(), deg_dg)
Ve = FiniteElement("DG", mesh.ufl_cell(), deg_dg)
Ge = FiniteElement("DG", mesh.ufl_cell(), deg_dg)
V_dg = FunctionSpace(mesh, MixedElement([Ee, Ve, Ge]))

phi, v = TrialFunction(V_dg), TestFunction(V_dg)
q_new, q_old = Function(V_dg), Function(V_dg)
q_rk = Function(V_dg)

q0 = Expression(("0","0","0"), degree=1, t=0, name='q0') # 
q_old = project(q0, V_dg)

v_exact = Expression("(t<tc1 ) ? A*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ", \
                     degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp, lx = lx) # 

v_exact2 = Expression("(t<tc1 ) ? A*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ", \
                     degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp2, lx = lx) # 

v_exactr = Expression(" 0 ", \
                     degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp, lx = lx) # 

f_ext = Expression(("(t<tc1 ) ? -A1*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ",\
                    "(t<tc1 ) ? -A2*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ",\
                    "0"), \
                   degree=1, t=0, tc1=t_excitation, c=fc, A1=A_amp2, A2=A_amp1, lx = lx) #

DOFIN_EPS = 1e-10 # + lx/m_size/2
if deg_dg == 0: DOFIN_EPS = 1e-10 + lx/m_size/2
def left(x, on_boundary):
    return abs(x[0]-0.) < DOFIN_EPS
def right(x, on_boundary):
    return abs(x[0]-lx) < DOFIN_EPS

boundary_markers = MeshFunction('size_t', mesh, mesh.topology().dim() - 1)

class BoundaryNR(SubDomain):
    def inside(self, x, on_boundary):
        DOFIN_EPS = 1e-10 # + lx/m_size/2
        if deg_dg == 0: DOFIN_EPS = 1e-10 + lx/m_size/2
        return on_boundary and near(x[0], lx, DOFIN_EPS)
    
class BoundaryNL(SubDomain):
    def inside(self, x, on_boundary):
        DOFIN_EPS = 1e-10 # + lx/m_size/2
        if deg_dg == 0: DOFIN_EPS = 1e-10 + lx/m_size/2
        return on_boundary and near(x[0], 0, DOFIN_EPS)

bx0 = BoundaryNR()
bx0.mark(boundary_markers, 0)
bx0 = BoundaryNL()
bx0.mark(boundary_markers, 1)

dss = Measure('ds', domain=mesh, subdomain_data=boundary_markers)

bc =  [DirichletBC(V_dg.sub(0), v_exact, left, method="pointwise")]

# Weak form
n = FacetNormal(mesh)

(eps1,vel1, g_int1) = split(q_old)
mu1 = mu_fun(eps1)
sig1 = stress_fun(eps1)

c_speed1 = sqrt((1-g_int1)*mu1/rho)

W_energy1 = energy_fun(eps1)

A_adv1 = as_tensor([[0, -1, 0], \
                    [-(1-g_int1)*mu1/rho, 0, sig1/rho], \
                    [0, 0, 0]])

R1 = as_tensor([[1, 1, sig1/rho], \
                [c_speed1, -c_speed1, 0], \
                [0,0,c_speed1*c_speed1]])
R_inv1 = as_tensor([[1/2, 1/c_speed1/2, -sig1/rho/c_speed1/c_speed1/2], \
                    [1/2, -1/c_speed1/2, -sig1/rho/c_speed1/c_speed1/2], \
                    [0, 0, 1/c_speed1/c_speed1] ])
Lambda_adv_abs1 = as_tensor([[c_speed1, 0, 0], \
                             [0, c_speed1, 0], \
                             [0, 0, 0] ])

A_adv_abs1 = dot( dot(R1, Lambda_adv_abs1), R_inv1)

A_adv_plus1 = (A_adv1 + A_adv_abs1)/2
A_adv_minus1 = (A_adv1 - A_adv_abs1)/2

F = dot( (phi-q_old)/delta_t, v) * dx 

flux_inner1 = as_vector([-vel1, -(1-g_int1)*sig1/rho, 0])
# F1 = F - dot(dot(A_adv1,q_old), grad(v)[:,0]) * dx
F1 = F - dot(flux_inner1, grad(v)[:,0]) * dx

r1 = as_vector([0, 0, 1/tau*W_energy1 - phig_fun(g_int1)])
F1 += - dot(r1, v) * dx

flux1 = dot(A_adv_plus1('+'), q_old('+')) + dot(A_adv_minus1('-'), q_old('-'))

# Roe solver
flux1 = 0.5*( flux_fun(q_old) \
             - dot( AStar_fun(q_old), q_old('-')-q_old('+')  ) ) 

F1 += dot( flux1*n('+')[0], jump(v)) * dS + dot(flux_inner1,v)*n[0] * dss(0) + dot(flux_inner1,v)*n[0] * dss(1)

(eps2,vel2, g_int2) = split(q_rk)
mu2 = mu_fun(eps2)
sig2 = stress_fun(eps2)

c_speed2 = sqrt((1-g_int2)*mu2/rho)

W_energy2 = energy_fun(eps2)

A_adv2 = as_tensor([[0, -1, 0], \
                    [-(1-g_int2)*mu2/rho, 0, sig2/rho], \
                    [0, 0, 0]])

R2 = as_tensor([[1, 1, sig2/rho], \
                [c_speed2, -c_speed2, 0], \
                [0,0,c_speed2*c_speed2]])
R_inv2 = as_tensor([[1/2, 1/c_speed2/2, -sig2/rho/c_speed2/c_speed2/2], \
                    [1/2, -1/c_speed2/2, -sig2/rho/c_speed2/c_speed2/2], \
                    [0, 0, 1/c_speed2/c_speed2] ])
Lambda_adv_abs2 = as_tensor([[c_speed2, 0, 0], \
                             [0, c_speed2, 0], \
                             [0, 0, 0] ])

A_adv_abs2 = dot( dot(R2, Lambda_adv_abs2), R_inv2)

A_adv_plus2 = (A_adv2 + A_adv_abs2)/2
A_adv_minus2 = (A_adv2 - A_adv_abs2)/2

flux_inner2 = as_vector([-vel2, -(1-g_int2)*sig2/rho, 0])
# F2 = - dot(dot(A_adv2,q_rk), grad(v)[:,0]) * dx
F2 = - dot(flux_inner2, grad(v)[:,0]) * dx

r2 = as_vector([0, 0, 1/tau*W_energy2 - phig_fun(g_int2)])

F2 += - dot(r2, v) * dx

flux2 = dot(A_adv_plus2('+'), q_rk('+')) + dot(A_adv_minus2('-'), q_rk('-'))

# Roe solver
flux2 = 0.5*( flux_fun(q_rk) \
            - dot( AStar_fun(q_rk), q_rk('-')-q_rk('+')  ) ) 

F2 += dot( flux2*n('+')[0], jump(v)) * dS + dot(flux_inner2,v)*n[0] * dss(0) + dot(flux_inner2,v)*n[0] * dss(1)

F += 0.5*((F1-F) + F2)

#===========
Sta1 = time.time()
T_sol = 0
#===========

t = 0
time_steps = int(t_total/delta_t)
uuu2 = np.zeros((time_steps,m_size,3))

a1,L1 = lhs(F1),rhs(F1)
a,L = lhs(F),rhs(F)

for n in range(time_steps):
    print('===============')
    print('Time step:',n)
    
    for i in range(m_size):
        uuu2[n,i,:] = q_old(i/(m_size-1)*lx)[:]
    
 
    T_incre1 = time.time()
    solve(a1==L1, q_new, bc)
    T_incre2 = time.time()
    T_sol += T_incre2-T_incre1
    q_rk.assign(q_new)
        
    
    T_incre1 = time.time()
    solve(a==L, q_new, bc)
    T_incre2 = time.time()
    T_sol += T_incre2-T_incre1
    q_old.assign(q_new)
    print('Strain:',q_old(0)[0])

    t += delta_t
    v_exact.t = t
    f_ext.t = t

T_total = time.time()-Sta1

plt.subplots()
plot(q_old[2])
plt.show()

print("Total time:",T_total)
print("Solving time:",T_sol)
# Out:
# ===============
# Time step: 0
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Strain: 0.0
# ===============
# Time step: 1
# Strain: 4.711613861719244e-08
# ===============
# Time step: 2
# Strain: 9.418577929397006e-08
# ===============
# Time step: 3
# Strain: 1.411624699777715e-07
# ===============
# Time step: 4
# Strain: 1.8799985034645638e-07
# ===============
# Time step: 5
# Strain: 2.346516975603463e-07
# ===============
# Time step: 6
# Strain: 2.8107197187858685e-07
# ===============
# Time step: 7
# Strain: 3.272148620948138e-07
# ===============
# Time step: 8
# Strain: 3.730348307472822e-07
# ===============
# Time step: 9
# Strain: 4.1848665905884395e-07
# ===============
# Time step: 10
# Strain: 4.635254915624211e-07
# ===============
# Time step: 11
# Strain: 5.081068803679372e-07
# ===============
# Time step: 12
# Strain: 5.52186829027017e-07
# ===============
# Time step: 13
# Strain: 5.95721835952171e-07
# ===============
# Time step: 14
# Strain: 6.386689373476092e-07
# ===============
# Time step: 15
# Strain: 6.809857496093203e-07
# ===============
# Time step: 16
# Strain: 7.22630511152573e-07
# ===============
# Time step: 17
# Strain: 7.63562123625557e-07
# ===============
# Time step: 18
# Strain: 8.03740192468495e-07
# ===============
# Time step: 19
# Strain: 8.431250667781961e-07
# ===============
# Time step: 20
# Strain: 8.816778784387099e-07
# ===============
# Time step: 21
# Strain: 9.193605804794649e-07
# ===============
# Time step: 22
# Strain: 9.561359846230348e-07
# ===============
# Time step: 23
# Strain: 9.919677979854781e-07
# ===============
# Time step: 24
# Strain: 1.0268206588930332e-06
# ===============
# Time step: 25
# Strain: 1.0606601717798216e-06
# ===============
# Time step: 26
# Strain: 1.0934529411321173e-06
# ===============
# Time step: 27
# Strain: 1.1251666044456895e-06
# ===============
# Time step: 28
# Strain: 1.155769864163684e-06
# ===============
# Time step: 29
# Strain: 1.1852325185635358e-06
# ===============
# Time step: 30
# Strain: 1.2135254915624213e-06
# ===============
# Time step: 31
# Strain: 1.240620861411843e-06
# ===============
# Time step: 32
# Strain: 1.2664918882530226e-06
# ===============
# Time step: 33
# Strain: 1.2911130405059155e-06
# ===============
# Time step: 34
# Strain: 1.3144600200657955e-06
# ===============
# Time step: 35
# Strain: 1.3365097862825517e-06
# ===============
# Time step: 36
# Strain: 1.3572405786990293e-06
# ===============
# Time step: 37
# Strain: 1.3766319385259716e-06
# ===============
# Time step: 38
# Strain: 1.3946647288323769e-06
# ===============
# Time step: 39
# Strain: 1.411321153431338e-06
# ===============
# Time step: 40
# Strain: 1.4265847744427302e-06
# ===============
# Time step: 41
# Strain: 1.4404405285154143e-06
# ===============
# Time step: 42
# Strain: 1.4528747416929463e-06
# ===============
# Time step: 43
# Strain: 1.4638751429081209e-06
# ===============
# Time step: 44
# Strain: 1.4734308760930327e-06
# ===============
# Time step: 45
# Strain: 1.4815325108927063e-06
# ===============
# Time step: 46
# Strain: 1.4881720519717166e-06
# ===============
# Time step: 47
# Strain: 1.4933429469046199e-06
# ===============
# Time step: 48
# Strain: 1.4970400926424071e-06
# ===============
# Time step: 49
# Strain: 1.4992598405485972e-06
# ===============
# Time step: 50
# Strain: 1.5e-06
# ===============
# Time step: 51
# Strain: 1.4992598405485974e-06
# ===============
# Time step: 52
# Strain: 1.4970400926424076e-06
# ===============
# Time step: 53
# Strain: 1.4933429469046203e-06
# ===============
# Time step: 54
# Strain: 1.488172051971717e-06
# ===============
# Time step: 55
# Strain: 1.4815325108927072e-06
# ===============
# Time step: 56
# Strain: 1.4734308760930336e-06
# ===============
# Time step: 57
# Strain: 1.463875142908122e-06
# ===============
# Time step: 58
# Strain: 1.4528747416929475e-06
# ===============
# Time step: 59
# Strain: 1.4404405285154156e-06
# ===============
# Time step: 60
# Strain: 1.4265847744427315e-06
# ===============
# Time step: 61
# Strain: 1.4113211534313396e-06
# ===============
# Time step: 62
# Strain: 1.3946647288323786e-06
# ===============
# Time step: 63
# Strain: 1.3766319385259733e-06
# ===============
# Time step: 64
# Strain: 1.3572405786990312e-06
# ===============
# Time step: 65
# Strain: 1.3365097862825536e-06
# ===============
# Time step: 66
# Strain: 1.3144600200657976e-06
# ===============
# Time step: 67
# Strain: 1.2911130405059178e-06
# ===============
# Time step: 68
# Strain: 1.2664918882530253e-06
# ===============
# Time step: 69
# Strain: 1.2406208614118452e-06
# ===============
# Time step: 70
# Strain: 1.213525491562424e-06
# ===============
# Time step: 71
# Strain: 1.1852325185635385e-06
# ===============
# Time step: 72
# Strain: 1.155769864163687e-06
# ===============
# Time step: 73
# Strain: 1.125166604445693e-06
# ===============
# Time step: 74
# Strain: 1.093452941132121e-06
# ===============
# Time step: 75
# Strain: 1.0606601717798252e-06
# ===============
# Time step: 76
# Strain: 1.0268206588930372e-06
# ===============
# Time step: 77
# Strain: 9.919677979854823e-07
# ===============
# Time step: 78
# Strain: 9.56135984623039e-07
# ===============
# Time step: 79
# Strain: 9.193605804794699e-07
# ===============
# Time step: 80
# Strain: 8.816778784387148e-07
# ===============
# Time step: 81
# Strain: 8.431250667782013e-07
# ===============
# Time step: 82
# Strain: 8.037401924685006e-07
# ===============
# Time step: 83
# Strain: 7.63562123625563e-07
# ===============
# Time step: 84
# Strain: 7.226305111525787e-07
# ===============
# Time step: 85
# Strain: 6.809857496093263e-07
# ===============
# Time step: 86
# Strain: 6.386689373476154e-07
# ===============
# Time step: 87
# Strain: 5.957218359521771e-07
# ===============
# Time step: 88
# Strain: 5.52186829027024e-07
# ===============
# Time step: 89
# Strain: 5.081068803679439e-07
# ===============
# Time step: 90
# Strain: 4.6352549156242826e-07
# ===============
# Time step: 91
# Strain: 4.1848665905885136e-07
# ===============
# Time step: 92
# Strain: 3.7303483074729e-07
# ===============
# Time step: 93
# Strain: 3.2721486209482125e-07
# ===============
# Time step: 94
# Strain: 2.8107197187859537e-07
# ===============
# Time step: 95
# Strain: 2.346516975603544e-07
# ===============
# Time step: 96
# Strain: 1.8799985034646477e-07
# ===============
# Time step: 97
# Strain: 1.4116246997778014e-07
# ===============
# Time step: 98
# Strain: 9.418577929397835e-08
# ===============
# Time step: 99
# Strain: 4.7116138617201013e-08
# ===============
# Time step: 100
# Strain: 8.843436611948324e-21
# ===============
# Time step: 101
# Strain: -4.7116138617184e-08
# ===============
# Time step: 102
# Strain: -9.418577929396069e-08
# ===============
# Time step: 103
# Strain: -1.4116246997776188e-07
# ===============
# Time step: 104
# Strain: -1.879998503464472e-07
# ===============
# Time step: 105
# Strain: -2.3465169756033693e-07
# ===============
# Time step: 106
# Strain: -2.81071971878578e-07
# ===============
# Time step: 107
# Strain: -3.272148620948047e-07
# ===============
# Time step: 108
# Strain: -3.730348307472722e-07
# ===============
# Time step: 109
# Strain: -4.184866590588337e-07
# ===============
# Time step: 110
# Strain: -4.635254915624114e-07
# ===============
# Time step: 111
# Strain: -5.081068803679272e-07
# ===============
# Time step: 112
# Strain: -5.521868290270076e-07
# ===============
# Time step: 113
# Strain: -5.957218359521615e-07
# ===============
# Time step: 114
# Strain: -6.386689373475988e-07
# ===============
# Time step: 115
# Strain: -6.809857496093105e-07
# ===============
# Time step: 116
# Strain: -7.226305111525631e-07
# ===============
# Time step: 117
# Strain: -7.635621236255477e-07
# ===============
# Time step: 118
# Strain: -8.037401924684857e-07
# ===============
# Time step: 119
# Strain: -8.431250667781871e-07
# ===============
# Time step: 120
# Strain: -8.816778784386999e-07
# ===============
# Time step: 121
# Strain: -9.193605804794555e-07
# ===============
# Time step: 122
# Strain: -9.561359846230253e-07
# ===============
# Time step: 123
# Strain: -9.91967797985469e-07
# ===============
# Time step: 124
# Strain: -1.0268206588930243e-06
# ===============
# Time step: 125
# Strain: -1.0606601717798132e-06
# ===============
# Time step: 126
# Strain: -1.0934529411321093e-06
# ===============
# Time step: 127
# Strain: -1.1251666044456817e-06
# ===============
# Time step: 128
# Strain: -1.1557698641636764e-06
# ===============
# Time step: 129
# Strain: -1.1852325185635284e-06
# ===============
# Time step: 130
# Strain: -1.2135254915624141e-06
# ===============
# Time step: 131
# Strain: -1.2406208614118357e-06
# ===============
# Time step: 132
# Strain: -1.2664918882530158e-06
# ===============
# Time step: 133
# Strain: -1.2911130405059087e-06
# ===============
# Time step: 134
# Strain: -1.3144600200657896e-06
# ===============
# Time step: 135
# Strain: -1.3365097862825458e-06
# ===============
# Time step: 136
# Strain: -1.3572405786990234e-06
# ===============
# Time step: 137
# Strain: -1.3766319385259667e-06
# ===============
# Time step: 138
# Strain: -1.3946647288323724e-06
# ===============
# Time step: 139
# Strain: -1.4113211534313336e-06
# ===============
# Time step: 140
# Strain: -1.4265847744427262e-06
# ===============
# Time step: 141
# Strain: -1.4404405285154107e-06
# ===============
# Time step: 142
# Strain: -1.452874741692943e-06
# ===============
# Time step: 143
# Strain: -1.4638751429081181e-06
# ===============
# Time step: 144
# Strain: -1.4734308760930302e-06
# ===============
# Time step: 145
# Strain: -1.4815325108927044e-06
# ===============
# Time step: 146
# Strain: -1.488172051971715e-06
# ===============
# Time step: 147
# Strain: -1.4933429469046186e-06
# ===============
# Time step: 148
# Strain: -1.4970400926424065e-06
# ===============
# Time step: 149
# Strain: -1.499259840548597e-06
# ===============
# Time step: 150
# Strain: -1.5e-06
# ===============
# Time step: 151
# Strain: -1.4992598405485978e-06
# ===============
# Time step: 152
# Strain: -1.4970400926424084e-06
# ===============
# Time step: 153
# Strain: -1.4933429469046215e-06
# ===============
# Time step: 154
# Strain: -1.4881720519717189e-06
# ===============
# Time step: 155
# Strain: -1.481532510892709e-06
# ===============
# Time step: 156
# Strain: -1.473430876093036e-06
# ===============
# Time step: 157
# Strain: -1.4638751429081245e-06
# ===============
# Time step: 158
# Strain: -1.4528747416929507e-06
# ===============
# Time step: 159
# Strain: -1.4404405285154192e-06
# ===============
# Time step: 160
# Strain: -1.4265847744427355e-06
# ===============
# Time step: 161
# Strain: -1.4113211534313438e-06
# ===============
# Time step: 162
# Strain: -1.3946647288323834e-06
# ===============
# Time step: 163
# Strain: -1.3766319385259786e-06
# ===============
# Time step: 164
# Strain: -1.3572405786990363e-06
# ===============
# Time step: 165
# Strain: -1.3365097862825598e-06
# ===============
# Time step: 166
# Strain: -1.314460020065804e-06
# ===============
# Time step: 167
# Strain: -1.291113040505924e-06
# ===============
# Time step: 168
# Strain: -1.266491888253032e-06
# ===============
# Time step: 169
# Strain: -1.2406208614118526e-06
# ===============
# Time step: 170
# Strain: -1.2135254915624315e-06
# ===============
# Time step: 171
# Strain: -1.1852325185635464e-06
# ===============
# Time step: 172
# Strain: -1.1557698641636954e-06
# ===============
# Time step: 173
# Strain: -1.1251666044457016e-06
# ===============
# Time step: 174
# Strain: -1.0934529411321302e-06
# ===============
# Time step: 175
# Strain: -1.0606601717798337e-06
# ===============
# Time step: 176
# Strain: -1.0268206588930461e-06
# ===============
# Time step: 177
# Strain: -9.919677979854925e-07
# ===============
# Time step: 178
# Strain: -9.561359846230488e-07
# ===============
# Time step: 179
# Strain: -9.193605804794796e-07
# ===============
# Time step: 180
# Strain: -8.81677878438725e-07
# ===============
# Time step: 181
# Strain: -8.431250667782118e-07
# ===============
# Time step: 182
# Strain: -8.037401924685115e-07
# ===============
# Time step: 183
# Strain: -7.635621236255728e-07
# ===============
# Time step: 184
# Strain: -7.226305111525905e-07
# ===============
# Time step: 185
# Strain: -6.809857496093382e-07
# ===============
# Time step: 186
# Strain: -6.386689373476264e-07
# ===============
# Time step: 187
# Strain: -5.957218359521889e-07
# ===============
# Time step: 188
# Strain: -5.521868290270353e-07
# ===============
# Time step: 189
# Strain: -5.08106880367956e-07
# ===============
# Time step: 190
# Strain: -4.635254915624405e-07
# ===============
# Time step: 191
# Strain: -4.1848665905886364e-07
# ===============
# Time step: 192
# Strain: -3.730348307473024e-07
# ===============
# Time step: 193
# Strain: -3.272148620948345e-07
# ===============
# Time step: 194
# Strain: -2.810719718786067e-07
# ===============
# Time step: 195
# Strain: -2.3465169756036641e-07
# ===============
# Time step: 196
# Strain: -1.8799985034647811e-07
# ===============
# Time step: 197
# Strain: -1.4116246997779227e-07
# ===============
# Time step: 198
# Strain: -9.418577929399117e-08
# ===============
# Time step: 199
# Strain: -4.711613861721385e-08
# ===============
# Time step: 200
# Strain: -2.168367611254721e-20
# ===============
# Time step: 201
# Strain: 4.71161386171705e-08
# ===============
# Time step: 202
# Strain: 9.418577929394923e-08
# ===============
# Time step: 203
# Strain: 1.411624699777491e-07
# ===============
# Time step: 204
# Strain: 1.8799985034643513e-07
# ===============
# Time step: 205
# Strain: 2.3465169756032486e-07
# ===============
# Time step: 206
# Strain: 2.8107197187856403e-07
# ===============
# Time step: 207
# Strain: 3.2721486209479213e-07
# ===============
# Time step: 208
# Strain: 3.730348307472604e-07
# ===============
# Time step: 209
# Strain: 4.1848665905882325e-07
# ===============
# Time step: 210
# Strain: 4.635254915623992e-07
# ===============
# Time step: 211
# Strain: 5.081068803679139e-07
# ===============
# Time step: 212
# Strain: 5.521868290269951e-07
# ===============
# Time step: 213
# Strain: 5.957218359521491e-07
# ===============
# Time step: 214
# Strain: 6.386689373475883e-07
# ===============
# Time step: 215
# Strain: 6.809857496092985e-07
# ===============
# Time step: 216
# Strain: 7.226305111525525e-07
# ===============
# Time step: 217
# Strain: 7.635621236255367e-07
# ===============
# Time step: 218
# Strain: 8.037401924684737e-07
# ===============
# Time step: 219
# Strain: 8.431250667781759e-07
# ===============
# Time step: 220
# Strain: 8.816778784386899e-07
# ===============
# Time step: 221
# Strain: 9.193605804794463e-07
# ===============
# Time step: 222
# Strain: 9.561359846230153e-07
# ===============
# Time step: 223
# Strain: 9.919677979854588e-07
# ===============
# Time step: 224
# Strain: 1.0268206588930154e-06
# ===============
# Time step: 225
# Strain: 1.060660171779803e-06
# ===============
# Time step: 226
# Strain: 1.0934529411321004e-06
# ===============
# Time step: 227
# Strain: 1.125166604445673e-06
# ===============
# Time step: 228
# Strain: 1.1557698641636685e-06
# ===============
# Time step: 229
# Strain: 1.18523251856352e-06
# ===============
# Time step: 230
# Strain: 1.213525491562406e-06
# ===============
# Time step: 231
# Strain: 1.240620861411829e-06
# ===============
# Time step: 232
# Strain: 1.2664918882530084e-06
# ===============
# Time step: 233
# Strain: 1.2911130405059026e-06
# ===============
# Time step: 234
# Strain: 1.3144600200657824e-06
# ===============
# Time step: 235
# Strain: 1.3365097862825397e-06
# ===============
# Time step: 236
# Strain: 1.3572405786990183e-06
# ===============
# Time step: 237
# Strain: 1.3766319385259608e-06
# ===============
# Time step: 238
# Strain: 1.3946647288323673e-06
# ===============
# Time step: 239
# Strain: 1.4113211534313292e-06
# ===============
# Time step: 240
# Strain: 1.4265847744427226e-06
# ===============
# Time step: 241
# Strain: 1.440440528515407e-06
# ===============
# Time step: 242
# Strain: 1.45287474169294e-06
# ===============
# Time step: 243
# Strain: 1.4638751429081154e-06
# ===============
# Time step: 244
# Strain: 1.4734308760930279e-06
# ===============
# Time step: 245
# Strain: 1.4815325108927023e-06
# ===============
# Time step: 246
# Strain: 1.4881720519717136e-06
# ===============
# Time step: 247
# Strain: 1.4933429469046177e-06
# ===============
# Time step: 248
# Strain: 1.4970400926424059e-06
# ===============
# Time step: 249
# Strain: 1.4992598405485966e-06
# ===============
# Time step: 250
# Strain: 1.5e-06
# ===============
# Time step: 251
# Strain: 1.499259840548598e-06
# ===============
# Time step: 252
# Strain: 1.4970400926424086e-06
# ===============
# Time step: 253
# Strain: 1.4933429469046218e-06
# ===============
# Time step: 254
# Strain: 1.488172051971719e-06
# ===============
# Time step: 255
# Strain: 1.481532510892709e-06
# ===============
# Time step: 256
# Strain: 1.4734308760930355e-06
# ===============
# Time step: 257
# Strain: 1.463875142908124e-06
# ===============
# Time step: 258
# Strain: 1.4528747416929492e-06
# ===============
# Time step: 259
# Strain: 1.440440528515417e-06
# ===============
# Time step: 260
# Strain: 1.426584774442733e-06
# ===============
# Time step: 261
# Strain: 1.4113211534313404e-06
# ===============
# Time step: 262
# Strain: 1.3946647288323796e-06
# ===============
# Time step: 263
# Strain: 1.3766319385259733e-06
# ===============
# Time step: 264
# Strain: 1.357240578699031e-06
# ===============
# Time step: 265
# Strain: 1.3365097862825528e-06
# ===============
# Time step: 266
# Strain: 1.3144600200657964e-06
# ===============
# Time step: 267
# Strain: 1.2911130405059153e-06
# ===============
# Time step: 268
# Strain: 1.2664918882530226e-06
# ===============
# Time step: 269
# Strain: 1.2406208614118414e-06
# ===============
# Time step: 270
# Strain: 1.2135254915624199e-06
# ===============
# Time step: 271
# Strain: 1.1852325185635328e-06
# ===============
# Time step: 272
# Strain: 1.155769864163681e-06
# ===============
# Time step: 273
# Strain: 1.1251666044456848e-06
# ===============
# Time step: 274
# Strain: 1.0934529411321129e-06
# ===============
# Time step: 275
# Strain: 1.060660171779815e-06
# ===============
# Time step: 276
# Strain: 1.0268206588930269e-06
# ===============
# Time step: 277
# Strain: 9.919677979854696e-07
# ===============
# Time step: 278
# Strain: 9.561359846230263e-07
# ===============
# Time step: 279
# Strain: 9.193605804794544e-07
# ===============
# Time step: 280
# Strain: 8.816778784386994e-07
# ===============
# Time step: 281
# Strain: 8.431250667781834e-07
# ===============
# Time step: 282
# Strain: 8.037401924684823e-07
# ===============
# Time step: 283
# Strain: 7.63562123625542e-07
# ===============
# Time step: 284
# Strain: 7.22630511152558e-07
# ===============
# Time step: 285
# Strain: 6.809857496093029e-07
# ===============
# Time step: 286
# Strain: 6.386689373475916e-07
# ===============
# Time step: 287
# Strain: 5.957218359521511e-07
# ===============
# Time step: 288
# Strain: 5.521868290269971e-07
# ===============
# Time step: 289
# Strain: 5.081068803679147e-07
# ===============
# Time step: 290
# Strain: 4.635254915623989e-07
# ===============
# Time step: 291
# Strain: 4.184866590588191e-07
# ===============
# Time step: 292
# Strain: 3.7303483074725485e-07
# ===============
# Time step: 293
# Strain: 3.272148620947839e-07
# ===============
# Time step: 294
# Strain: 2.8107197187855715e-07
# ===============
# Time step: 295
# Strain: 2.3465169756031392e-07
# ===============
# Time step: 296
# Strain: 1.8799985034642412e-07
# ===============
# Time step: 297
# Strain: 1.4116246997773676e-07
# ===============
# Time step: 298
# Strain: 9.418577929393551e-08
# ===============
# Time step: 299
# Strain: 4.711613861715544e-08
# ===============
# Time step: 300
# Strain: -3.675240256778895e-20
# ===============
# Time step: 301
# Strain: -4.711613861723157e-08
# ===============
# Time step: 302
# Strain: -9.418577929400887e-08
# ===============
# Time step: 303
# Strain: -1.411624699778126e-07
# ===============
# Time step: 304
# Strain: -1.8799985034649707e-07
# ===============
# Time step: 305
# Strain: -2.346516975603892e-07
# ===============
# Time step: 306
# Strain: -2.8107197187862936e-07
# ===============
# Time step: 307
# Strain: -3.2721486209485825e-07
# ===============
# Time step: 308
# Strain: -3.7303483074732605e-07
# ===============
# Time step: 309
# Strain: -4.1848665905888964e-07
# ===============
# Time step: 310
# Strain: -4.635254915624662e-07
# ===============
# Time step: 311
# Strain: -5.08106880367984e-07
# ===============
# Time step: 312
# Strain: -5.52186829027063e-07
# ===============
# Time step: 313
# Strain: -5.957218359522185e-07
# ===============
# Time step: 314
# Strain: -6.386689373476557e-07
# ===============
# Time step: 315
# Strain: -6.809857496093683e-07
# ===============
# Time step: 316
# Strain: -7.226305111526201e-07
# ===============
# Time step: 317
# Strain: -7.635621236256053e-07
# ===============
# Time step: 318
# Strain: -8.037401924685421e-07
# ===============
# Time step: 319
# Strain: -8.431250667782442e-07
# ===============
# Time step: 320
# Strain: -8.816778784387567e-07
# ===============
# Time step: 321
# Strain: -9.193605804795125e-07
# ===============
# Time step: 322
# Strain: -9.56135984623081e-07
# ===============
# Time step: 323
# Strain: -9.919677979855247e-07
# ===============
# Time step: 324
# Strain: -1.0268206588930783e-06
# ===============
# Time step: 325
# Strain: -1.060660171779867e-06
# ===============
# Time step: 326
# Strain: -1.0934529411321616e-06
# ===============
# Time step: 327
# Strain: -1.1251666044457335e-06
# ===============
# Time step: 328
# Strain: -1.1557698641637263e-06
# ===============
# Time step: 329
# Strain: -1.1852325185635794e-06
# ===============
# Time step: 330
# Strain: -1.2135254915624633e-06
# ===============
# Time step: 331
# Strain: -1.2406208614118842e-06
# ===============
# Time step: 332
# Strain: -1.266491888253062e-06
# ===============
# Time step: 333
# Strain: -1.291113040505954e-06
# ===============
# Time step: 334
# Strain: -1.314460020065832e-06
# ===============
# Time step: 335
# Strain: -1.336509786282587e-06
# ===============
# Time step: 336
# Strain: -1.3572405786990624e-06
# ===============
# Time step: 337
# Strain: -1.3766319385260035e-06
# ===============
# Time step: 338
# Strain: -1.3946647288324065e-06
# ===============
# Time step: 339
# Strain: -1.411321153431366e-06
# ===============
# Time step: 340
# Strain: -1.4265847744427556e-06
# ===============
# Time step: 341
# Strain: -1.440440528515438e-06
# ===============
# Time step: 342
# Strain: -1.4528747416929677e-06
# ===============
# Time step: 343
# Strain: -1.46387514290814e-06
# ===============
# Time step: 344
# Strain: -1.4734308760930492e-06
# ===============
# Time step: 345
# Strain: -1.4815325108927205e-06
# ===============
# Time step: 346
# Strain: -1.4881720519717278e-06
# ===============
# Time step: 347
# Strain: -1.4933429469046285e-06
# ===============
# Time step: 348
# Strain: -1.497040092642413e-06
# ===============
# Time step: 349
# Strain: -1.4992598405486004e-06
# ===============
# Time step: 350
# Strain: -1.5e-06
# ===============
# Time step: 351
# Strain: -1.4992598405485944e-06
# ===============
# Time step: 352
# Strain: -1.4970400926424014e-06
# ===============
# Time step: 353
# Strain: -1.493342946904611e-06
# ===============
# Time step: 354
# Strain: -1.4881720519717047e-06
# ===============
# Time step: 355
# Strain: -1.481532510892691e-06
# ===============
# Time step: 356
# Strain: -1.4734308760930145e-06
# ===============
# Time step: 357
# Strain: -1.463875142908099e-06
# ===============
# Time step: 358
# Strain: -1.4528747416929215e-06
# ===============
# Time step: 359
# Strain: -1.4404405285153857e-06
# ===============
# Time step: 360
# Strain: -1.4265847744426984e-06
# ===============
# Time step: 361
# Strain: -1.4113211534313023e-06
# ===============
# Time step: 362
# Strain: -1.3946647288323383e-06
# ===============
# Time step: 363
# Strain: -1.376631938525929e-06
# ===============
# Time step: 364
# Strain: -1.3572405786989836e-06
# ===============
# Time step: 365
# Strain: -1.336509786282502e-06
# ===============
# Time step: 366
# Strain: -1.3144600200657413e-06
# ===============
# Time step: 367
# Strain: -1.291113040505857e-06
# ===============
# Time step: 368
# Strain: -1.2664918882529614e-06
# ===============
# Time step: 369
# Strain: -1.2406208614117772e-06
# ===============
# Time step: 370
# Strain: -1.2135254915623525e-06
# ===============
# Time step: 371
# Strain: -1.1852325185634627e-06
# ===============
# Time step: 372
# Strain: -1.1557698641636084e-06
# ===============
# Time step: 373
# Strain: -1.1251666044456092e-06
# ===============
# Time step: 374
# Strain: -1.0934529411320345e-06
# ===============
# Time step: 375
# Strain: -1.0606601717797342e-06
# ===============
# Time step: 376
# Strain: -1.0268206588929434e-06
# ===============
# Time step: 377
# Strain: -9.919677979853839e-07
# ===============
# Time step: 378
# Strain: -9.561359846229382e-07
# ===============
# Time step: 379
# Strain: -9.19360580479364e-07
# ===============
# Time step: 380
# Strain: -8.816778784386068e-07
# ===============
# Time step: 381
# Strain: -8.431250667780888e-07
# ===============
# Time step: 382
# Strain: -8.037401924683857e-07
# ===============
# Time step: 383
# Strain: -7.635621236254436e-07
# ===============
# Time step: 384
# Strain: -7.226305111524578e-07
# ===============
# Time step: 385
# Strain: -6.809857496092009e-07
# ===============
# Time step: 386
# Strain: -6.386689373474881e-07
# ===============
# Time step: 387
# Strain: -5.957218359520462e-07
# ===============
# Time step: 388
# Strain: -5.521868290268907e-07
# ===============
# Time step: 389
# Strain: -5.081068803678071e-07
# ===============
# Time step: 390
# Strain: -4.6352549156229003e-07
# ===============
# Time step: 391
# Strain: -4.184866590587092e-07
# ===============
# Time step: 392
# Strain: -3.730348307471466e-07
# ===============
# Time step: 393
# Strain: -3.2721486209467487e-07
# ===============
# Time step: 394
# Strain: -2.810719718784474e-07
# ===============
# Time step: 395
# Strain: -2.346516975602036e-07
# ===============
# Time step: 396
# Strain: -1.8799985034631064e-07
# ===============
# Time step: 397
# Strain: -1.411624699776255e-07
# ===============
# Time step: 398
# Strain: -9.418577929382134e-08
# ===============
# Time step: 399
# Strain: -4.711613861704376e-08
# ===============
# Time step: 400
# Strain: 1.5114372168923302e-19
# ===============
# Time step: 401
# Strain: 4.711613861734591e-08
# ===============
# Time step: 402
# Strain: 9.418577929412305e-08
# ===============
# Time step: 403
# Strain: 1.4116246997792644e-07
# ===============
# Time step: 404
# Strain: 1.8799985034661057e-07
# ===============
# Time step: 405
# Strain: 2.3465169756050212e-07
# ===============
# Time step: 406
# Strain: 2.810719718787417e-07
# ===============
# Time step: 407
# Strain: 3.272148620949699e-07
# ===============
# Time step: 408
# Strain: 3.7303483074743685e-07
# ===============
# Time step: 409
# Strain: 4.184866590589995e-07
# ===============
# Time step: 410
# Strain: 4.63525491562575e-07
# ===============
# Time step: 411
# Strain: 5.081068803680915e-07
# ===============
# Time step: 412
# Strain: 5.521868290271694e-07
# ===============
# Time step: 413
# Strain: 5.957218359523236e-07
# ===============
# Time step: 414
# Strain: 6.386689373477592e-07
# ===============
# Time step: 415
# Strain: 6.809857496094703e-07
# ===============
# Time step: 416
# Strain: 7.226305111527203e-07
# ===============
# Time step: 417
# Strain: 7.635621236257037e-07
# ===============
# Time step: 418
# Strain: 8.037401924686387e-07
# ===============
# Time step: 419
# Strain: 8.431250667783388e-07
# ===============
# Time step: 420
# Strain: 8.816778784388493e-07
# ===============
# Time step: 421
# Strain: 9.19360580479603e-07
# ===============
# Time step: 422
# Strain: 9.561359846231712e-07
# ===============
# Time step: 423
# Strain: 9.919677979856105e-07
# ===============
# Time step: 424
# Strain: 1.0268206588931639e-06
# ===============
# Time step: 425
# Strain: 1.060660171779948e-06
# ===============
# Time step: 426
# Strain: 1.0934529411322416e-06
# ===============
# Time step: 427
# Strain: 1.1251666044458091e-06
# ===============
# Time step: 428
# Strain: 1.1557698641638009e-06
# ===============
# Time step: 429
# Strain: 1.1852325185636478e-06
# ===============
# Time step: 430
# Strain: 1.2135254915625302e-06
# ===============
# Time step: 431
# Strain: 1.240620861411947e-06
# ===============
# Time step: 432
# Strain: 1.2664918882531232e-06
# ===============
# Time step: 433
# Strain: 1.291113040506011e-06
# ===============
# Time step: 434
# Strain: 1.314460020065887e-06
# ===============
# Time step: 435
# Strain: 1.336509786282638e-06
# ===============
# Time step: 436
# Strain: 1.3572405786991113e-06
# ===============
# Time step: 437
# Strain: 1.376631938526048e-06
# ===============
# Time step: 438
# Strain: 1.3946647288324486e-06
# ===============
# Time step: 439
# Strain: 1.411321153431404e-06
# ===============
# Time step: 440
# Strain: 1.4265847744427912e-06
# ===============
# Time step: 441
# Strain: 1.4404405285154694e-06
# ===============
# Time step: 442
# Strain: 1.452874741692996e-06
# ===============
# Time step: 443
# Strain: 1.4638751429081643e-06
# ===============
# Time step: 444
# Strain: 1.4734308760930706e-06
# ===============
# Time step: 445
# Strain: 1.481532510892738e-06
# ===============
# Time step: 446
# Strain: 1.4881720519717424e-06
# ===============
# Time step: 447
# Strain: 1.4933429469046391e-06
# ===============
# Time step: 448
# Strain: 1.4970400926424203e-06
# ===============
# Time step: 449
# Strain: 1.4992598405486038e-06
# ===============
# Time step: 450
# Strain: 1.5e-06
# ===============
# Time step: 451
# Strain: 1.499259840548591e-06
# ===============
# Time step: 452
# Strain: 1.497040092642394e-06
# ===============
# Time step: 453
# Strain: 1.4933429469046004e-06
# ===============
# Time step: 454
# Strain: 1.48817205197169e-06
# ===============
# Time step: 455
# Strain: 1.4815325108926735e-06
# ===============
# Time step: 456
# Strain: 1.4734308760929927e-06
# ===============
# Time step: 457
# Strain: 1.4638751429080736e-06
# ===============
# Time step: 458
# Strain: 1.4528747416928925e-06
# ===============
# Time step: 459
# Strain: 1.4404405285153531e-06
# ===============
# Time step: 460
# Strain: 1.4265847744426624e-06
# ===============
# Time step: 461
# Strain: 1.4113211534312627e-06
# ===============
# Time step: 462
# Strain: 1.3946647288322953e-06
# ===============
# Time step: 463
# Strain: 1.3766319385258824e-06
# ===============
# Time step: 464
# Strain: 1.3572405786989336e-06
# ===============
# Time step: 465
# Strain: 1.3365097862824488e-06
# ===============
# Time step: 466
# Strain: 1.3144600200656862e-06
# ===============
# Time step: 467
# Strain: 1.2911130405057988e-06
# ===============
# Time step: 468
# Strain: 1.2664918882529e-06
# ===============
# Time step: 469
# Strain: 1.2406208614117129e-06
# ===============
# Time step: 470
# Strain: 1.2135254915622854e-06
# ===============
# Time step: 471
# Strain: 1.1852325185633926e-06
# ===============
# Time step: 472
# Strain: 1.1557698641635353e-06
# ===============
# Time step: 473
# Strain: 1.1251666044455336e-06
# ===============
# Time step: 474
# Strain: 1.0934529411319564e-06
# ===============
# Time step: 475
# Strain: 1.0606601717796533e-06
# ===============
# Time step: 476
# Strain: 1.02682065889286e-06
# ===============
# Time step: 477
# Strain: 9.919677979852981e-07
# ===============
# Time step: 478
# Strain: 9.561359846228501e-07
# ===============
# Time step: 479
# Strain: 9.193605804792738e-07
# ===============
# Time step: 480
# Strain: 8.816778784385142e-07
# ===============
# Time step: 481
# Strain: 8.43125066777994e-07
# ===============
# Time step: 482
# Strain: 8.037401924682892e-07
# ===============
# Time step: 483
# Strain: 7.635621236253452e-07
# ===============
# Time step: 484
# Strain: 7.226305111523575e-07
# ===============
# Time step: 485
# Strain: 6.80985749609099e-07
# ===============
# Time step: 486
# Strain: 6.386689373473846e-07
# ===============
# Time step: 487
# Strain: 5.957218359519411e-07
# ===============
# Time step: 488
# Strain: 5.521868290267844e-07
# ===============
# Time step: 489
# Strain: 5.081068803676995e-07
# ===============
# Time step: 490
# Strain: 4.635254915621813e-07
# ===============
# Time step: 491
# Strain: 4.1848665905859937e-07
# ===============
# Time step: 492
# Strain: 3.7303483074703583e-07
# ===============
# Time step: 493
# Strain: 3.2721486209456327e-07
# ===============
# Time step: 494
# Strain: 2.810719718783324e-07
# ===============
# Time step: 495
# Strain: 2.3465169756009063e-07
# ===============
# Time step: 496
# Strain: 1.8799985034619714e-07
# ===============
# Time step: 497
# Strain: 1.4116246997751163e-07
# ===============
# Time step: 498
# Strain: 9.418577929370453e-08
# ===============
# Time step: 499
# Strain: 4.7116138616929433e-08
# ===============
# Time step: 500
# Strain: -2.6819957606977745e-19
# ===============
# Time step: 501
# Strain: -4.711613861745758e-08
# ===============
# Time step: 502
# Strain: -9.418577929423987e-08
# ===============
# Time step: 503
# Strain: -1.411624699780377e-07
# ===============
# Time step: 504
# Strain: -1.8799985034672666e-07
# ===============
# Time step: 505
# Strain: -2.346516975606125e-07
# ===============
# Time step: 506
# Strain: -2.810719718788567e-07
# ===============
# Time step: 507
# Strain: -3.2721486209507896e-07
# ===============
# Time step: 508
# Strain: -3.730348307475502e-07
# ===============
# Time step: 509
# Strain: -4.184866590591068e-07
# ===============
# Time step: 510
# Strain: -4.635254915626863e-07
# ===============
# Time step: 511
# Strain: -5.081068803681967e-07
# ===============
# Time step: 512
# Strain: -5.521868290272757e-07
# ===============
# Time step: 513
# Strain: -5.957218359524286e-07
# ===============
# Time step: 514
# Strain: -6.386689373478651e-07
# ===============
# Time step: 515
# Strain: -6.809857496095699e-07
# ===============
# Time step: 516
# Strain: -7.226305111528205e-07
# ===============
# Time step: 517
# Strain: -7.635621236258022e-07
# ===============
# Time step: 518
# Strain: -8.037401924687377e-07
# ===============
# Time step: 519
# Strain: -8.431250667784312e-07
# ===============
# Time step: 520
# Strain: -8.816778784389418e-07
# ===============
# Time step: 521
# Strain: -9.193605804796933e-07
# ===============
# Time step: 522
# Strain: -9.561359846232593e-07
# ===============
# Time step: 523
# Strain: -9.919677979856945e-07
# ===============
# Time step: 524
# Strain: -1.0268206588932452e-06
# ===============
# Time step: 525
# Strain: -1.060660171780029e-06
# ===============
# Time step: 526
# Strain: -1.09345294113232e-06
# ===============
# Time step: 527
# Strain: -1.125166604445883e-06
# ===============
# Time step: 528
# Strain: -1.155769864163872e-06
# ===============
# Time step: 529
# Strain: -1.185232518563718e-06
# ===============
# Time step: 530
# Strain: -1.2135254915625975e-06
# ===============
# Time step: 531
# Strain: -1.2406208614120127e-06
# ===============
# Time step: 532
# Strain: -1.266491888253183e-06
# ===============
# Time step: 533
# Strain: -1.2911130405060718e-06
# ===============
# Time step: 534
# Strain: -1.314460020065942e-06
# ===============
# Time step: 535
# Strain: -1.336509786282691e-06
# ===============
# Time step: 536
# Strain: -1.3572405786991587e-06
# ===============
# Time step: 537
# Strain: -1.3766319385260954e-06
# ===============
# Time step: 538
# Strain: -1.3946647288324908e-06
# ===============
# Time step: 539
# Strain: -1.4113211534314436e-06
# ===============
# Time step: 540
# Strain: -1.4265847744428255e-06
# ===============
# Time step: 541
# Strain: -1.4404405285155028e-06
# ===============
# Time step: 542
# Strain: -1.4528747416930246e-06
# ===============
# Time step: 543
# Strain: -1.46387514290819e-06
# ===============
# Time step: 544
# Strain: -1.4734308760930916e-06
# ===============
# Time step: 545
# Strain: -1.4815325108927567e-06
# ===============
# Time step: 546
# Strain: -1.4881720519717566e-06
# ===============
# Time step: 547
# Strain: -1.4933429469046501e-06
# ===============
# Time step: 548
# Strain: -1.4970400926424272e-06
# ===============
# Time step: 549
# Strain: -1.4992598405486076e-06
# ===============
# Time step: 550
# Strain: -1.5e-06
# ===============
# Time step: 551
# Strain: -1.4992598405485872e-06
# ===============
# Time step: 552
# Strain: -1.4970400926423872e-06
# ===============
# Time step: 553
# Strain: -1.4933429469045891e-06
# ===============
# Time step: 554
# Strain: -1.4881720519716761e-06
# ===============
# Time step: 555
# Strain: -1.4815325108926553e-06
# ===============
# Time step: 556
# Strain: -1.4734308760929711e-06
# ===============
# Time step: 557
# Strain: -1.4638751429080487e-06
# ===============
# Time step: 558
# Strain: -1.4528747416928648e-06
# ===============
# Time step: 559
# Strain: -1.4404405285153218e-06
# ===============
# Time step: 560
# Strain: -1.4265847744426269e-06
# ===============
# Time step: 561
# Strain: -1.411321153431224e-06
# ===============
# Time step: 562
# Strain: -1.3946647288322543e-06
# ===============
# Time step: 563
# Strain: -1.376631938525838e-06
# ===============
# Time step: 564
# Strain: -1.3572405786988851e-06
# ===============
# Time step: 565
# Strain: -1.336509786282397e-06
# ===============
# Time step: 566
# Strain: -1.3144600200656325e-06
# ===============
# Time step: 567
# Strain: -1.2911130405057419e-06
# ===============
# Time step: 568
# Strain: -1.2664918882528388e-06
# ===============
# Time step: 569
# Strain: -1.2406208614116485e-06
# ===============
# Time step: 570
# Strain: -1.2135254915622166e-06
# ===============
# Time step: 571
# Strain: -1.1852325185633242e-06
# ===============
# Time step: 572
# Strain: -1.1557698641634625e-06
# ===============
# Time step: 573
# Strain: -1.125166604445458e-06
# ===============
# Time step: 574
# Strain: -1.0934529411318763e-06
# ===============
# Time step: 575
# Strain: -1.0606601717795743e-06
# ===============
# Time step: 576
# Strain: -1.0268206588927766e-06
# ===============
# Time step: 577
# Strain: -9.919677979852121e-07
# ===============
# Time step: 578
# Strain: -9.5613598462276e-07
# ===============
# Time step: 579
# Strain: -9.193605804791853e-07
# ===============
# Time step: 580
# Strain: -8.816778784384218e-07
# ===============
# Time step: 581
# Strain: -8.431250667778995e-07
# ===============
# Time step: 582
# Strain: -8.037401924681904e-07
# ===============
# Time step: 583
# Strain: -7.635621236252489e-07
# ===============
# Time step: 584
# Strain: -7.226305111522572e-07
# ===============
# Time step: 585
# Strain: -6.809857496089971e-07
# ===============
# Time step: 586
# Strain: -6.386689373472786e-07
# ===============
# Time step: 587
# Strain: -5.957218359518386e-07
# ===============
# Time step: 588
# Strain: -5.521868290266781e-07
# ===============
# Time step: 589
# Strain: -5.081068803675919e-07
# ===============
# Time step: 590
# Strain: -4.6352549156206996e-07
# ===============
# Time step: 591
# Strain: -4.184866590584921e-07
# ===============
# Time step: 592
# Strain: -3.7303483074692503e-07
# ===============
# Time step: 593
# Strain: -3.272148620944516e-07
# ===============
# Time step: 594
# Strain: -2.8107197187822003e-07
# ===============
# Time step: 595
# Strain: -2.346516975599803e-07
# ===============
# Time step: 596
# Strain: -1.879998503460863e-07
# ===============
# Time step: 597
# Strain: -1.4116246997739776e-07
# ===============
# Time step: 598
# Strain: -9.418577929359301e-08
# ===============
# Time step: 599
# Strain: -4.711613861681776e-08
# ===============
# Time step: 600
# Strain: 3.7726182467302074e-19
# ===============
# Time step: 601
# Strain: 4.7116138617571915e-08
# ===============
# Time step: 602
# Strain: 9.418577929435136e-08
# ===============
# Time step: 603
# Strain: 1.4116246997815421e-07
# ===============
# Time step: 604
# Strain: 1.8799985034683487e-07
# ===============
# Time step: 605
# Strain: 2.3465169756073074e-07
# ===============
# Time step: 606
# Strain: 2.810719718789664e-07
# ===============
# Time step: 607
# Strain: 3.272148620951932e-07
# ===============
# Time step: 608
# Strain: 3.73034830747661e-07
# ===============
# Time step: 609
# Strain: 4.184866590592218e-07
# ===============
# Time step: 610
# Strain: 4.6352549156279254e-07
# ===============
# Time step: 611
# Strain: 5.081068803683069e-07
# ===============
# Time step: 612
# Strain: 5.521868290273845e-07
# ===============
# Time step: 613
# Strain: 5.95721835952536e-07
# ===============
# Time step: 614
# Strain: 6.386689373479662e-07
# ===============
# Time step: 615
# Strain: 6.809857496096741e-07
# ===============
# Time step: 616
# Strain: 7.226305111529231e-07
# ===============
# Time step: 617
# Strain: 7.63562123625903e-07
# ===============
# Time step: 618
# Strain: 8.037401924688319e-07
# ===============
# Time step: 619
# Strain: 8.43125066778528e-07
# ===============
# Time step: 620
# Strain: 8.816778784390364e-07
# ===============
# Time step: 621
# Strain: 9.193605804797858e-07
# ===============
# Time step: 622
# Strain: 9.561359846233454e-07
# ===============
# Time step: 623
# Strain: 9.919677979857822e-07
# ===============
# Time step: 624
# Strain: 1.0268206588933305e-06
# ===============
# Time step: 625
# Strain: 1.0606601717801117e-06
# ===============
# Time step: 626
# Strain: 1.0934529411323964e-06
# ===============
# Time step: 627
# Strain: 1.1251666044459605e-06
# ===============
# Time step: 628
# Strain: 1.1557698641639468e-06
# ===============
# Time step: 629
# Strain: 1.1852325185637897e-06
# ===============
# Time step: 630
# Strain: 1.2135254915626632e-06
# ===============
# Time step: 631
# Strain: 1.2406208614120756e-06
# ===============
# Time step: 632
# Strain: 1.266491888253246e-06
# ===============
# Time step: 633
# Strain: 1.2911130405061287e-06
# ===============
# Time step: 634
# Strain: 1.3144600200659958e-06
# ===============
# Time step: 635
# Strain: 1.3365097862827419e-06
# ===============
# Time step: 636
# Strain: 1.3572405786992087e-06
# ===============
# Time step: 637
# Strain: 1.3766319385261397e-06
# ===============
# Time step: 638
# Strain: 1.3946647288325319e-06
# ===============
# Time step: 639
# Strain: 1.4113211534314815e-06
# ===============
# Time step: 640
# Strain: 1.4265847744428617e-06
# ===============
# Time step: 641
# Strain: 1.440440528515534e-06
# ===============
# Time step: 642
# Strain: 1.4528747416930536e-06
# ===============
# Time step: 643
# Strain: 1.4638751429082143e-06
# ===============
# Time step: 644
# Strain: 1.4734308760931136e-06
# ===============
# Time step: 645
# Strain: 1.4815325108927741e-06
# ===============
# Time step: 646
# Strain: 1.4881720519717712e-06
# ===============
# Time step: 647
# Strain: 1.4933429469046607e-06
# ===============
# Time step: 648
# Strain: 1.4970400926424347e-06
# ===============
# Time step: 649
# Strain: 1.4992598405486112e-06
# ===============
# Time step: 650
# Strain: 1.5e-06
# ===============
# Time step: 651
# Strain: 1.4992598405485836e-06
# ===============
# Time step: 652
# Strain: 1.4970400926423798e-06
# ===============
# Time step: 653
# Strain: 1.4933429469045786e-06
# ===============
# Time step: 654
# Strain: 1.4881720519716613e-06
# ===============
# Time step: 655
# Strain: 1.4815325108926377e-06
# ===============
# Time step: 656
# Strain: 1.4734308760929501e-06
# ===============
# Time step: 657
# Strain: 1.463875142908024e-06
# ===============
# Time step: 658
# Strain: 1.4528747416928355e-06
# ===============
# Time step: 659
# Strain: 1.4404405285152906e-06
# ===============
# Time step: 660
# Strain: 1.4265847744425909e-06
# ===============
# Time step: 661
# Strain: 1.4113211534311863e-06
# ===============
# Time step: 662
# Strain: 1.394664728832211e-06
# ===============
# Time step: 663
# Strain: 1.3766319385257937e-06
# ===============
# Time step: 664
# Strain: 1.3572405786988351e-06
# ===============
# Time step: 665
# Strain: 1.3365097862823461e-06
# ===============
# Time step: 666
# Strain: 1.314460020065576e-06
# ===============
# Time step: 667
# Strain: 1.2911130405056851e-06
# ===============
# Time step: 668
# Strain: 1.266491888252776e-06
# ===============
# Time step: 669
# Strain: 1.2406208614115856e-06
# ===============
# Time step: 670
# Strain: 1.213525491562151e-06
# ===============
# Time step: 671
# Strain: 1.1852325185632556e-06
# ===============
# Time step: 672
# Strain: 1.1557698641633877e-06
# ===============
# Time step: 673
# Strain: 1.1251666044453841e-06
# ===============
# Time step: 674
# Strain: 1.0934529411317997e-06
# ===============
# Time step: 675
# Strain: 1.0606601717794953e-06
# ===============
# Time step: 676
# Strain: 1.0268206588926914e-06
# ===============
# Time step: 677
# Strain: 9.919677979851245e-07
# ===============
# Time step: 678
# Strain: 9.561359846226737e-07
# ===============
# Time step: 679
# Strain: 9.193605804790929e-07
# ===============
# Time step: 680
# Strain: 8.81677878438327e-07
# ===============
# Time step: 681
# Strain: 8.431250667778027e-07
# ===============
# Time step: 682
# Strain: 8.03740192468096e-07
# ===============
# Time step: 683
# Strain: 7.635621236251481e-07
# ===============
# Time step: 684
# Strain: 7.226305111521547e-07
# ===============
# Time step: 685
# Strain: 6.809857496088928e-07
# ===============
# Time step: 686
# Strain: 6.386689373471776e-07
# ===============
# Time step: 687
# Strain: 5.957218359517312e-07
# ===============
# Time step: 688
# Strain: 5.521868290265693e-07
# ===============
# Time step: 689
# Strain: 5.081068803674818e-07
# ===============
# Time step: 690
# Strain: 4.6352549156196366e-07
# ===============
# Time step: 691
# Strain: 4.184866590583797e-07
# ===============
# Time step: 692
# Strain: 3.7303483074681164e-07
# ===============
# Time step: 693
# Strain: 3.272148620943374e-07
# ===============
# Time step: 694
# Strain: 2.810719718781103e-07
# ===============
# Time step: 695
# Strain: 2.3465169755986465e-07
# ===============
# Time step: 696
# Strain: 1.8799985034597016e-07
# ===============
# Time step: 697
# Strain: 1.4116246997728121e-07
# ===============
# Time step: 698
# Strain: 9.418577929348151e-08
# ===============
# Time step: 699
# Strain: 4.711613861670076e-08
# ===============
# Time step: 700
# Strain: -4.9431767905356515e-19
# ===============
# Time step: 701
# Strain: -4.7116138617688904e-08
# ===============
# Time step: 702
# Strain: -9.418577929446288e-08
# ===============
# Time step: 703
# Strain: -1.4116246997826544e-07
# ===============
# Time step: 704
# Strain: -1.87999850346951e-07
# ===============
# Time step: 705
# Strain: -2.3465169756084112e-07
# ===============
# Time step: 706
# Strain: -2.8107197187907617e-07
# ===============
# Time step: 707
# Strain: -3.272148620953022e-07
# ===============
# Time step: 708
# Strain: -3.730348307477692e-07
# ===============
# Time step: 709
# Strain: -4.1848665905932903e-07
# ===============
# Time step: 710
# Strain: -4.635254915628989e-07
# ===============
# Time step: 711
# Strain: -5.081068803684119e-07
# ===============
# Time step: 712
# Strain: -5.521868290274884e-07
# ===============
# Time step: 713
# Strain: -5.957218359526385e-07
# ===============
# Time step: 714
# Strain: -6.386689373480721e-07
# ===============
# Time step: 715
# Strain: -6.809857496097737e-07
# ===============
# Time step: 716
# Strain: -7.226305111530257e-07
# ===============
# Time step: 717
# Strain: -7.635621236259992e-07
# ===============
# Time step: 718
# Strain: -8.037401924689307e-07
# ===============
# Time step: 719
# Strain: -8.431250667786204e-07
# ===============
# Time step: 720
# Strain: -8.816778784391312e-07
# ===============
# Time step: 721
# Strain: -9.193605804798741e-07
# ===============
# Time step: 722
# Strain: -9.561359846234354e-07
# ===============
# Time step: 723
# Strain: -9.91967797985866e-07
# ===============
# Time step: 724
# Strain: -1.0268206588934159e-06
# ===============
# Time step: 725
# Strain: -1.0606601717801905e-06
# ===============
# Time step: 726
# Strain: -1.0934529411324764e-06
# ===============
# Time step: 727
# Strain: -1.1251666044460342e-06
# ===============
# Time step: 728
# Strain: -1.1557698641640213e-06
# ===============
# Time step: 729
# Strain: -1.1852325185638583e-06
# ===============
# Time step: 730
# Strain: -1.2135254915627322e-06
# ===============
# Time step: 731
# Strain: -1.2406208614121383e-06
# ===============
# Time step: 732
# Strain: -1.2664918882533087e-06
# ===============
# Time step: 733
# Strain: -1.2911130405061857e-06
# ===============
# Time step: 734
# Strain: -1.3144600200660522e-06
# ===============
# Time step: 735
# Strain: -1.3365097862827925e-06
# ===============
# Time step: 736
# Strain: -1.3572405786992584e-06
# ===============
# Time step: 737
# Strain: -1.3766319385261842e-06
# ===============
# Time step: 738
# Strain: -1.3946647288325749e-06
# ===============
# Time step: 739
# Strain: -1.4113211534315191e-06
# ===============
# Time step: 740
# Strain: -1.426584774442898e-06
# ===============
# Time step: 741
# Strain: -1.440440528515565e-06
# ===============
# Time step: 742
# Strain: -1.4528747416930814e-06
# ===============
# Time step: 743
# Strain: -1.4638751429082397e-06
# ===============
# Time step: 744
# Strain: -1.4734308760931354e-06
# ===============
# Time step: 745
# Strain: -1.4815325108927917e-06
# ===============
# Time step: 746
# Strain: -1.4881720519717852e-06
# ===============
# Time step: 747
# Strain: -1.4933429469046717e-06
# ===============
# Time step: 748
# Strain: -1.497040092642442e-06
# ===============
# Time step: 749
# Strain: -1.4992598405486146e-06
# ===============
# Time step: 750
# Strain: -1.5e-06
# ===============
# Time step: 751
# Strain: -1.49925984054858e-06
# ===============
# Time step: 752
# Strain: -1.4970400926423726e-06
# ===============
# Time step: 753
# Strain: -1.4933429469045676e-06
# ===============
# Time step: 754
# Strain: -1.4881720519716473e-06
# ===============
# Time step: 755
# Strain: -1.4815325108926195e-06
# ===============
# Time step: 756
# Strain: -1.4734308760929281e-06
# ===============
# Time step: 757
# Strain: -1.4638751429079987e-06
# ===============
# Time step: 758
# Strain: -1.4528747416928078e-06
# ===============
# Time step: 759
# Strain: -1.440440528515258e-06
# ===============
# Time step: 760
# Strain: -1.4265847744425564e-06
# ===============
# Time step: 761
# Strain: -1.4113211534311465e-06
# ===============
# Time step: 762
# Strain: -1.39466472883217e-06
# ===============
# Time step: 763
# Strain: -1.3766319385257473e-06
# ===============
# Time step: 764
# Strain: -1.3572405786987875e-06
# ===============
# Time step: 765
# Strain: -1.336509786282293e-06
# ===============
# Time step: 766
# Strain: -1.3144600200655221e-06
# ===============
# Time step: 767
# Strain: -1.2911130405056256e-06
# ===============
# Time step: 768
# Strain: -1.2664918882527162e-06
# ===============
# Time step: 769
# Strain: -1.24062086141152e-06
# ===============
# Time step: 770
# Strain: -1.2135254915620853e-06
# ===============
# Time step: 771
# Strain: -1.1852325185631839e-06
# ===============
# Time step: 772
# Strain: -1.1557698641633166e-06
# ===============
# Time step: 773
# Strain: -1.1251666044453066e-06
# ===============
# Time step: 774
# Strain: -1.0934529411317232e-06
# ===============
# Time step: 775
# Strain: -1.0606601717794125e-06
# ===============
# Time step: 776
# ...
# Strain: -1.493342946901476e-06
# ===============
# Time step: 9748
# Strain: -1.497040092640303e-06
# ===============
# Time step: 9749
# Strain: -1.4992598405475441e-06
# ===============
# Time step: 9750
# Strain: -1.5e-06
# ===============
# Time step: 9751
# Strain: -1.4992598405496517e-06
# ===============
# Time step: 9752
# Strain: -1.4970400926445165e-06
# ===============
# Time step: 9753
# Strain: -1.4933429469077829e-06
# ===============
# Time step: 9754
# Strain: -1.488172051975942e-06
# ===============
# Time step: 9755
# Strain: -1.4815325108979834e-06
# ===============
# Time step: 9756
# Strain: -1.4734308760993573e-06
# ===============
# Time step: 9757
# Strain: -1.4638751429154877e-06
# ===============
# Time step: 9758
# Strain: -1.4528747417013707e-06
# ===============
# Time step: 9759
# Strain: -1.4404405285248465e-06
# ===============
# Time step: 9760
# Strain: -1.4265847744531832e-06
# ===============
# Time step: 9761
# Strain: -1.4113211534428315e-06
# ===============
# Time step: 9762
# Strain: -1.3946647288448744e-06
# ===============
# Time step: 9763
# Strain: -1.376631938539462e-06
# ===============
# Time step: 9764
# Strain: -1.3572405787135362e-06
# ===============
# Time step: 9765
# Strain: -1.3365097862980287e-06
# ===============
# Time step: 9766
# Strain: -1.3144600200822277e-06
# ===============
# Time step: 9767
# Strain: -1.2911130405232884e-06
# ===============
# Time step: 9768
# Strain: -1.2664918882713198e-06
# ===============
# Time step: 9769
# Strain: -1.240620861431047e-06
# ===============
# Time step: 9770
# Strain: -1.2135254915825149e-06
# ===============
# Time step: 9771
# Strain: -1.1852325185845517e-06
# ===============
# Time step: 9772
# Strain: -1.155769864185553e-06
# ===============
# Time step: 9773
# Strain: -1.1251666044683904e-06
# ===============
# Time step: 9774
# Strain: -1.0934529411556873e-06
# ===============
# Time step: 9775
# Strain: -1.060660171804121e-06
# ===============
# Time step: 9776
# Strain: -1.026820658918098e-06
# ===============
# Time step: 9777
# Strain: -9.91967798011348e-07
# ===============
# Time step: 9778
# Strain: -9.56135984649623e-07
# ===============
# Time step: 9779
# Strain: -9.193605805067458e-07
# ===============
# Time step: 9780
# Strain: -8.816778784666572e-07
# ===============
# Time step: 9781
# Strain: -8.431250668068536e-07
# ===============
# Time step: 9782
# Strain: -8.037401924977662e-07
# ===============
# Time step: 9783
# Strain: -7.635621236554136e-07
# ===============
# Time step: 9784
# Strain: -7.22630511182986e-07
# ===============
# Time step: 9785
# Strain: -6.809857496402603e-07
# ===============
# Time step: 9786
# Strain: -6.386689373790461e-07
# ===============
# Time step: 9787
# Strain: -5.957218359841528e-07
# ===============
# Time step: 9788
# Strain: -5.521868290594354e-07
# ===============
# Time step: 9789
# Strain: -5.081068804007604e-07
# ===============
# Time step: 9790
# Strain: -4.6352549159569866e-07
# ===============
# Time step: 9791
# Strain: -4.1848665909238084e-07
# ===============
# Time step: 9792
# Strain: -3.73034830781127e-07
# ===============
# Time step: 9793
# Strain: -3.272148621290166e-07
# ===============
# Time step: 9794
# Strain: -2.8107197191303155e-07
# ===============
# Time step: 9795
# Strain: -2.3465169759499894e-07
# ===============
# Time step: 9796
# Strain: -1.8799985038128312e-07
# ===============
# Time step: 9797
# Strain: -1.4116247001282296e-07
# ===============
# Time step: 9798
# Strain: -9.418577932912718e-08
# ===============
# Time step: 9799
# Strain: -4.711613865233538e-08
# ===============
# Time step: 9800
# Strain: -3.526447471532724e-17
# ===============
# Time step: 9801
# Strain: 4.711613858192646e-08
# ===============
# Time step: 9802
# Strain: 9.418577925873741e-08
# ===============
# Time step: 9803
# Strain: 1.4116246994252213e-07
# ===============
# Time step: 9804
# Strain: 1.8799985031131028e-07
# ===============
# Time step: 9805
# Strain: 2.3465169752533835e-07
# ===============
# Time step: 9806
# Strain: 2.810719718437519e-07
# ===============
# Time step: 9807
# Strain: 3.272148620601862e-07
# ===============
# Time step: 9808
# Strain: 3.7303483071289644e-07
# ===============
# Time step: 9809
# Strain: 4.184866590247342e-07
# ===============
# Time step: 9810
# Strain: 4.6352549152854054e-07
# ===============
# Time step: 9811
# Strain: 5.081068803344011e-07
# ===============
# Time step: 9812
# Strain: 5.521868289938593e-07
# ===============
# Time step: 9813
# Strain: 5.957218359193462e-07
# ===============
# Time step: 9814
# Strain: 6.386689373152297e-07
# ===============
# Time step: 9815
# Strain: 6.809857495774946e-07
# ===============
# Time step: 9816
# Strain: 7.22630511121181e-07
# ===============
# Time step: 9817
# Strain: 7.635621235947063e-07
# ===============
# Time step: 9818
# Strain: 8.037401924382168e-07
# ===============
# Time step: 9819
# Strain: 8.431250667484501e-07
# ===============
# Time step: 9820
# Strain: 8.816778784095982e-07
# ===============
# Time step: 9821
# Strain: 9.19360580451017e-07
# ===============
# Time step: 9822
# Strain: 9.561359845952794e-07
# ===============
# Time step: 9823
# Strain: 9.919677979583792e-07
# ===============
# Time step: 9824
# Strain: 1.0268206588667466e-06
# ===============
# Time step: 9825
# Strain: 1.06066017175431e-06
# ===============
# Time step: 9826
# Strain: 1.0934529411073486e-06
# ===============
# Time step: 9827
# Strain: 1.1251666044217487e-06
# ===============
# Time step: 9828
# Strain: 1.155769864140596e-06
# ===============
# Time step: 9829
# Strain: 1.185232518541272e-06
# ===============
# Time step: 9830
# Strain: 1.213525491541059e-06
# ===============
# Time step: 9831
# Strain: 1.240620861391404e-06
# ===============
# Time step: 9832
# Strain: 1.2664918882335283e-06
# ===============
# Time step: 9833
# Strain: 1.2911130404873862e-06
# ===============
# Time step: 9834
# Strain: 1.3144600200482503e-06
# ===============
# Time step: 9835
# Strain: 1.3365097862660094e-06
# ===============
# Time step: 9836
# Strain: 1.3572405786834704e-06
# ===============
# Time step: 9837
# Strain: 1.3766319385114515e-06
# ===============
# Time step: 9838
# Strain: 1.394664728818911e-06
# ===============
# Time step: 9839
# Strain: 1.411321153418912e-06
# ===============
# Time step: 9840
# Strain: 1.4265847744314147e-06
# ===============
# Time step: 9841
# Strain: 1.4404405285051934e-06
# ===============
# Time step: 9842
# Strain: 1.4528747416838095e-06
# ===============
# Time step: 9843
# Strain: 1.463875142900102e-06
# ===============
# Time step: 9844
# Strain: 1.4734308760861413e-06
# ===============
# Time step: 9845
# Strain: 1.4815325108869501e-06
# ===============
# Time step: 9846
# Strain: 1.4881720519670918e-06
# ===============
# Time step: 9847
# Strain: 1.4933429469011455e-06
# ===============
# Time step: 9848
# Strain: 1.497040092640088e-06
# ===============
# Time step: 9849
# Strain: 1.4992598405474365e-06
# ===============
# Time step: 9850
# Strain: 1.5e-06
# ===============
# Time step: 9851
# Strain: 1.4992598405497595e-06
# ===============
# Time step: 9852
# Strain: 1.4970400926447371e-06
# ===============
# Time step: 9853
# Strain: 1.4933429469081134e-06
# ===============
# Time step: 9854
# Strain: 1.4881720519763714e-06
# ===============
# Time step: 9855
# Strain: 1.4815325108985193e-06
# ===============
# Time step: 9856
# Strain: 1.4734308760999992e-06
# ===============
# Time step: 9857
# Strain: 1.463875142916235e-06
# ===============
# Time step: 9858
# Strain: 1.4528747417022228e-06
# ===============
# Time step: 9859
# Strain: 1.440440528525826e-06
# ===============
# Time step: 9860
# Strain: 1.4265847744542683e-06
# ===============
# Time step: 9861
# Strain: 1.4113211534439923e-06
# ===============
# Time step: 9862
# Strain: 1.3946647288461674e-06
# ===============
# Time step: 9863
# Strain: 1.3766319385408567e-06
# ===============
# Time step: 9864
# Strain: 1.3572405787149593e-06
# ===============
# Time step: 9865
# Strain: 1.3365097862995845e-06
# ===============
# Time step: 9866
# Strain: 1.3144600200838788e-06
# ===============
# Time step: 9867
# Strain: 1.2911130405250326e-06
# ===============
# Time step: 9868
# Strain: 1.2664918882732017e-06
# ===============
# Time step: 9869
# Strain: 1.2406208614330212e-06
# ===============
# Time step: 9870
# Strain: 1.213525491584579e-06
# ===============
# Time step: 9871
# Strain: 1.1852325185866522e-06
# ===============
# Time step: 9872
# Strain: 1.1557698641877372e-06
# ===============
# Time step: 9873
# Strain: 1.1251666044706566e-06
# ===============
# Time step: 9874
# Strain: 1.0934529411579747e-06
# ===============
# Time step: 9875
# Strain: 1.0606601718066044e-06
# ===============
# Time step: 9876
# Strain: 1.0268206589206581e-06
# ===============
# Time step: 9877
# Strain: 9.919677980139183e-07
# ===============
# Time step: 9878
# Strain: 9.561359846523288e-07
# ===============
# Time step: 9879
# Strain: 9.193605805095207e-07
# ===============
# Time step: 9880
# Strain: 8.816778784694986e-07
# ===============
# Time step: 9881
# Strain: 8.431250668096879e-07
# ===============
# Time step: 9882
# Strain: 8.037401925006596e-07
# ===============
# Time step: 9883
# Strain: 7.63562123658363e-07
# ===============
# Time step: 9884
# Strain: 7.22630511185989e-07
# ===============
# Time step: 9885
# Strain: 6.809857496433896e-07
# ===============
# Time step: 9886
# Strain: 6.386689373822239e-07
# ===============
# Time step: 9887
# Strain: 5.957218359872978e-07
# ===============
# Time step: 9888
# Strain: 5.521868290627007e-07
# ===============
# Time step: 9889
# Strain: 5.081068804039847e-07
# ===============
# Time step: 9890
# Strain: 4.635254915988766e-07
# ===============
# Time step: 9891
# Strain: 4.1848665909575346e-07
# ===============
# Time step: 9892
# Strain: 3.730348307845287e-07
# ===============
# Time step: 9893
# Strain: 3.272148621323608e-07
# ===============
# Time step: 9894
# Strain: 2.810719719163976e-07
# ===============
# Time step: 9895
# Strain: 2.3465169759846778e-07
# ===============
# Time step: 9896
# Strain: 1.8799985038476744e-07
# ===============
# Time step: 9897
# Strain: 1.411624700162345e-07
# ===============
# Time step: 9898
# Strain: 9.41857793325472e-08
# ===============
# Time step: 9899
# Strain: 4.711613865584569e-08
# ===============
# Time step: 9900
# Strain: 3.869125075555019e-17
# ===============
# Time step: 9901
# Strain: -4.711613857841614e-08
# ===============
# Time step: 9902
# Strain: -9.41857792552323e-08
# ===============
# Time step: 9903
# Strain: -1.4116246993911055e-07
# ===============
# Time step: 9904
# Strain: -1.8799985030782596e-07
# ===============
# Time step: 9905
# Strain: -2.346516975219538e-07
# ===============
# Time step: 9906
# Strain: -2.8107197184038577e-07
# ===============
# Time step: 9907
# Strain: -3.272148620567587e-07
# ===============
# Time step: 9908
# Strain: -3.730348307094947e-07
# ===============
# Time step: 9909
# Strain: -4.184866590213617e-07
# ===============
# Time step: 9910
# Strain: -4.6352549152528147e-07
# ===============
# Time step: 9911
# Strain: -5.081068803310967e-07
# ===============
# Time step: 9912
# Strain: -5.521868289905938e-07
# ===============
# Time step: 9913
# Strain: -5.957218359162797e-07
# ===============
# Time step: 9914
# Strain: -6.38668937312129e-07
# ===============
# Time step: 9915
# Strain: -6.809857495743653e-07
# ===============
# Time step: 9916
# Strain: -7.226305111181781e-07
# ===============
# Time step: 9917
# Strain: -7.635621235916834e-07
# ===============
# Time step: 9918
# Strain: -8.037401924352513e-07
# ===============
# Time step: 9919
# Strain: -8.431250667456158e-07
# ===============
# Time step: 9920
# Strain: -8.816778784068258e-07
# ===============
# Time step: 9921
# Strain: -9.193605804483092e-07
# ===============
# Time step: 9922
# Strain: -9.56135984592639e-07
# ===============
# Time step: 9923
# Strain: -9.919677979558728e-07
# ===============
# Time step: 9924
# Strain: -1.0268206588641865e-06
# ===============
# Time step: 9925
# Strain: -1.0606601717518266e-06
# ===============
# Time step: 9926
# Strain: -1.0934529411050027e-06
# ===============
# Time step: 9927
# Strain: -1.1251666044194262e-06
# ===============
# Time step: 9928
# Strain: -1.1557698641383573e-06
# ===============
# Time step: 9929
# Strain: -1.1852325185392238e-06
# ===============
# Time step: 9930
# Strain: -1.2135254915390447e-06
# ===============
# Time step: 9931
# Strain: -1.2406208613894778e-06
# ===============
# Time step: 9932
# Strain: -1.2664918882316924e-06
# ===============
# Time step: 9933
# Strain: -1.2911130404855984e-06
# ===============
# Time step: 9934
# Strain: -1.3144600200465583e-06
# ===============
# Time step: 9935
# Strain: -1.3365097862644146e-06
# ===============
# Time step: 9936
# Strain: -1.3572405786820112e-06
# ===============
# Time step: 9937
# Strain: -1.3766319385100905e-06
# ===============
# Time step: 9938
# Strain: -1.3946647288176495e-06
# ===============
# Time step: 9939
# Strain: -1.4113211534177799e-06
# ===============
# Time step: 9940
# Strain: -1.4265847744303294e-06
# ===============
# Time step: 9941
# Strain: -1.4404405285042134e-06
# ===============
# Time step: 9942
# Strain: -1.4528747416829572e-06
# ===============
# Time step: 9943
# Strain: -1.463875142899336e-06
# ===============
# Time step: 9944
# Strain: -1.4734308760854833e-06
# ===============
# Time step: 9945
# Strain: -1.4815325108864008e-06
# ===============
# Time step: 9946
# Strain: -1.4881720519666623e-06
# ===============
# Time step: 9947
# Strain: -1.493342946900823e-06
# ===============
# Time step: 9948
# Strain: -1.4970400926398728e-06
# ===============
# Time step: 9949
# Strain: -1.4992598405473288e-06
# ===============
# Time step: 9950
# Strain: -1.5e-06
# ===============
# Time step: 9951
# Strain: -1.4992598405498699e-06
# ===============
# Time step: 9952
# Strain: -1.4970400926449523e-06
# ===============
# Time step: 9953
# Strain: -1.4933429469084438e-06
# ===============
# Time step: 9954
# Strain: -1.4881720519768009e-06
# ===============
# Time step: 9955
# Strain: -1.4815325108990555e-06
# ===============
# Time step: 9956
# Strain: -1.4734308761006573e-06
# ===============
# Time step: 9957
# Strain: -1.4638751429170012e-06
# ===============
# Time step: 9958
# Strain: -1.452874741703075e-06
# ===============
# Time step: 9959
# Strain: -1.4404405285267821e-06
# ===============
# Time step: 9960
# Strain: -1.4265847744553535e-06
# ===============
# Time step: 9961
# Strain: -1.411321153445182e-06
# ===============
# Time step: 9962
# Strain: -1.3946647288474289e-06
# ===============
# Time step: 9963
# Strain: -1.3766319385422177e-06
# ===============
# Time step: 9964
# Strain: -1.3572405787164545e-06
# ===============
# Time step: 9965
# Strain: -1.33650978630114e-06
# ===============
# Time step: 9966
# Strain: -1.3144600200855705e-06
# ===============
# Time step: 9967
# Strain: -1.2911130405268205e-06
# ===============
# Time step: 9968
# Strain: -1.2664918882750376e-06
# ===============
# Time step: 9969
# Strain: -1.2406208614349474e-06
# ===============
# Time step: 9970
# Strain: -1.2135254915865933e-06
# ===============
# Time step: 9971
# Strain: -1.1852325185887524e-06
# ===============
# Time step: 9972
# Strain: -1.155769864189976e-06
# ===============
# Time step: 9973
# Strain: -1.125166604472979e-06
# ===============
# Time step: 9974
# Strain: -1.093452941160379e-06
# ===============
# Time step: 9975
# Strain: -1.0606601718090278e-06
# ===============
# Time step: 9976
# Strain: -1.0268206589232183e-06
# ===============
# Time step: 9977
# Strain: -9.919677980165528e-07
# ===============
# Time step: 9978
# Strain: -9.561359846549036e-07
# ===============
# Time step: 9979
# Strain: -9.193605805122285e-07
# ===============
# Time step: 9980
# Strain: -8.816778784722709e-07
# ===============
# Time step: 9981
# Strain: -8.431250668125221e-07
# ===============
# Time step: 9982
# Strain: -8.037401925036249e-07
# ===============
# Time step: 9983
# Strain: -7.635621236613862e-07
# ===============
# Time step: 9984
# Strain: -7.226305111890665e-07
# ===============
# Time step: 9985
# Strain: -6.809857496464428e-07
# ===============
# Time step: 9986
# Strain: -6.386689373853246e-07
# ===============
# Time step: 9987
# Strain: -5.957218359904427e-07
# ===============
# Time step: 9988
# Strain: -5.521868290658076e-07
# ===============
# Time step: 9989
# Strain: -5.08106880407289e-07
# ===============
# Time step: 9990
# Strain: -4.635254916022168e-07
# ===============
# Time step: 9991
# Strain: -4.184866590990442e-07
# ===============
# Time step: 9992
# Strain: -3.7303483078793037e-07
# ===============
# Time step: 9993
# Strain: -3.272148621357883e-07
# ===============
# Time step: 9994
# Strain: -2.8107197191976366e-07
# ===============
# Time step: 9995
# Strain: -2.3465169760185237e-07
# ===============
# Time step: 9996
# Strain: -1.879998503881672e-07
# ===============
# Time step: 9997
# Strain: -1.4116247001964607e-07
# ===============
# Time step: 9998
# Strain: -9.418577933596721e-08
# ===============
# Time step: 9999
# Strain: -4.7116138659356004e-08
# <img src="data:image/png;base64,..." width="572.85">
# Total time: 49.79194760322571
# Solving time: 31.94122004508972

# %% [markdown]
# # BC3

# %%
# parameters["ghost_mode"] = "shared_facet"

# compare upwind flux with lax-friedrichs flux
lx = 1
m_size = lx*80
mesh = IntervalMesh(m_size, 0.0, lx)

# Material properties
mu = Constant(14e9)
rho = Constant(2.2e3)
gamma = Constant(20)
tau_min = 1e-3
tau_max = 10e-3
tau = tau_min*gamma # \tau_1 in the literature


beta_E = 50
delta_E = 1e8

delta_t = 1e-6
t_total = 10e-3

t_excitation = 40e-3

fc = 5e3

A_amp = 5e-6

g0 = 1e-2

deg_dg = 1 # DG degree

def mu_fun(eps):
    return mu * (1 - 2*beta_E*eps - 3 * delta_E*eps*eps)

def stress_fun(eps):
    return mu * eps * (1 - beta_E*eps - delta_E*eps*eps)

def energy_fun(eps):
    return mu * eps * eps * (0.5 - beta_E/3*eps  - delta_E/4*eps*eps)

EPS_SMALL = 1e-4
def phig_fun(g_inti):
    return g_inti/(tau_max*(exp(-g_inti/g0*math.log(tau_max/tau_min)))\
                            *(g_inti/g0*math.log(tau_max/tau_min)* (1-ln(g_inti/g0+EPS_SMALL)) + 1) \
                    + tau_min*(g_inti)/g0*math.log(tau_max/tau_min) )

A_amp1 = float(stress_fun(A_amp)/rho)

A_amp2 = -float(sqrt(mu_fun(A_amp)/rho)*A_amp)

def flux_fun(q_f):
    (eps,vel, g_int) = split(q_f)
    return as_vector([-vel('+'), -(1-g_int('+'))*stress_fun(eps('+'))/rho ,0]) \
           + as_vector([-vel('-'), -(1-g_int('-'))*stress_fun(eps('-'))/rho ,0])

def AStar_fun(q_f):
    (eps, vel, g_int) = split(q_f)
    a = (1 - 0.5*(g_int('+')+g_int('-')) ) * mu_fun((eps('+')+eps('-'))*0.5)/rho
    b = stress_fun((eps('+')+eps('-'))*0.5)/rho
    RStar = as_tensor([[1, 1, b], \
                       [sqrt(a), -sqrt(a), 0], \
                       [0, 0, a]])
    RStar_inv = as_tensor([[1/2, 1/2/sqrt(a), -b/a/2], \
                           [1/2, -1/2/sqrt(a), -b/a/2], \
                           [0, 0, 1/a]])
    Lamb = as_tensor([[sqrt(a), 0, 0], \
                      [0, sqrt(a), 0], \
                      [0, 0, 0]])
    return dot(dot(RStar,Lamb),RStar_inv)

# Function space
Ee = FiniteElement("DG", mesh.ufl_cell(), deg_dg)
Ve = FiniteElement("DG", mesh.ufl_cell(), deg_dg)
Ge = FiniteElement("DG", mesh.ufl_cell(), deg_dg)
V_dg = FunctionSpace(mesh, MixedElement([Ee, Ve, Ge]))

phi, v = TrialFunction(V_dg), TestFunction(V_dg)
q_new, q_old = Function(V_dg), Function(V_dg)
q_rk = Function(V_dg)

q0 = Expression(("0","0","0"), degree=1, t=0, name='q0') # 
q_old = project(q0, V_dg)

v_exact = Expression("(t<tc1 ) ? A*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ", \
                     degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp, lx = lx) # 

v_exact2 = Expression("(t<tc1 ) ? A*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ", \
                     degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp2, lx = lx) # 

v_exactr = Expression(" 0 ", \
                     degree=1, t=0, tc1=t_excitation, c=fc, A=A_amp, lx = lx) # 

f_ext = Expression(("(t<tc1 ) ? -A1*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ",\
                    "(t<tc1 ) ? -A2*(lx-x[0])/lx*sin(2*pi*(x[0] + c*t)) : 0 ",\
                    "0"), \
                   degree=1, t=0, tc1=t_excitation, c=fc, A1=A_amp2, A2=A_amp1, lx = lx) #

DOFIN_EPS = 1e-10 # + lx/m_size/2
if deg_dg == 0: DOFIN_EPS = 1e-10 + lx/m_size/2
def left(x, on_boundary):
    return abs(x[0]-0.) < DOFIN_EPS
def right(x, on_boundary):
    return abs(x[0]-lx) < DOFIN_EPS

boundary_markers = MeshFunction('size_t', mesh, mesh.topology().dim() - 1)

class BoundaryNR(SubDomain):
    def inside(self, x, on_boundary):
        DOFIN_EPS = 1e-10 # + lx/m_size/2
        if deg_dg == 0: DOFIN_EPS = 1e-10 + lx/m_size/2
        return on_boundary and near(x[0], lx, DOFIN_EPS)
    
class BoundaryNL(SubDomain):
    def inside(self, x, on_boundary):
        DOFIN_EPS = 1e-10 # + lx/m_size/2
        if deg_dg == 0: DOFIN_EPS = 1e-10 + lx/m_size/2
        return on_boundary and near(x[0], 0, DOFIN_EPS)

bx0 = BoundaryNR()
bx0.mark(boundary_markers, 0)
bx0 = BoundaryNL()
bx0.mark(boundary_markers, 1)

dss = Measure('ds', domain=mesh, subdomain_data=boundary_markers)

bc =  [DirichletBC(V_dg.sub(0), v_exact, left, method="pointwise")]

# Weak form
n = FacetNormal(mesh)

(eps1,vel1, g_int1) = split(q_old)
mu1 = mu_fun(eps1)
sig1 = stress_fun(eps1)

c_speed1 = sqrt((1-g_int1)*mu1/rho)

W_energy1 = energy_fun(eps1)

A_adv1 = as_tensor([[0, -1, 0], \
                    [-(1-g_int1)*mu1/rho, 0, sig1/rho], \
                    [0, 0, 0]])

R1 = as_tensor([[1, 1, sig1/rho], \
                [c_speed1, -c_speed1, 0], \
                [0,0,c_speed1*c_speed1]])
R_inv1 = as_tensor([[1/2, 1/c_speed1/2, -sig1/rho/c_speed1/c_speed1/2], \
                    [1/2, -1/c_speed1/2, -sig1/rho/c_speed1/c_speed1/2], \
                    [0, 0, 1/c_speed1/c_speed1] ])
Lambda_adv_abs1 = as_tensor([[c_speed1, 0, 0], \
                             [0, c_speed1, 0], \
                             [0, 0, 0] ])

A_adv_abs1 = dot( dot(R1, Lambda_adv_abs1), R_inv1)

A_adv_plus1 = (A_adv1 + A_adv_abs1)/2
A_adv_minus1 = (A_adv1 - A_adv_abs1)/2

F = dot( (phi-q_old)/delta_t, v) * dx 

flux_inner1 = as_vector([-vel1, -(1-g_int1)*sig1/rho, 0])
# F1 = F - dot(dot(A_adv1,q_old), grad(v)[:,0]) * dx
F1 = F - dot(flux_inner1, grad(v)[:,0]) * dx

r1 = as_vector([0, 0, 1/tau*W_energy1 - phig_fun(g_int1)])
F1 += - dot(r1, v) * dx

flux1 = dot(A_adv_plus1('+'), q_old('+')) + dot(A_adv_minus1('-'), q_old('-'))

# Roe solver
flux1 = 0.5*( flux_fun(q_old) \
             - dot( AStar_fun(q_old), q_old('-')-q_old('+')  ) ) 

F1 += dot( flux1*n('+')[0], jump(v)) * dS + dot(flux_inner1,v)*n[0] * dss(1) + dot(flux_inner1,v)*n[0] * dss(0) 
# + dot(flux_inner1,v)*n[0] * dss(0) 
(eps2,vel2, g_int2) = split(q_rk)
mu2 = mu_fun(eps2)
sig2 = stress_fun(eps2)

c_speed2 = sqrt((1-g_int2)*mu2/rho)

W_energy2 = energy_fun(eps2)

A_adv2 = as_tensor([[0, -1, 0], \
                    [-(1-g_int2)*mu2/rho, 0, sig2/rho], \
                    [0, 0, 0]])

R2 = as_tensor([[1, 1, sig2/rho], \
                [c_speed2, -c_speed2, 0], \
                [0,0,c_speed2*c_speed2]])
R_inv2 = as_tensor([[1/2, 1/c_speed2/2, -sig2/rho/c_speed2/c_speed2/2], \
                    [1/2, -1/c_speed2/2, -sig2/rho/c_speed2/c_speed2/2], \
                    [0, 0, 1/c_speed2/c_speed2] ])
Lambda_adv_abs2 = as_tensor([[c_speed2, 0, 0], \
                             [0, c_speed2, 0], \
                             [0, 0, 0] ])

A_adv_abs2 = dot( dot(R2, Lambda_adv_abs2), R_inv2)

A_adv_plus2 = (A_adv2 + A_adv_abs2)/2
A_adv_minus2 = (A_adv2 - A_adv_abs2)/2

flux_inner2 = as_vector([-vel2, -(1-g_int2)*sig2/rho, 0])
# F2 = - dot(dot(A_adv2,q_rk), grad(v)[:,0]) * dx
F2 = - dot(flux_inner2, grad(v)[:,0]) * dx

r2 = as_vector([0, 0, 1/tau*W_energy2 - phig_fun(g_int2)])

F2 += - dot(r2, v) * dx

flux2 = dot(A_adv_plus2('+'), q_rk('+')) + dot(A_adv_minus2('-'), q_rk('-'))

# Roe solver
flux2 = 0.5*( flux_fun(q_rk) \
            - dot( AStar_fun(q_rk), q_rk('-')-q_rk('+')  ) ) 

F2 += dot( flux2*n('+')[0], jump(v)) * dS + dot(flux_inner1,v)*n[0] * dss(1) + dot(flux_inner1,v)*n[0] * dss(0)
# + dot(flux_inner2,v)*n[0] * dss(0)
F += 0.5*((F1-F) + F2)

#===========
Sta1 = time.time()
T_sol = 0
#===========

t = 0
time_steps = int(t_total/delta_t)
uuu5 = np.zeros((time_steps,m_size,3))

a1,L1 = lhs(F1),rhs(F1)
a,L = lhs(F),rhs(F)

for n in range(time_steps):
    print('===============')
    print('Time step:',n)
    
    for i in range(m_size):
        uuu5[n,i,:] = q_old(i/(m_size-1)*lx)[:]
    
 
    T_incre1 = time.time()
    solve(a1==L1, q_new, bc)
    T_incre2 = time.time()
    T_sol += T_incre2-T_incre1
    q_rk.assign(q_new)
        
    
    T_incre1 = time.time()
    solve(a==L, q_new, bc)
    T_incre2 = time.time()
    T_sol += T_incre2-T_incre1
    q_old.assign(q_new)
    print('Strain:',q_old(0)[0])

    t += delta_t
    v_exact.t = t
    f_ext.t = t

T_total = time.time()-Sta1

plt.subplots()
plot(q_old[2])
plt.show()

print("Total time:",T_total)
print("Solving time:",T_sol)
